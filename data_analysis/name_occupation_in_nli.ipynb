# %% [markdown]
# # 🗄 NLI name frequency count

# %% [markdown]
# ## 1. Gomu Names in NLI dataset

# %%
gomu_occupations = json.load(open("../data/keywords/occupations.json"))
len(gomu_occupations)
# Out:
# 145

# %%
with open("occupations.csv", 'r') as f:
    total_occupations = []
    for line in f.readlines():
         total_occupations.append(line.strip())

# %%
len(total_occupations)
# Out:
# 1156

# %%
with open("../template_experiments/keywords/names.csv", 'r') as f:
    total_names = []
    for line in f.readlines()[1:]:
#         import ipdb; ipdb.set_trace()
        line = line.strip().split(',')
        name = dict()
        name['name'] = line[0]
        name['gender'] = line[1]
        name['race'] = line[2]
        total_names.append(name)

# %%
len(total_names)
# Out:
# 372

# %%
total_names[0]
# Out:
# {'name': "A'deem", 'gender': 'male', 'race': 'none'}

# %%
total_names_list = [n['name'] for n in total_names]

# %%
# load mnli train data
with open('../data/MNLI/original/multinli_1.0_train.jsonl') as f:
    json_list = list(f)
    mnli_train = []
    for json_str in json_list:
        result = json.loads(json_str)
        mnli_train.append(result)
len(mnli_train)
# Out:
# 392702

# %%
mnli_data = []
SEP = ' [SEP] '
for m in mnli_train:
    sent = m['sentence1'] + SEP + m['sentence2']
    mnli_data.append(sent)
mnli_data[0]
# Out:
# 'Conceptually cream skimming has two basic dimensions - product and geography. [SEP] Product and geography are what make cream skimming work. '

# %%
# load snli train data
with open('../data/SNLI/snli_1.0_train.jsonl') as f:
    json_list = list(f)
    snli_train = []
    for json_str in json_list:
        result = json.loads(json_str)
        snli_train.append(result)
len(snli_train)
# Out:
# 550152

# %%
snli_data = []
SEP = ' [SEP] '
for m in snli_train:
    sent = m['sentence1'] + SEP + m['sentence2']
    snli_data.append(sent)
snli_data[0]
# Out:
# 'A person on a horse jumps over a broken down airplane. [SEP] A person is training his horse for a competition.'

# %% [markdown]
# ### Count names in MNLI

# %%
def count_name(data, names):
    name_count = dict()
    for n in names:
        name_count[n['name']] = 0
    for d in data:
        for n in names:
            if n['name'] in d:
                name_count[n['name']] = name_count.get(n['name'], 0) + 1
    return name_count

# %%
total_name_mnli = count_name(mnli_data, total_names)

# %%
total_name_snli = count_name(snli_data, total_names)

# %%
total_name_count = {}
for name in total_name_mnli.keys():
    total_name_count[name] = total_name_mnli[name] + total_name_snli[name]
total_name_count
# Out:
# {"A'deem": 129,
#  'Aaron': 55,
#  'Abigail': 0,
#  'Adam': 170,
#  'Adrin': 1139,
#  'Aisha': 0,
#  'Alan': 110,
#  'Alexander': 225,
#  'Alfred': 253,
#  'Ally': 14,
#  'Amhad': 1,
#  'Amy': 60,
#  'Andrew': 125,
#  'Andy': 73,
#  'Anita': 21,
#  'Anna': 151,
#  'Anne': 296,
#  'Anse': 341,
#  'Ashley': 15,
#  'Bai': 169,
#  'Barbara': 71,
#  'Becky': 8,
#  'Ben': 1223,
#  'Benjamin': 121,
#  'Benny': 19,
#  'Beth': 100,
#  'Betty': 78,
#  'Beyonce': 2,
#  'Biff': 3,
#  'Bill': 855,
#  'Billy': 104,
#  'Bob': 621,
#  'Boris': 163,
#  'Brad': 400,
#  'Bradford': 6,
#  'Brady': 24,
#  'Brayden': 0,
#  'Brenda': 13,
#  'Brent': 31,
#  'Brian': 73,
#  'Brittany': 94,
#  'Brown': 950,
#  'Burr': 39,
#  'Cadaan': 1,
#  'Cadan': 0,
#  'Cal': 2024,
#  'Camille': 6,
#  'Candace': 12,
#  'Candice': 1,
#  'Candy': 53,
#  'Carl': 292,
#  'Carla': 6,
#  'Carlos': 88,
#  'Carly': 25,
#  'Carol': 384,
#  'Carrie': 40,
#  'Cathy': 12,
#  'Cazar': 252,
#  'Celia': 0,
#  'Chan': 712,
#  'Chang': 366,
#  'Chang Lee': 0,
#  'Charlene': 0,
#  'Charles': 416,
#  'Charlie': 93,
#  'Chen': 116,
#  'Chen Lang': 0,
#  'Chen Wee': 0,
#  'Chen Wu': 0,
#  'Cheryl': 6,
#  'Chin Pang': 0,
#  'Chong Ling': 0,
#  'Cindy': 30,
#  'Claire': 10,
#  'Cody': 3,
#  'Cole': 113,
#  'Connor': 33,
#  'Corey': 1,
#  'Craig': 65,
#  'Cynthia': 333,
#  "D'quan": 0,
#  'Dale': 34,
#  'Dan': 1034,
#  'Daniel': 328,
#  'Danny': 41,
#  'Dave': 713,
#  'David': 856,
#  'Dawn': 14,
#  'Dawson': 31,
#  'DeAndre': 0,
#  'Denny': 17,
#  'DeShawn': 0,
#  'Diamond': 53,
#  'Donald': 529,
#  'Drew': 1237,
#  'Dustin': 23,
#  'Dylan': 47,
#  'Earl': 264,
#  'Ebony': 0,
#  'Ed': 1719,
#  'Eddie': 39,
#  'Edith': 27,
#  'Edward': 246,
#  'Ellen': 44,
#  'Emily': 83,
#  'Eric': 68,
#  'Erica': 1,
#  'Erik': 15,
#  'Essex': 40,
#  'Ethan': 7,
#  'Eugene': 30,
#  'Fabioloa': 0,
#  'Feng Wu': 0,
#  'Flora': 9,
#  'Fowler': 48,
#  'Fred': 174,
#  'Gabriel': 133,
#  'Gary': 81,
#  'George': 929,
#  'Grace': 57,
#  'Greg': 74,
#  'Greta': 9,
#  'Greuze': 222,
#  'Gus': 41,
#  'Harold': 49,
#  'Heather': 19,
#  'Henderson': 22,
#  'Hunt': 338,
#  'Hunter': 46,
#  'Inglethorp': 913,
#  'Jack': 539,
#  'Jackson': 238,
#  'Jacob': 186,
#  'Jacques': 45,
#  'Jacqui': 0,
#  'Jafari': 0,
#  'Jake': 15,
#  'Jaleel': 0,
#  'Jamal': 0,
#  'Jamel': 0,
#  'James': 1067,
#  'Jamie': 21,
#  'Jane': 600,
#  'Janet': 91,
#  'Janice': 1,
#  'Jason': 20,
#  'Javier': 7,
#  'Jed': 39,
#  'Jeff': 195,
#  'Jeffrey': 36,
#  'Jen': 304,
#  'Jenna': 5,
#  'Jennifer': 41,
#  'Jenny': 12,
#  'Jeremy': 11,
#  'Jerome': 24,
#  'Jerry': 137,
#  "Jessica's": 0,
#  'Jesus': 756,
#  'Jill': 15,
#  'Jim': 411,
#  'Jimmy': 107,
#  'Joan': 54,
#  'Joanne': 0,
#  'Joe': 270,
#  'Joey': 11,
#  'John': 2516,
#  'Johnathan': 0,
#  'Johnny': 266,
#  'Jon': 2821,
#  'Jones': 344,
#  'Joo-Lin': 0,
#  'Jorge': 15,
#  'Jose': 266,
#  'Joseph': 183,
#  'Josh': 30,
#  'Joxer': 0,
#  'Joyce': 81,
#  'Juan': 214,
#  'Judy': 52,
#  'Julie': 83,
#  'Juliette': 0,
#  'Julius': 985,
#  'Kacey': 0,
#  'Kariem': 0,
#  'Kassandra': 12,
#  'Kassidy': 0,
#  'Kate': 30,
#  'Katherine': 34,
#  'Kathy': 24,
#  'Katie': 3,
#  'Kelly': 92,
#  'Kelsi': 0,
#  'Kenny': 24,
#  'Kevin': 69,
#  'Kia': 9,
#  'Kim': 106,
#  'King': 1429,
#  'Kirby': 198,
#  'Kristy': 2,
#  'Kurt': 25,
#  'Kwame': 0,
#  'Kyle': 18,
#  'Lamar': 45,
#  'Lance': 31,
#  'Laquan': 0,
#  'Laquisha': 0,
#  'Lara': 4,
#  'Lars': 6,
#  'LaShawnda': 0,
#  'Laura': 64,
#  'Lawrence': 330,
#  'Lea': 914,
#  'LeBron': 9,
#  'Lena': 4,
#  'Leonard': 192,
#  'LeShawn': 0,
#  'Li': 6276,
#  'Lily': 3,
#  'Lisa': 76,
#  'Liz': 32,
#  'Lloyd': 32,
#  'Lou': 1179,
#  'Louis': 920,
#  'Lucy': 49,
#  'Lynn': 30,
#  'Mack': 21,
#  'Maggie': 10,
#  'Malcolm': 51,
#  'Malik': 0,
#  'Manuel': 42,
#  'Marcus': 84,
#  'Marianne': 3,
#  'Marie': 111,
#  'Mark': 669,
#  'Marquis': 19,
#  'Martha': 83,
#  'Martin': 654,
#  'Marty': 33,
#  'Mary': 979,
#  'Mathew': 28,
#  'Matt': 230,
#  'Mattie': 0,
#  'Maya': 45,
#  'Megan': 6,
#  'Meghan': 0,
#  'Melissa': 13,
#  'Michael': 613,
#  'Micheal': 8,
#  'Miguel': 10,
#  'Mike': 147,
#  'Ming': 30,
#  'Missy': 0,
#  'Mitchell': 49,
#  'Mohammad': 3,
#  'Molly': 15,
#  'Monica': 398,
#  'Monique': 0,
#  'Muhammad': 46,
#  'Naomi': 19,
#  'Nell': 9,
#  'Nia': 18,
#  'Nick': 46,
#  'Nina': 5,
#  'Olga': 9,
#  'Patricia': 31,
#  'Patrick': 156,
#  'Paul': 561,
#  'Paula': 115,
#  'Perth': 159,
#  'Phoebe': 6,
#  'Precious': 23,
#  'Prescott': 3,
#  'Priya': 0,
#  'Rachel': 19,
#  'Raegan': 0,
#  'Ragesh': 0,
#  'Raja': 114,
#  'Rajeev': 0,
#  'Ramirez': 6,
#  'Ramon': 18,
#  'Raven': 66,
#  'Raymond': 15,
#  'Richard': 534,
#  'Robert': 771,
#  'Roberta': 15,
#  'Rocco': 6,
#  'Ron': 228,
#  'Ronald': 93,
#  'Ronnie': 4,
#  'Ruby': 22,
#  'Russ': 1031,
#  'Ryan': 67,
#  'Sally': 39,
#  'Sam': 627,
#  'Samantha': 0,
#  'Sammy': 25,
#  'Sara': 196,
#  'Sarah': 48,
#  'Scott': 638,
#  'Sergey': 0,
#  'Seth': 25,
#  'Shane': 15,
#  'Shaniqua': 0,
#  'Shannon': 177,
#  'Shaquille': 0,
#  'Sharon': 51,
#  'Shawn': 15,
#  'Shelly': 7,
#  'Sheng Lee': 0,
#  'Sherry': 18,
#  'Shevon': 0,
#  'Shiloh': 191,
#  'Sidney': 36,
#  'Silas': 0,
#  'Simon': 218,
#  'Soren': 3,
#  'Spence': 34,
#  'Stephen': 163,
#  'Steve': 424,
#  'Steven': 216,
#  'Stewart': 107,
#  'Sudeep': 0,
#  'Sue': 62,
#  'Susan': 540,
#  'Susie': 3,
#  'Tammy': 12,
#  'Tanisha': 0,
#  'Tarnisha': 0,
#  'Tasha': 0,
#  'Terrance': 4,
#  'Terrell': 0,
#  'Tessa': 0,
#  'Thomas': 377,
#  'Thorn': 499,
#  'Tim': 2308,
#  'Timmy': 9,
#  'Tina': 58,
#  'Tom': 2304,
#  'Tommy': 1699,
#  'Tony': 151,
#  'Trevon': 0,
#  'Treyvone': 0,
#  'Tricia': 0,
#  'Tuppence': 1723,
#  'Tyler': 31,
#  'Tyresse': 0,
#  'Tyrone': 7,
#  'Val': 1066,
#  'Veronica': 32,
#  'Vince': 83,
#  'Vrenna': 320,
#  'Wang': 3,
#  'Wendy': 52,
#  'Wesley': 10,
#  'Will': 1194,
#  'William': 565,
#  'Won Lee': 0,
#  'Won San Lee': 0,
#  'Wong Chang': 0,
#  'Wright': 76,
#  'Yang Wang': 0,
#  'Yolanda': 0,
#  'Zack': 6,
#  'Geraldo': 6,
#  'Mario': 62,
#  'Elena': 9,
#  'Natalia': 243,
#  'Adrian': 22,
#  'Julian': 18,
#  'Xavier': 24}

# %%
for name in total_names:
    name['count'] = total_name_count[name['name']]

# %%
total_names
# Out:
# [{'name': "A'deem", 'gender': 'male', 'race': 'none', 'count': 129},
#  {'name': 'Aaron', 'gender': 'male', 'race': 'none', 'count': 55},
#  {'name': 'Abigail', 'gender': 'female', 'race': 'white', 'count': 0},
#  {'name': 'Adam', 'gender': 'male', 'race': 'none', 'count': 170},
#  {'name': 'Adrin', 'gender': 'male', 'race': 'latinx', 'count': 1139},
#  {'name': 'Aisha', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Alan', 'gender': 'male', 'race': 'none', 'count': 110},
#  {'name': 'Alexander', 'gender': 'male', 'race': 'none', 'count': 225},
#  {'name': 'Alfred', 'gender': 'male', 'race': 'none', 'count': 253},
#  {'name': 'Ally', 'gender': 'none', 'race': 'none', 'count': 14},
#  {'name': 'Amhad', 'gender': 'male', 'race': 'none', 'count': 1},
#  {'name': 'Amy', 'gender': 'female', 'race': 'white', 'count': 60},
#  {'name': 'Andrew', 'gender': 'male', 'race': 'none', 'count': 125},
#  {'name': 'Andy', 'gender': 'male', 'race': 'none', 'count': 73},
#  {'name': 'Anita', 'gender': 'female', 'race': 'latinx', 'count': 21},
 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Thomas', 'gender': 'male', 'race': 'none', 'count': 377},
#  {'name': 'Thorn', 'gender': 'male', 'race': 'none', 'count': 499},
#  {'name': 'Tim', 'gender': 'male', 'race': 'none', 'count': 2308},
#  {'name': 'Timmy', 'gender': 'male', 'race': 'none', 'count': 9},
#  {'name': 'Tina', 'gender': 'female', 'race': 'none', 'count': 58},
#  {'name': 'Tom', 'gender': 'male', 'race': 'none', 'count': 2304},
#  {'name': 'Tommy', 'gender': 'male', 'race': 'none', 'count': 1699},
#  {'name': 'Tony', 'gender': 'male', 'race': 'none', 'count': 151},
#  {'name': 'Trevon', 'gender': 'male', 'race': 'black', 'count': 0},
#  {'name': 'Treyvone', 'gender': 'male', 'race': 'black', 'count': 0},
#  {'name': 'Tricia', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Tuppence', 'gender': 'female', 'race': 'none', 'count': 1723},
#  {'name': 'Tyler', 'gender': 'male', 'race': 'none', 'count': 31},
#  {'name': 'Tyresse', 'gender': 'male', 'race': 'black', 'count': 0},
#  {'name': 'Tyrone', 'gender': 'male', 'race': 'black', 'count': 7},
#  {'name': 'Val', 'gender': 'male', 'race': 'none', 'count': 1066},
#  {'name': 'Veronica', 'gender': 'female', 'race': 'none', 'count': 32},
#  {'name': 'Vince', 'gender': 'male', 'race': 'none', 'count': 83},
#  {'name': 'Vrenna', 'gender': 'female', 'race': 'none', 'count': 320},
#  {'name': 'Wang', 'gender': 'none', 'race': 'asian', 'count': 3},
#  {'name': 'Wendy', 'gender': 'female', 'race': 'none', 'count': 52},
#  {'name': 'Wesley', 'gender': 'male', 'race': 'none', 'count': 10},
#  {'name': 'Will', 'gender': 'male', 'race': 'none', 'count': 1194},
#  {'name': 'William', 'gender': 'male', 'race': 'none', 'count': 565},
#  {'name': 'Won Lee', 'gender': 'male', 'race': 'asian', 'count': 0},
#  {'name': 'Won San Lee', 'gender': 'male', 'race': 'asian', 'count': 0},
#  {'name': 'Wong Chang', 'gender': 'none', 'race': 'asian', 'count': 0},
#  {'name': 'Wright', 'gender': 'none', 'race': 'black', 'count': 76},
#  {'name': 'Yang Wang', 'gender': 'none', 'race': 'asian', 'count': 0},
#  {'name': 'Yolanda', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Zack', 'gender': 'male', 'race': 'none', 'count': 6},
#  {'name': 'Geraldo', 'gender': 'male', 'race': 'latinx', 'count': 6},
#  {'name': 'Manuel', 'gender': 'male', 'race': 'latinx', 'count': 42},
#  {'name': 'Mario', 'gender': 'male', 'race': 'latinx', 'count': 62},
#  {'name': 'Elena', 'gender': 'female', 'race': 'latinx', 'count': 9},
#  {'name': 'Natalia', 'gender': 'female', 'race': 'latinx', 'count': 243},
#  {'name': 'Adrian', 'gender': 'male', 'race': 'latinx', 'count': 22},
#  {'name': 'Julian', 'gender': 'male', 'race': 'latinx', 'count': 18},
#  {'name': 'Xavier', 'gender': 'male', 'race': 'latinx', 'count': 24}]

# %%
total_names_sorted = sorted(total_names, key=(lambda x: x['count']), reverse=True)

# %%
total_names_sorted
# Out:
# [{'name': 'Li', 'gender': 'none', 'race': 'asian', 'count': 6276},
#  {'name': 'Jon', 'gender': 'male', 'race': 'none', 'count': 2821},
#  {'name': 'John', 'gender': 'male', 'race': 'none', 'count': 2516},
#  {'name': 'Tim', 'gender': 'male', 'race': 'none', 'count': 2308},
#  {'name': 'Tom', 'gender': 'male', 'race': 'none', 'count': 2304},
#  {'name': 'Cal', 'gender': 'male', 'race': 'none', 'count': 2024},
#  {'name': 'Marianne', 'gender': 'female', 'race': 'none', 'count': 3},
#  {'name': 'Mohammad', 'gender': 'male', 'race': 'none', 'count': 3},
#  {'name': 'Prescott', 'gender': 'none', 'race': 'white', 'count': 3},
#  {'name': 'Soren', 'gender': 'male', 'race': 'none', 'count': 3},
#  {'name': 'Susie', 'gender': 'female', 'race': 'none', 'count': 3},
#  {'name': 'Wang', 'gender': 'none', 'race': 'asian', 'count': 3},
#  {'name': 'Beyonce', 'gender': 'female', 'race': 'black', 'count': 2},
#  {'name': 'Kristy', 'gender': 'female', 'race': 'none', 'count': 2},
#  {'name': 'Amhad', 'gender': 'male', 'race': 'none', 'count': 1},
#  {'name': 'Cadaan', 'gender': 'none', 'race': 'none', 'count': 1},
#  {'name': 'Candice', 'gender': 'female', 'race': 'none', 'count': 1},
#  {'name': 'Corey', 'gender': 'male', 'race': 'none', 'count': 1},
#  {'name': 'Erica', 'gender': 'female', 'race': 'none', 'count': 1},
#  {'name': 'Janice', 'gender': 'female', 'race': 'none', 'count': 1},
#  {'name': 'Abigail', 'gender': 'female', 'race': 'white', 'count': 0},
#  {'name': 'Aisha', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Brayden', 'gender': 'male', 'race': 'none', 'count': 0},
#  {'name': 'Cadan', 'gender': 'male', 'race': 'white', 'count': 0},
#  {'name': 'Celia', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Chang Lee', 'gender': 'male', 'race': 'asian', 'count': 0},
#  {'name': 'Charlene', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Chen Lang', 'gender': 'none', 'race': 'asian', 'count': 0},
#  {'name': 'Chen Wee', 'gender': 'male', 'race': 'asian', 'count': 0},
#  {'name': 'Chen Wu', 'gender': 'male', 'race': 'asian', 'count': 0},
#  {'name': 'Chin Pang', 'gender': 'none', 'race': 'asian', 'count': 0},
#  {'name': 'Chong Ling', 'gender': 'none', 'race': 'asian', 'count': 0},
#  {'name': "D'quan", 'gender': 'male', 'race': 'black', 'count': 0},
#  {'name': 'DeAndre', 'gender': 'male', 'race': 'none', 'count': 0},
#  {'name': 'DeShawn', 'gender': 'male', 'race': 'black', 'count': 0},
#  {'name': 'Ebony', 'gender': 'female', 'race': 'black', 'count': 0},
#  {'name': 'Fabioloa', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Feng Wu', 'gender': 'none', 'race': 'asian', 'count': 0},
#  {'name': 'Jacqui', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Jafari', 'gender': 'male', 'race': 'none', 'count': 0},
#  {'name': 'Jaleel', 'gender': 'male', 'race': 'none', 'count': 0},
#  {'name': 'Jamal', 'gender': 'male', 'race': 'black', 'count': 0},
#  {'name': 'Jamel', 'gender': 'male', 'race': 'black', 'count': 0},
#  {'name': "Jessica's", 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Joanne', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Johnathan', 'gender': 'male', 'race': 'none', 'count': 0},
#  {'name': 'Joo-Lin', 'gender': 'none', 'race': 'asian', 'count': 0},
#  {'name': 'Joxer', 'gender': 'male', 'race': 'none', 'count': 0},
#  {'name': 'Juliette', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Kacey', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Kariem', 'gender': 'male', 'race': 'none', 'count': 0},
#  {'name': 'Kassidy', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Kelsi', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Kwame', 'gender': 'male', 'race': 'black', 'count': 0},
#  {'name': 'Laquan', 'gender': 'male', 'race': 'asian', 'count': 0},
#  {'name': 'Laquisha', 'gender': 'female', 'race': 'black', 'count': 0},
#  {'name': 'LaShawnda', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'LeShawn', 'gender': 'male', 'race': 'white', 'count': 0},
#  {'name': 'Malik', 'gender': 'male', 'race': 'black', 'count': 0},
#  {'name': 'Mattie', 'gender': 'male', 'race': 'none', 'count': 0},
#  {'name': 'Meghan', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Missy', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Monique', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Priya', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Raegan', 'gender': 'none', 'race': 'none', 'count': 0},
#  {'name': 'Ragesh', 'gender': 'male', 'race': 'asian', 'count': 0},
#  {'name': 'Rajeev', 'gender': 'male', 'race': 'asian', 'count': 0},
#  {'name': 'Samantha', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Sergey', 'gender': 'male', 'race': 'none', 'count': 0},
#  {'name': 'Shaniqua', 'gender': 'female', 'race': 'black', 'count': 0},
#  {'name': 'Shaquille', 'gender': 'male', 'race': 'none', 'count': 0},
#  {'name': 'Sheng Lee', 'gender': 'male', 'race': 'asian', 'count': 0},
#  {'name': 'Shevon', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Silas', 'gender': 'male', 'race': 'latinx', 'count': 0},
#  {'name': 'Sudeep', 'gender': 'male', 'race': 'asian', 'count': 0},
#  {'name': 'Tanisha', 'gender': 'female', 'race': 'black', 'count': 0},
#  {'name': 'Tarnisha', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Tasha', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Terrell', 'gender': 'male', 'race': 'black', 'count': 0},
#  {'name': 'Tessa', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Trevon', 'gender': 'male', 'race': 'black', 'count': 0},
#  {'name': 'Treyvone', 'gender': 'male', 'race': 'black', 'count': 0},
#  {'name': 'Tricia', 'gender': 'female', 'race': 'none', 'count': 0},
#  {'name': 'Tyresse', 'gender': 'male', 'race': 'black', 'count': 0},
#  {'name': 'Won Lee', 'gender': 'male', 'race': 'asian', 'count': 0},
#  {'name': 'Won San Lee', 'gender': 'male', 'race': 'asian', 'count': 0},
#  {'name': 'Wong Chang', 'gender': 'none', 'race': 'asian', 'count': 0},
#  {'name': 'Yang Wang', 'gender': 'none', 'race': 'asian', 'count': 0},
#  {'name': 'Yolanda', 'gender': 'female', 'race': 'none', 'count': 0}]

# %%
with open("names_sorted.json",'w') as f:
    json.dump(total_names_sorted, f)

# %%
import pandas as pd

# %%
name_df = pd.DataFrame(total_names_sorted)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-140-24e22e30e311>:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
name_df[name_df['race']=='latinx']
# Out:
#         name  gender    race  count
# 14   Adrin    male    latinx  1139
# 29   Jesus    male    latinx  756
# 66   Jose     male    latinx  266
# 71   Natalia  female  latinx  243
# 79   Juan     male    latinx  214
# 99   Gabriel  male    latinx  133
# 119  Carlos   male    latinx  88
# 141  Mario    male    latinx  62
# 163  Lamar    male    latinx  45
# 164  Maya     female  latinx  45
# 166  Manuel   male    latinx  42
# 167  Manuel   male    latinx  42
# 208  Xavier   male    latinx  24
# 213  Adrian   male    latinx  22
# 214  Anita    female  latinx  21
# 225  Ramon    male    latinx  18
# 227  Julian   male    latinx  18
# 233  Jorge    male    latinx  15
# 252  Miguel   male    latinx  10
# 261  Elena    female  latinx  9
# 265  Javier   male    latinx  7
# 275  Ramirez  male    latinx  6
# 278  Geraldo  male    latinx  6
# 280  Nina     female  latinx  5
# 356  Silas    male    latinx  0

# %%
male_name_df = name_df[name_df['gender']=='male']
female_name_df = name_df[name_df['gender']=='female']
none_name_df = name_df[name_df['gender']=='none']

# %%
is_white = name_df['race'] == 'white'
is_black = name_df['race'] == 'black'
is_latinx = name_df['race'] == 'latinx'
is_asian = name_df['race'] == 'asian'

# %%
def name_distribution(name_df):
    is_male = name_df['gender'] == 'male'
    is_female = name_df['gender'] == 'female'

    is_white = name_df['race'] == 'white'
    is_black = name_df['race'] == 'black'
    is_latinx = name_df['race'] == 'latinx'
    is_asian = name_df['race'] == 'asian'

    print(f"Male names : {len(name_df[is_male])}")
    print(f"Female names : {len(name_df[is_female])}")
    print(f"White names : {len(name_df[is_white])}")
    print(f"Black names : {len(name_df[is_black])}")
    print(f"Latinx names : {len(name_df[is_latinx])}")
    print(f"Asian names : {len(name_df[is_asian])}")

# %%
name_distribution(name_df)
# Out:
# Male names : 209
# Female names : 135
# White names : 30
# Black names : 25
# Latinx names : 25
# Asian names : 25

# %%
print("Male")
name_distribution(male_name_df)
print()
print("Female")
name_distribution(female_name_df)
print()
print("None")
name_distribution(none_name_df)
# Out:
# Male
# Male names : 203
# Female names : 0
# White names : 14
# Black names : 15
# Latinx names : 14
# Asian names : 13
#
# Female
# Male names : 0
# Female names : 133
# White names : 11
# Black names : 9
# Latinx names : 3
# Asian names : 1
#
# None
# Male names : 0
# Female names : 0
# White names : 5
# Black names : 1
# Latinx names : 0
# Asian names : 11

# %%
name_distribution(male_name_df[:100])
# Out:
# Male names : 100
# Female names : 0
# White names : 6
# Black names : 1
# Latinx names : 6
# Asian names : 2

# %%
print(f"Number of 'male' names : {len(male_name_df[:100])}")
print(f"Frequency count : {male_name_df[:100]['count'].sum()}")
# Out:
# Number of 'male' names : 100
# Frequency count : 50475

# %%
male_name_df[:10].to_dict('record')
# Out:
# /home/boychaboy/anaconda3/envs/gomu/lib/python3.8/site-packages/pandas/core/frame.py:1549: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   warnings.warn(
# [{'name': 'Jon', 'gender': 'male', 'race': 'none', 'count': 2821},
#  {'name': 'John', 'gender': 'male', 'race': 'none', 'count': 2516},
#  {'name': 'Tim', 'gender': 'male', 'race': 'none', 'count': 2308},
#  {'name': 'Tom', 'gender': 'male', 'race': 'none', 'count': 2304},
#  {'name': 'Cal', 'gender': 'male', 'race': 'none', 'count': 2024},
#  {'name': 'Ed', 'gender': 'male', 'race': 'none', 'count': 1719},
#  {'name': 'Tommy', 'gender': 'male', 'race': 'none', 'count': 1699},
#  {'name': 'Drew', 'gender': 'male', 'race': 'none', 'count': 1237},
#  {'name': 'Ben', 'gender': 'male', 'race': 'none', 'count': 1223},
#  {'name': 'Will', 'gender': 'male', 'race': 'none', 'count': 1194}]

# %%
def save_name(name_df, filename):
    name_df.to_csv(filename+'.csv')
    json.dump(name_df.to_dict('record'), open(filename+'.json', 'w'))

# %%
name_distribution(female_name_df[:100])
# Out:
# Male names : 0
# Female names : 100
# White names : 10
# Black names : 4
# Latinx names : 3
# Asian names : 1

# %%
print(f"Number of 'female' names : {len(female_name_df[:100])}")
print(f"Frequency count : {female_name_df[:100]['count'].sum()}")
# Out:
# Number of 'female' names : 100
# Frequency count : 11433

# %%
white_name_df = name_df[is_white]
black_name_df = name_df[is_black]
latinx_name_df = name_df[is_latinx]
asian_name_df = name_df[is_asian]

# %%
white_name_df = white_name_df[:25]
print(f"Number of names : {len(white_name_df)}")
name_distribution(white_name_df)
print(f"Frequency count : {white_name_df['count'].sum()}")
white_name_df[:25]
# Out:
# Number of names : 25
# Male names : 12
# Female names : 9
# White names : 25
# Black names : 0
# Latinx names : 0
# Asian names : 0
# Frequency count : 4162
#            name  gender   race  count
# 21   Brown       none    white  950
# 25   Inglethorp  none    white  913
# 34   Scott       male    white  638
# 42   Jack        male    white  539
# 76   Greuze      none    white  222
# 85   Jacob       male    white  186
# 106  Cole        male    white  113
# 121  Emily       female  white  83
# 130  Greg        male    white  74
# 138  Craig       female  white  65
# 142  Amy         female  white  60
# 158  Dylan       male    white  47
# 159  Hunter      male    white  46
# 172  Essex       none    white  40
# 180  Katherine   female  white  34
# 182  Connor      male    white  33
# 200  Carly       female  white  25
# 209  Dustin      male    white  23
# 219  Heather     female  white  19
# 231  Jake        male    white  15
# 234  Molly       female  white  15
# 250  Claire      female  white  10
# 279  Jenna       female  white  5
# 283  Ronnie      male    white  4
# 286  Cody        male    white  3

# %%
print(f"Number of names : {len(black_name_df)}")
name_distribution(black_name_df)
print(f"Frequency count : {black_name_df['count'].sum()}")
black_name_df
# Out:
# Number of names : 25
# Male names : 15
# Female names : 9
# White names : 0
# Black names : 25
# Latinx names : 0
# Asian names : 0
# Frequency count : 349
#          name  gender   race  count
# 125  Gary      male    black  81
# 129  Wright    none    black  76
# 137  Raven     female  black  66
# 148  Diamond   female  black  53
# 210  Precious  female  black  23
# 220  Marquis   male    black  19
# 256  Kia       female  black  9
# 257  LeBron    male    black  9
# 267  Tyrone    male    black  7
# 284  Terrance  male    black  4
# 295  Beyonce   female  black  2
# 315  D'quan    male    black  0
# 317  DeShawn   male    black  0
# 318  Ebony     female  black  0
# 324  Jamal     male    black  0
# 325  Jamel     male    black  0
# 336  Kwame     male    black  0
# 338  Laquisha  female  black  0
# 341  Malik     male    black  0
# 352  Shaniqua  female  black  0
# 358  Tanisha   female  black  0
# 361  Terrell   male    black  0
# 363  Trevon    male    black  0
# 364  Treyvone  male    black  0
# 366  Tyresse   male    black  0

# %%
print(f"Number of names : {len(latinx_name_df)}")
name_distribution(latinx_name_df)
print(f"Frequency count : {latinx_name_df['count'].sum()}")
latinx_name_df[:25]
# Out:
# Number of names : 25
# Male names : 20
# Female names : 5
# White names : 0
# Black names : 0
# Latinx names : 25
# Asian names : 0
# Frequency count : 3236
#         name  gender    race  count
# 14   Adrin    male    latinx  1139
# 29   Jesus    male    latinx  756
# 66   Jose     male    latinx  266
# 71   Natalia  female  latinx  243
# 79   Juan     male    latinx  214
# 99   Gabriel  male    latinx  133
# 119  Carlos   male    latinx  88
# 141  Mario    male    latinx  62
# 163  Lamar    male    latinx  45
# 164  Maya     female  latinx  45
# 166  Manuel   male    latinx  42
# 167  Manuel   male    latinx  42
# 208  Xavier   male    latinx  24
# 213  Adrian   male    latinx  22
# 214  Anita    female  latinx  21
# 225  Ramon    male    latinx  18
# 227  Julian   male    latinx  18
# 233  Jorge    male    latinx  15
# 252  Miguel   male    latinx  10
# 261  Elena    female  latinx  9
# 265  Javier   male    latinx  7
# 275  Ramirez  male    latinx  6
# 278  Geraldo  male    latinx  6
# 280  Nina     female  latinx  5
# 356  Silas    male    latinx  0

# %%
print(f"Number of names : {len(asian_name_df)}")
name_distribution(asian_name_df)
print(f"Frequency count : {asian_name_df['count'].sum()}")
asian_name_df[:25]
# Out:
# Number of names : 25
# Male names : 13
# Female names : 1
# White names : 0
# Black names : 0
# Latinx names : 0
# Asian names : 25
# Frequency count : 7786
#             name  gender   race  count
# 0    Li           none    asian  6276
# 31   Chan         male    asian  712
# 53   Chang        none    asian  366
# 90   Bai          female  asian  169
# 103  Chen         male    asian  116
# 105  Raja         none    asian  114
# 197  Ming         male    asian  30
# 294  Wang         none    asian  3
# 308  Chang Lee    male    asian  0
# 310  Chen Lang    none    asian  0
# 311  Chen Wee     male    asian  0
# 312  Chen Wu      male    asian  0
# 313  Chin Pang    none    asian  0
# 314  Chong Ling   none    asian  0
# 320  Feng Wu      none    asian  0
# 329  Joo-Lin      none    asian  0
# 337  Laquan       male    asian  0
# 348  Ragesh       male    asian  0
# 349  Rajeev       male    asian  0
# 354  Sheng Lee    male    asian  0
# 357  Sudeep       male    asian  0
# 367  Won Lee      male    asian  0
# 368  Won San Lee  male    asian  0
# 369  Wong Chang   none    asian  0
# 370  Yang Wang    none    asian  0

# %%
save_name(male_name_df[:100], 'male_names')
save_name(female_name_df[:100], 'female_names')
save_name(white_name_df, 'white_names')
save_name(black_name_df, 'black_names')
save_name(latinx_name_df, 'latinx_names')
save_name(asian_name_df, 'asian_names')

# %% [markdown]
# ## 2. Gomu occupations in NLI dataset

# %% [markdown]
# ### Count occupation in MNLI

# %%
def count_entity(entities, data):
    count = dict()
    sent = []
    for e in entities:
        count[e] = count.get(e, 0)
    for d in data:
        for e in entities:
            if e in d:
                count[e] += 1
                sent.append(d)
    return count, sent

# %%
gomu_occupations
# Out:
# ['academic',
#  'accountant',
#  'actor',
#  'administrator',
#  'aeronautical engineer',
#  'agent',
#  'airman',
#  'analyst',
#  'architect',
#  'army',
#  'artist',
#  'arts',
#  'assistant',
#  'astronomer',
#  'athlete',
#  'attendant',
#  'attourney',
#  'auditor',
#  'author',
#  'baker',
#  'banker',
#  'barber',
#  'bartender',
#  'boxer',
#  'broker',
#  'builder',
#  'businessperson',
#  'butcher',
#  'butler',
#  'carpenter',
#  'cashier',
#  'CEO',
#  'chef',
#  'chemist',
#  'chess player',
#  'chief',
#  'civil',
#  'cleaner',
#  'cleric',
#  'clerk',
#  'coach',
#  'comedian',
#  'commander',
#  'composer',
#  'construction worker',
#  'cook',
#  'counselor',
#  'dancer',
#  'dealer',
#  'delivery',
#  'dentist',
#  'designer',
#  'detective',
#  'diplomat',
#  'director',
#  'doctor',
#  'drawer',
#  'driver',
#  'economist',
#  'editor',
#  'electrician',
#  'employee',
#  'employment',
#  'engineer',
#  'entrepreneur',
#  'executive',
#  'farmer',
#  'firefighter',
#  'fireman',
#  'football player',
#  'foster parent',
#  'gambler',
#  'grocer',
#  'groom',
#  'guard',
#  'guitarist',
#  'hairdresser',
#  'handball player',
#  'handyman',
#  'historian',
#  'hostess',
#  'housekeeper',
#  'illustrator',
#  'inspector',
#  'janitor',
#  'journalist',
#  'judge',
#  'laborer',
#  'landlord',
#  'lawn mower',
#  'lawyer',
#  'librarian',
#  'lifeguard',
#  'linguist',
#  'magician',
#  'manager',
#  'mathematician',
#  'mechanic',
#  'medical student',
#  'model',
#  'mover',
#  'musician',
#  'nurse',
#  'office worker',
#  'opera singer',
#  'painter',
#  'pensioner',
#  'performing artist',
#  'pharmacist',
#  'photographer',
#  'physician',
#  'physicist',
#  'pianist',
#  'pilot',
#  'plumber',
#  'poet',
#  'police officer',
#  'politician',
#  'postman',
#  'producer',
#  'professor',
#  'prosecutor',
#  'psychologist',
#  'radiologist',
#  'realtor',
#  'receptionist',
#  'researcher',
#  'salesperson',
#  'scientist',
#  'secretary',
#  'security guard',
#  'servant',
#  'sheriff',
#  'singer',
#  'sociologist',
#  'software engineer',
#  'soldier',
#  'supervisor',
#  'surgeon',
#  'swimmer',
#  'tailor',
#  'teacher',
#  'tennis player',
#  'theologian',
#  'umpire']

# %%
occurence, sentence = count_entity(gomu_occupations, mnli_data)

# %%
occupation_mnli_occurence = sorted(occurence.items(), key=(lambda x:x[1]), reverse=True)
json.dump(occupation_mnli_occurence, open("occupation_mnli_occurence.json", 'w'))
with open("occupation_mnli_sentence.txt", 'w') as f:
    for sent in sentence:
        f.write(f"{sent}\n")

# %%
occupation_mnli_occurence
# Out:
# [('actor', 2631),
#  ('author', 2442),
#  ('arts', 2203),
#  ('model', 2101),
#  ('employee', 1970),
#  ('lawyer', 1868),
#  ('executive', 1511),
#  ('civil', 1500),
#  ('architect', 1453),
#  ('delivery', 1342),
#  ('manager', 1228),
#  ('artist', 1167),
#  ('judge', 993),
#  ('auditor', 979),
#  ('doctor', 930),
#  ('cook', 921),
#  ('guard', 908),
#  ('director', 903),
#  ('engineer', 828),
#  ('editor', 707),
#  ('employment', 687),
#  ('army', 643),
#  ('teacher', 630),
#  ('soldier', 544),
#  ('chief', 497),
#  ('agent', 465),
#  ('politician', 458),
#  ('driver', 439),
#  ('poet', 412),
#  ('economist', 371),
#  ('professor', 360),
#  ('farmer', 348),
#  ('journalist', 338),
#  ('nurse', 327),
#  ('dealer', 322),
#  ('physician', 312),
#  ('CEO', 300),
#  ('researcher', 293),
#  ('painter', 291),
#  ('coach', 288),
#  ('airman', 279),
#  ('academic', 278),
#  ('singer', 269),
#  ('historian', 257),
#  ('pilot', 241),
#  ('grocer', 227),
#  ('scientist', 213),
#  ('secretary', 207),
#  ('analyst', 201),
#  ('assistant', 196),
#  ('designer', 195),
#  ('administrator', 193),
#  ('servant', 191),
#  ('mechanic', 189),
#  ('supervisor', 186),
#  ('producer', 179),
#  ('prosecutor', 177),
#  ('tailor', 161),
#  ('musician', 150),
#  ('diplomat', 148),
#  ('landlord', 144),
#  ('chemist', 141),
#  ('detective', 132),
#  ('athlete', 127),
#  ('builder', 125),
#  ('baker', 118),
#  ('commander', 114),
#  ('dancer', 114),
#  ('entrepreneur', 114),
#  ('photographer', 114),
#  ('accountant', 101),
#  ('broker', 98),
#  ('drawer', 96),
#  ('cleaner', 90),
#  ('inspector', 89),
#  ('gambler', 88),
#  ('clerk', 85),
#  ('police officer', 82),
#  ('laborer', 78),
#  ('psychologist', 76),
#  ('composer', 72),
#  ('banker', 69),
#  ('surgeon', 69),
#  ('chef', 63),
#  ('attendant', 62),
#  ('mathematician', 57),
#  ('lawn mower', 56),
#  ('janitor', 54),
#  ('comedian', 53),
#  ('astronomer', 52),
#  ('butcher', 51),
#  ('dentist', 51),
#  ('linguist', 50),
#  ('counselor', 49),
#  ('groom', 46),
#  ('carpenter', 45),
#  ('swimmer', 45),
#  ('barber', 43),
#  ('butler', 42),
#  ('boxer', 40),
#  ('football player', 39),
#  ('plumber', 39),
#  ('magician', 37),
#  ('sociologist', 37),
#  ('firefighter', 26),
#  ('lifeguard', 26),
#  ('security guard', 26),
#  ('physicist', 25),
#  ('cleric', 24),
#  ('theologian', 24),
#  ('cashier', 19),
#  ('electrician', 17),
#  ('construction worker', 16),
#  ('bartender', 15),
#  ('hostess', 15),
#  ('sheriff', 15),
#  ('guitarist', 12),
#  ('librarian', 12),
#  ('medical student', 12),
#  ('mover', 12),
#  ('illustrator', 11),
#  ('pianist', 10),
#  ('pharmacist', 8),
#  ('fireman', 7),
#  ('housekeeper', 6),
#  ('receptionist', 6),
#  ('chess player', 5),
#  ('office worker', 5),
#  ('salesperson', 5),
#  ('tennis player', 5),
#  ('hairdresser', 4),
#  ('opera singer', 4),
#  ('software engineer', 4),
#  ('radiologist', 3),
#  ('handyman', 2),
#  ('postman', 2),
#  ('umpire', 1),
#  ('aeronautical engineer', 0),
#  ('attourney', 0),
#  ('businessperson', 0),
#  ('foster parent', 0),
#  ('handball player', 0),
#  ('pensioner', 0),
#  ('performing artist', 0),
#  ('realtor', 0)]

# %% [markdown]
# ### 2. Count occupation in SNLI

# %%
occurence, sentence = count_entity(gomu_occupations, snli_data)

# %%
occupation_snli_occurence = sorted(occurence.items(), key=(lambda x:x[1]), reverse=True)
json.dump(occupation_snli_occurence, open("occupation_snli_occurence.json", 'w'))
with open("occupation_snli_sentence.txt", 'w') as f:
    for sent in sentence:
        f.write(f"{sent}\n")

# %%
occupation_snli_occurence
# Out:
# [('cook', 4484),
#  ('construction worker', 2458),
#  ('arts', 2321),
#  ('musician', 2189),
#  ('football player', 1802),
#  ('dancer', 1516),
#  ('artist', 1507),
#  ('grocer', 1462),
#  ('actor', 1310),
#  ('photographer', 1215),
#  ('guard', 1054),
#  ('singer', 1043),
#  ('athlete', 1019),
#  ('chef', 1019),
#  ('police officer', 1001),
#  ('soldier', 968),
#  ('driver', 877),
#  ('groom', 844),
#  ('teacher', 817),
#  ('tennis player', 801),
#  ('model', 790),
#  ('swimmer', 761),
#  ('guitarist', 679),
#  ('doctor', 657),
#  ('farmer', 647),
#  ('firefighter', 527),
#  ('employee', 505),
#  ('coach', 452),
#  ('army', 448),
#  ('nurse', 374),
#  ('barber', 360),
#  ('mechanic', 341),
#  ('boxer', 338),
#  ('fireman', 298),
#  ('scientist', 284),
#  ('baker', 283),
#  ('pilot', 267),
#  ('auditor', 266),
#  ('butcher', 263),
#  ('painter', 248),
#  ('umpire', 223),
#  ('judge', 205),
#  ('security guard', 186),
#  ('cleaner', 182),
#  ('chief', 181),
#  ('bartender', 180),
#  ('architect', 162),
#  ('dentist', 160),
#  ('lawn mower', 158),
#  ('civil', 149),
#  ('professor', 144),
#  ('janitor', 143),
#  ('cashier', 142),
#  ('surgeon', 137),
#  ('delivery', 125),
#  ('agent', 118),
#  ('clerk', 109),
#  ('attendant', 106),
#  ('author', 98),
#  ('magician', 98),
#  ('lifeguard', 97),
#  ('director', 96),
#  ('dealer', 88),
#  ('carpenter', 77),
#  ('designer', 74),
#  ('manager', 73),
#  ('chemist', 69),
#  ('engineer', 69),
#  ('assistant', 68),
#  ('office worker', 63),
#  ('airman', 62),
#  ('comedian', 57),
#  ('drawer', 56),
#  ('lawyer', 55),
#  ('librarian', 53),
#  ('laborer', 52),
#  ('politician', 52),
#  ('executive', 51),
#  ('electrician', 49),
#  ('pianist', 49),
#  ('inspector', 42),
#  ('supervisor', 41),
#  ('builder', 40),
#  ('poet', 38),
#  ('plumber', 32),
#  ('tailor', 32),
#  ('mover', 31),
#  ('hairdresser', 27),
#  ('researcher', 27),
#  ('hostess', 23),
#  ('employment', 21),
#  ('CEO', 20),
#  ('astronomer', 19),
#  ('pharmacist', 19),
#  ('realtor', 19),
#  ('journalist', 17),
#  ('detective', 16),
#  ('accountant', 13),
#  ('salesperson', 13),
#  ('servant', 13),
#  ('sheriff', 13),
#  ('broker', 11),
#  ('secretary', 11),
#  ('receptionist', 10),
#  ('banker', 9),
#  ('chess player', 9),
#  ('postman', 9),
#  ('opera singer', 8),
#  ('entrepreneur', 7),
#  ('academic', 6),
#  ('cleric', 6),
#  ('handyman', 6),
#  ('medical student', 6),
#  ('counselor', 5),
#  ('editor', 5),
#  ('producer', 5),
#  ('butler', 4),
#  ('commander', 4),
#  ('handball player', 4),
#  ('housekeeper', 4),
#  ('physician', 4),
#  ('administrator', 3),
#  ('analyst', 3),
#  ('gambler', 3),
#  ('historian', 3),
#  ('psychologist', 3),
#  ('composer', 2),
#  ('pensioner', 2),
#  ('businessperson', 1),
#  ('diplomat', 1),
#  ('foster parent', 1),
#  ('landlord', 1),
#  ('performing artist', 1),
#  ('physicist', 1),
#  ('prosecutor', 1),
#  ('aeronautical engineer', 0),
#  ('attourney', 0),
#  ('economist', 0),
#  ('illustrator', 0),
#  ('linguist', 0),
#  ('mathematician', 0),
#  ('radiologist', 0),
#  ('sociologist', 0),
#  ('software engineer', 0),
#  ('theologian', 0)]

# %% [markdown]
# ### 3. Count occupation in MNLI + SNLI

# %%
nli_data = mnli_data + snli_data
len(nli_data)
# Out:
# 942854

# %%
occurence, sentence = count_entity(gomu_occupations, nli_data)

# %%
occupation_occurence = sorted(occurence.items(), key=(lambda x:x[1]), reverse=True)
json.dump(occupation_occurence, open("occupation_occurence.json", 'w'))
with open("occupation_sentence.txt", 'w') as f:
    for sent in sentence:
        f.write(f"{sent}\n")

# %%
pd.DataFrame(occupation_occurence)
# Out:
#                          0     1
# 0    cook                   5405
# 1    arts                   4524
# 2    actor                  3941
# 3    model                  2891
# 4    artist                 2674
# 5    author                 2540
# 6    employee               2475
# 7    construction worker    2474
# 8    musician               2339
# 9    guard                  1962
# 10   lawyer                 1923
# 11   football player        1841
# 12   grocer                 1689
# 13   civil                  1649
# 14   dancer                 1630
# 15   architect              1615
# 16   doctor                 1587
# 17   executive              1562
# 18   soldier                1512
# 19   delivery               1467
# 20   teacher                1447
# 21   photographer           1329
# 22   driver                 1316
# 23   singer                 1312
# 24   manager                1301
# 25   auditor                1245
# 26   judge                  1198
# 27   athlete                1146
# 28   army                   1091
# 29   police officer         1083
# 30   chef                   1082
# 31   director               999
# 32   farmer                 995
# 33   engineer               897
# 34   groom                  890
# 35   swimmer                806
# 36   tennis player          806
# 37   coach                  740
# 38   editor                 712
# 39   employment             708
# 40   nurse                  701
# 41   guitarist              691
# 42   chief                  678
# 43   agent                  583
# 44   firefighter            553
# 45   painter                539
# 46   mechanic               530
# 47   politician             510
# 48   pilot                  508
# 49   professor              504
# 50   scientist              497
# 51   poet                   450
# 52   dealer                 410
# 53   barber                 403
# 54   baker                  401
# 55   boxer                  378
# 56   economist              371
# 57   journalist             355
# 58   airman                 341
# 59   CEO                    320
# 60   researcher             320
# 61   physician              316
# 62   butcher                314
# 63   fireman                305
# 64   academic               284
# 65   cleaner                272
# 66   designer               269
# 67   assistant              264
# 68   historian              260
# 69   supervisor             227
# 70   umpire                 224
# 71   secretary              218
# 72   lawn mower             214
# 73   security guard         212
# 74   dentist                211
# 75   chemist                210
# 76   surgeon                206
# 77   analyst                204
# 78   servant                204
# 79   janitor                197
# 80   administrator          196
# 81   bartender              195
# 82   clerk                  194
# 83   tailor                 193
# 84   producer               184
# 85   prosecutor             178
# 86   attendant              168
# 87   builder                165
# 88   cashier                161
# 89   drawer                 152
# 90   diplomat               149
# 91   detective              148
# 92   landlord               145
# 93   magician               135
# 94   inspector              131
# 95   laborer                130
# 96   lifeguard              123
# 97   carpenter              122
# 98   entrepreneur           121
# 99   commander              118
# 100  accountant             114
# 101  comedian               110
# 102  broker                 109
# 103  gambler                91
# 104  psychologist           79
# 105  banker                 78
# 106  composer               74
# 107  astronomer             71
# 108  plumber                71
# 109  office worker          68
# 110  electrician            66
# 111  librarian              65
# 112  pianist                59
# 113  mathematician          57
# 114  counselor              54
# 115  linguist               50
# 116  butler                 46
# 117  mover                  43
# 118  hostess                38
# 119  sociologist            37
# 120  hairdresser            31
# 121  cleric                 30
# 122  sheriff                28
# 123  pharmacist             27
# 124  physicist              26
# 125  theologian             24
# 126  realtor                19
# 127  medical student        18
# 128  salesperson            18
# 129  receptionist           16
# 130  chess player           14
# 131  opera singer           12
# 132  illustrator            11
# 133  postman                11
# 134  housekeeper            10
# 135  handyman               8
# 136  handball player        4
# 137  software engineer      4
# 138  radiologist            3
# 139  pensioner              2
# 140  businessperson         1
# 141  foster parent          1
# 142  performing artist      1
# 143  aeronautical engineer  0
# 144  attourney              0

# %% [markdown]
# # New occupations in NLI dataset

# %%
def count_occupation(data, occupations):
    sents = []
    occs = {}
    for d in data:
        for o in occupations:
            if o in d:
                sents.append(d)
                occs[o] = occs.get(o, 0) + 1
    return occs, sents

# %%
occupation_mnli_count, occupations_mnli_sent = count_occupation(mnli_data, total_occupations)
occupation_snli_count, occupations_snli_sent = count_occupation(mnli_data, total_occupations)

# %%
occupation_mnli_count = sorted(occupation_mnli_count.items(), key=(lambda x:x[1]), reverse=True)
json.dump(occupation_mnli_count, open("new_mnli_occupation.json", 'w'))
with open("new_mnli_occupation_sent.txt", 'w') as f:
    for sent in sentence:
        f.write(f"{sent}\n")

# %%
occupation_snli_count = sorted(occupation_snli_count.items(), key=(lambda x:x[1]), reverse=True)
json.dump(occupation_snli_count, open("new_snli_occupation.json", 'w'))
with open("new_snli_occupation_sent.txt", 'w') as f:
    for sent in sentence:
        f.write(f"{sent}\n")
