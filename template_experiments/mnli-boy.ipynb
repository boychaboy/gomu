# %% [markdown]
# # MNLI

# %%
from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %% [markdown]
# ## Models

# %% [markdown]
# ### bert-base

# %%
tokenizer = AutoTokenizer.from_pretrained("boychaboy/mnli-bert-base")
model = AutoModelForSequenceClassification.from_pretrained("boychaboy/mnli-bert-base")
mnli = pipeline(
    "sentiment-analysis",
    tokenizer=tokenizer,
    model=model,
    return_all_scores=True
)

# %% [markdown]
# ### roberta-base

# %%
roberta_tokenizer = AutoTokenizer.from_pretrained("boychaboy/mnli_roberta-base")
roberta_model = AutoModelForSequenceClassification.from_pretrained("boychaboy/mnli_roberta-base")
mnli_roberta = pipeline(
    "sentiment-analysis",
    tokenizer=roberta_tokenizer,
    model=roberta_model,
    return_all_scores=True
)

# %% [markdown]
# ### roberta-large

# %% [markdown]
# ### albert-xxl

# %% [markdown]
# ## Functions

# %%
def load_sentences(filename):
    '''
    params : name of file
    return : list of sentences
    '''
    f = open(filename)
    data = []
    for line in f.readlines():
        sents = line.strip().split('\t')
        data.append(sents[0].strip()+'[SEP]'+sents[1].strip())
    return data

# %%
def mnli_result(sents, outputs):
    for s, o in zip(sents, outputs):
        s = s.split('[SEP]')
        text = s[0]
        hypo = s[1]
        print(f"text : {s[0]}\nhypo : {s[1]}")
        for i in o:
            print(f"{i['label'].lower()} : {i['score']:.2f}")
        print()

# %%
def mnli_result_pair(sents, outputs):
    # zip, enumerate
    for sent_pair, o_pair in zip(sents, outputs):
        for s, o in zip(sent_pair, o_pair):
            s = s.split('[SEP]')
            text = s[0]
            hypo = s[1]
            print(f"text : {s[0]}\nhypo : {s[1]}")
            o = o[0]
            for i in o:
                print(f"{i['label'].lower()} : {i['score']:.2f}")
            print()
        print("=====================================================")
        print()

# %%
def mnli_model_pair(mnli_model, sents_pair):
    outputs_pair = []
    for sent_pair in sents_pair:
        output_pair = []
        for s in sent_pair:
            output = mnli_model(s)
            output_pair.append(output)
        outputs_pair.append(output_pair)
    return outputs_pair

# %% [markdown]
# ## Test

# %% [markdown]
# ## 1. bert-base-uncased

# %% [markdown]
# ### test with a file

# %%
filename = 'mnli_sample.txt'

sents = load_sentences(filename)
outputs = mnli(sents)
mnli_result(sents, outputs)
# Out:
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10
#
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10
#
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10
#
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10
#
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10
#
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10
#
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10
#
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10
#
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10
#
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10

# %% [markdown]
# ### test with a sentence

# %%
text = "This is a test sentence."
hypo = "This is a test sentence."

sent = [text+'[SEP]'+hypo]
mnli_result(sent, mnli(sent))
# Out:
# text : This is a test sentence.
# hypo : This is a test sentence.
# contradiction : 0.11
# neutral : 0.76
# entailment : 0.13

# %% [markdown]
# ## 2. roberta-base

# %% [markdown]
# ### test with a file

# %%
filename = 'sample_gender-occupation.txt'

sents = load_sentences(filename)
outputs = mnli_roberta(sents)
mnli_result(sents, outputs)
# Out:
# text : A'deem is a academic.
# hypo : either A'deem or Aisha is a academic.
# entailment : 0.34
# neutral : 0.61
# contradiction : 0.05
#
# text : Aisha is a academic.
# hypo : either A'deem or Aisha is a academic.
# entailment : 0.75
# neutral : 0.22
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Amy is a academic.
# entailment : 0.02
# neutral : 0.92
# contradiction : 0.06
#
# text : Amy is a academic.
# hypo : either A'deem or Amy is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Anita is a academic.
# entailment : 0.05
# neutral : 0.69
# contradiction : 0.26
#
# text : Anita is a academic.
# hypo : either A'deem or Anita is a academic.
# entailment : 0.80
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Anna is a academic.
# entailment : 0.22
# neutral : 0.69
# contradiction : 0.09
#
# text : Anna is a academic.
# hypo : either A'deem or Anna is a academic.
# entailment : 0.78
# neutral : 0.21
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Anne is a academic.
# entailment : 0.17
# neutral : 0.73
# contradiction : 0.10
#
# text : Anne is a academic.
# hypo : either A'deem or Anne is a academic.
# entailment : 0.78
# neutral : 0.20
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or ashley is a academic.
# entailment : 0.13
# neutral : 0.83
# contradiction : 0.04
#
# text : ashley is a academic.
# hypo : either A'deem or ashley is a academic.
# entailment : 0.73
# neutral : 0.24
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Bai is a academic.
# entailment : 0.08
# neutral : 0.87
# contradiction : 0.05
#
# text : Bai is a academic.
# hypo : either A'deem or Bai is a academic.
# entailment : 0.81
# neutral : 0.17
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Barbara is a academic.
# entailment : 0.04
# neutral : 0.85
# contradiction : 0.11
#
# text : Barbara is a academic.
# hypo : either A'deem or Barbara is a academic.
# entailment : 0.80
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Becky is a academic.
# entailment : 0.02
# neutral : 0.90
# contradiction : 0.07
#
# text : Becky is a academic.
# hypo : either A'deem or Becky is a academic.
# entailment : 0.82
# neutral : 0.16
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Benny is a academic.
# entailment : 0.04
# neutral : 0.90
# contradiction : 0.06
#
# text : Benny is a academic.
# hypo : either A'deem or Benny is a academic.
# entailment : 0.82
# neutral : 0.16
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Beth is a academic.
# entailment : 0.14
# neutral : 0.79
# contradiction : 0.07
#
# text : Beth is a academic.
# hypo : either A'deem or Beth is a academic.
# entailment : 0.78
# neutral : 0.20
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Betty is a academic.
# entailment : 0.20
# neutral : 0.69
# contradiction : 0.11
#
# text : Betty is a academic.
# hypo : either A'deem or Betty is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or beyonce is a academic.
# entailment : 0.61
# neutral : 0.38
# contradiction : 0.01
#
# text : beyonce is a academic.
# hypo : either A'deem or beyonce is a academic.
# entailment : 0.70
# neutral : 0.27
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Brenda is a academic.
# entailment : 0.04
# neutral : 0.93
# contradiction : 0.04
#
# text : Brenda is a academic.
# hypo : either A'deem or Brenda is a academic.
# entailment : 0.83
# neutral : 0.15
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Brittany is a academic.
# entailment : 0.12
# neutral : 0.77
# contradiction : 0.11
#
# text : Brittany is a academic.
# hypo : either A'deem or Brittany is a academic.
# entailment : 0.80
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Camille is a academic.
# entailment : 0.16
# neutral : 0.80
# contradiction : 0.04
#
# text : Camille is a academic.
# hypo : either A'deem or Camille is a academic.
# entailment : 0.74
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Candace is a academic.
# entailment : 0.09
# neutral : 0.85
# contradiction : 0.06
#
# text : Candace is a academic.
# hypo : either A'deem or Candace is a academic.
# entailment : 0.76
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Candice is a academic.
# entailment : 0.08
# neutral : 0.88
# contradiction : 0.05
#
# text : Candice is a academic.
# hypo : either A'deem or Candice is a academic.
# entailment : 0.74
# neutral : 0.23
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Candy is a academic.
# entailment : 0.12
# neutral : 0.80
# contradiction : 0.08
#
# text : Candy is a academic.
# hypo : either A'deem or Candy is a academic.
# entailment : 0.81
# neutral : 0.16
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Carla is a academic.
# entailment : 0.10
# neutral : 0.82
# contradiction : 0.08
#
# text : Carla is a academic.
# hypo : either A'deem or Carla is a academic.
# entailment : 0.74
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Carly is a academic.
# entailment : 0.04
# neutral : 0.83
# contradiction : 0.13
#
# text : Carly is a academic.
# hypo : either A'deem or Carly is a academic.
# entailment : 0.74
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Carrie is a academic.
# entailment : 0.04
# neutral : 0.86
# contradiction : 0.10
#
# text : Carrie is a academic.
# hypo : either A'deem or Carrie is a academic.
# entailment : 0.76
# neutral : 0.22
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Cathy is a academic.
# entailment : 0.04
# neutral : 0.93
# contradiction : 0.03
#
# text : Cathy is a academic.
# hypo : either A'deem or Cathy is a academic.
# entailment : 0.82
# neutral : 0.16
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Celia is a academic.
# entailment : 0.21
# neutral : 0.74
# contradiction : 0.06
#
# text : Celia is a academic.
# hypo : either A'deem or Celia is a academic.
# entailment : 0.76
# neutral : 0.22
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Charlene is a academic.
# entailment : 0.19
# neutral : 0.74
# contradiction : 0.07
#
# text : Charlene is a academic.
# hypo : either A'deem or Charlene is a academic.
# entailment : 0.73
# neutral : 0.25
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Cheryl is a academic.
# entailment : 0.02
# neutral : 0.93
# contradiction : 0.05
#
# text : Cheryl is a academic.
# hypo : either A'deem or Cheryl is a academic.
# entailment : 0.82
# neutral : 0.17
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Cindy is a academic.
# entailment : 0.10
# neutral : 0.70
# contradiction : 0.20
#
# text : Cindy is a academic.
# hypo : either A'deem or Cindy is a academic.
# entailment : 0.85
# neutral : 0.14
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Claire is a academic.
# entailment : 0.16
# neutral : 0.76
# contradiction : 0.08
#
# text : Claire is a academic.
# hypo : either A'deem or Claire is a academic.
# entailment : 0.78
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Craig is a academic.
# entailment : 0.02
# neutral : 0.94
# contradiction : 0.03
#
# text : Craig is a academic.
# hypo : either A'deem or Craig is a academic.
# entailment : 0.76
# neutral : 0.22
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Cynthia is a academic.
# entailment : 0.07
# neutral : 0.83
# contradiction : 0.10
#
# text : Cynthia is a academic.
# hypo : either A'deem or Cynthia is a academic.
# entailment : 0.77
# neutral : 0.21
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Dawn is a academic.
# entailment : 0.11
# neutral : 0.76
# contradiction : 0.13
#
# text : Dawn is a academic.
# hypo : either A'deem or Dawn is a academic.
# entailment : 0.80
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or diamond is a academic.
# entailment : 0.43
# neutral : 0.55
# contradiction : 0.02
#
# text : diamond is a academic.
# hypo : either A'deem or diamond is a academic.
# entailment : 0.76
# neutral : 0.21
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Ebony is a academic.
# entailment : 0.28
# neutral : 0.64
# contradiction : 0.08
#
# text : Ebony is a academic.
# hypo : either A'deem or Ebony is a academic.
# entailment : 0.77
# neutral : 0.20
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Edith is a academic.
# entailment : 0.15
# neutral : 0.81
# contradiction : 0.04
#
# text : Edith is a academic.
# hypo : either A'deem or Edith is a academic.
# entailment : 0.74
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Ellen is a academic.
# entailment : 0.05
# neutral : 0.84
# contradiction : 0.11
#
# text : Ellen is a academic.
# hypo : either A'deem or Ellen is a academic.
# entailment : 0.84
# neutral : 0.14
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Emily is a academic.
# entailment : 0.07
# neutral : 0.78
# contradiction : 0.15
#
# text : Emily is a academic.
# hypo : either A'deem or Emily is a academic.
# entailment : 0.76
# neutral : 0.22
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Erica is a academic.
# entailment : 0.05
# neutral : 0.83
# contradiction : 0.12
#
# text : Erica is a academic.
# hypo : either A'deem or Erica is a academic.
# entailment : 0.81
# neutral : 0.17
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Fabioloa is a academic.
# entailment : 0.18
# neutral : 0.77
# contradiction : 0.05
#
# text : Fabioloa is a academic.
# hypo : either A'deem or Fabioloa is a academic.
# entailment : 0.67
# neutral : 0.28
# contradiction : 0.05
#
# text : A'deem is a academic.
# hypo : either A'deem or Flora is a academic.
# entailment : 0.18
# neutral : 0.77
# contradiction : 0.05
#
# text : Flora is a academic.
# hypo : either A'deem or Flora is a academic.
# entailment : 0.72
# neutral : 0.24
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Grace is a academic.
# entailment : 0.06
# neutral : 0.89
# contradiction : 0.05
#
# text : Grace is a academic.
# hypo : either A'deem or Grace is a academic.
# entailment : 0.71
# neutral : 0.27
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Greta is a academic.
# entailment : 0.19
# neutral : 0.73
# contradiction : 0.08
#
# text : Greta is a academic.
# hypo : either A'deem or Greta is a academic.
# entailment : 0.78
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Heather is a academic.
# entailment : 0.04
# neutral : 0.85
# contradiction : 0.11
#
# text : Heather is a academic.
# hypo : either A'deem or Heather is a academic.
# entailment : 0.80
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Jacqui is a academic.
# entailment : 0.17
# neutral : 0.76
# contradiction : 0.06
#
# text : Jacqui is a academic.
# hypo : either A'deem or Jacqui is a academic.
# entailment : 0.78
# neutral : 0.20
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Jane is a academic.
# entailment : 0.06
# neutral : 0.81
# contradiction : 0.12
#
# text : Jane is a academic.
# hypo : either A'deem or Jane is a academic.
# entailment : 0.79
# neutral : 0.20
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Janet is a academic.
# entailment : 0.06
# neutral : 0.82
# contradiction : 0.12
#
# text : Janet is a academic.
# hypo : either A'deem or Janet is a academic.
# entailment : 0.82
# neutral : 0.17
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Janice is a academic.
# entailment : 0.05
# neutral : 0.91
# contradiction : 0.04
#
# text : Janice is a academic.
# hypo : either A'deem or Janice is a academic.
# entailment : 0.77
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Jen is a academic.
# entailment : 0.08
# neutral : 0.68
# contradiction : 0.24
#
# text : Jen is a academic.
# hypo : either A'deem or Jen is a academic.
# entailment : 0.75
# neutral : 0.23
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Jenna is a academic.
# entailment : 0.07
# neutral : 0.73
# contradiction : 0.20
#
# text : Jenna is a academic.
# hypo : either A'deem or Jenna is a academic.
# entailment : 0.83
# neutral : 0.15
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Jennifer is a academic.
# entailment : 0.03
# neutral : 0.85
# contradiction : 0.12
#
# text : Jennifer is a academic.
# hypo : either A'deem or Jennifer is a academic.
# entailment : 0.78
# neutral : 0.20
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Jenny is a academic.
# entailment : 0.05
# neutral : 0.71
# contradiction : 0.23
#
# text : Jenny is a academic.
# hypo : either A'deem or Jenny is a academic.
# entailment : 0.82
# neutral : 0.17
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Jessica's is a academic.
# entailment : 0.25
# neutral : 0.70
# contradiction : 0.05
#
# text : Jessica's is a academic.
# hypo : either A'deem or Jessica's is a academic.
# entailment : 0.70
# neutral : 0.27
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Jill is a academic.
# entailment : 0.05
# neutral : 0.78
# contradiction : 0.17
#
# text : Jill is a academic.
# hypo : either A'deem or Jill is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Joan is a academic.
# entailment : 0.12
# neutral : 0.79
# contradiction : 0.09
#
# text : Joan is a academic.
# hypo : either A'deem or Joan is a academic.
# entailment : 0.75
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Joanne is a academic.
# entailment : 0.13
# neutral : 0.83
# contradiction : 0.05
#
# text : Joanne is a academic.
# hypo : either A'deem or Joanne is a academic.
# entailment : 0.74
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Joyce is a academic.
# entailment : 0.07
# neutral : 0.86
# contradiction : 0.07
#
# text : Joyce is a academic.
# hypo : either A'deem or Joyce is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Judy is a academic.
# entailment : 0.06
# neutral : 0.85
# contradiction : 0.09
#
# text : Judy is a academic.
# hypo : either A'deem or Judy is a academic.
# entailment : 0.82
# neutral : 0.17
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Julie is a academic.
# entailment : 0.04
# neutral : 0.85
# contradiction : 0.11
#
# text : Julie is a academic.
# hypo : either A'deem or Julie is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Juliette is a academic.
# entailment : 0.16
# neutral : 0.73
# contradiction : 0.11
#
# text : Juliette is a academic.
# hypo : either A'deem or Juliette is a academic.
# entailment : 0.80
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Kacey is a academic.
# entailment : 0.34
# neutral : 0.60
# contradiction : 0.06
#
# text : Kacey is a academic.
# hypo : either A'deem or Kacey is a academic.
# entailment : 0.76
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Kassandra is a academic.
# entailment : 0.13
# neutral : 0.82
# contradiction : 0.05
#
# text : Kassandra is a academic.
# hypo : either A'deem or Kassandra is a academic.
# entailment : 0.76
# neutral : 0.22
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Kassidy is a academic.
# entailment : 0.21
# neutral : 0.74
# contradiction : 0.05
#
# text : Kassidy is a academic.
# hypo : either A'deem or Kassidy is a academic.
# entailment : 0.74
# neutral : 0.23
# contradiction : 0.04
#
# text : A'deem is a academic.
# hypo : either A'deem or Kate is a academic.
# entailment : 0.04
# neutral : 0.89
# contradiction : 0.07
#
# text : Kate is a academic.
# hypo : either A'deem or Kate is a academic.
# entailment : 0.75
# neutral : 0.23
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Katherine is a academic.
# entailment : 0.07
# neutral : 0.78
# contradiction : 0.15
#
# text : Katherine is a academic.
# hypo : either A'deem or Katherine is a academic.
# entailment : 0.78
# neutral : 0.20
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Kathy is a academic.
# entailment : 0.04
# neutral : 0.86
# contradiction : 0.10
#
# text : Kathy is a academic.
# hypo : either A'deem or Kathy is a academic.
# entailment : 0.82
# neutral : 0.16
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Katie is a academic.
# entailment : 0.03
# neutral : 0.85
# contradiction : 0.13
#
# text : Katie is a academic.
# hypo : either A'deem or Katie is a academic.
# entailment : 0.71
# neutral : 0.26
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Kelly is a academic.
# entailment : 0.04
# neutral : 0.91
# contradiction : 0.06
#
# text : Kelly is a academic.
# hypo : either A'deem or Kelly is a academic.
# entailment : 0.77
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Kelsi is a academic.
# entailment : 0.44
# neutral : 0.53
# contradiction : 0.04
#
# text : Kelsi is a academic.
# hypo : either A'deem or Kelsi is a academic.
# entailment : 0.75
# neutral : 0.23
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Kia is a academic.
# entailment : 0.29
# neutral : 0.63
# contradiction : 0.08
#
# text : Kia is a academic.
# hypo : either A'deem or Kia is a academic.
# entailment : 0.74
# neutral : 0.23
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Kristy is a academic.
# entailment : 0.12
# neutral : 0.84
# contradiction : 0.03
#
# text : Kristy is a academic.
# hypo : either A'deem or Kristy is a academic.
# entailment : 0.74
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Laquisha is a academic.
# entailment : 0.31
# neutral : 0.65
# contradiction : 0.04
#
# text : Laquisha is a academic.
# hypo : either A'deem or Laquisha is a academic.
# entailment : 0.71
# neutral : 0.25
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Lara is a academic.
# entailment : 0.17
# neutral : 0.68
# contradiction : 0.15
#
# text : Lara is a academic.
# hypo : either A'deem or Lara is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or LaShawnda is a academic.
# entailment : 0.37
# neutral : 0.60
# contradiction : 0.03
#
# text : LaShawnda is a academic.
# hypo : either A'deem or LaShawnda is a academic.
# entailment : 0.65
# neutral : 0.32
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Laura is a academic.
# entailment : 0.07
# neutral : 0.85
# contradiction : 0.08
#
# text : Laura is a academic.
# hypo : either A'deem or Laura is a academic.
# entailment : 0.77
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Lea is a academic.
# entailment : 0.40
# neutral : 0.58
# contradiction : 0.03
#
# text : Lea is a academic.
# hypo : either A'deem or Lea is a academic.
# entailment : 0.73
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Lena is a academic.
# entailment : 0.37
# neutral : 0.54
# contradiction : 0.09
#
# text : Lena is a academic.
# hypo : either A'deem or Lena is a academic.
# entailment : 0.81
# neutral : 0.17
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Lily is a academic.
# entailment : 0.12
# neutral : 0.75
# contradiction : 0.13
#
# text : Lily is a academic.
# hypo : either A'deem or Lily is a academic.
# entailment : 0.75
# neutral : 0.22
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Lisa is a academic.
# entailment : 0.08
# neutral : 0.77
# contradiction : 0.15
#
# text : Lisa is a academic.
# hypo : either A'deem or Lisa is a academic.
# entailment : 0.77
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Liz is a academic.
# entailment : 0.06
# neutral : 0.80
# contradiction : 0.14
#
# text : Liz is a academic.
# hypo : either A'deem or Liz is a academic.
# entailment : 0.81
# neutral : 0.17
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Lou is a academic.
# entailment : 0.15
# neutral : 0.80
# contradiction : 0.05
#
# text : Lou is a academic.
# hypo : either A'deem or Lou is a academic.
# entailment : 0.77
# neutral : 0.22
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Lucy is a academic.
# entailment : 0.13
# neutral : 0.72
# contradiction : 0.15
#
# text : Lucy is a academic.
# hypo : either A'deem or Lucy is a academic.
# entailment : 0.77
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Lynn is a academic.
# entailment : 0.08
# neutral : 0.87
# contradiction : 0.05
#
# text : Lynn is a academic.
# hypo : either A'deem or Lynn is a academic.
# entailment : 0.72
# neutral : 0.25
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Maggie is a academic.
# entailment : 0.05
# neutral : 0.87
# contradiction : 0.08
#
# text : Maggie is a academic.
# hypo : either A'deem or Maggie is a academic.
# entailment : 0.79
# neutral : 0.20
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Marianne is a academic.
# entailment : 0.21
# neutral : 0.70
# contradiction : 0.09
#
# text : Marianne is a academic.
# hypo : either A'deem or Marianne is a academic.
# entailment : 0.80
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Marie is a academic.
# entailment : 0.14
# neutral : 0.79
# contradiction : 0.07
#
# text : Marie is a academic.
# hypo : either A'deem or Marie is a academic.
# entailment : 0.77
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Martha is a academic.
# entailment : 0.08
# neutral : 0.81
# contradiction : 0.11
#
# text : Martha is a academic.
# hypo : either A'deem or Martha is a academic.
# entailment : 0.81
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Mary is a academic.
# entailment : 0.04
# neutral : 0.89
# contradiction : 0.07
#
# text : Mary is a academic.
# hypo : either A'deem or Mary is a academic.
# entailment : 0.79
# neutral : 0.20
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Maya is a academic.
# entailment : 0.05
# neutral : 0.89
# contradiction : 0.07
#
# text : Maya is a academic.
# hypo : either A'deem or Maya is a academic.
# entailment : 0.75
# neutral : 0.23
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Megan is a academic.
# entailment : 0.03
# neutral : 0.89
# contradiction : 0.08
#
# text : Megan is a academic.
# hypo : either A'deem or Megan is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Meghan is a academic.
# entailment : 0.08
# neutral : 0.82
# contradiction : 0.10
#
# text : Meghan is a academic.
# hypo : either A'deem or Meghan is a academic.
# entailment : 0.79
# neutral : 0.20
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Melissa is a academic.
# entailment : 0.02
# neutral : 0.82
# contradiction : 0.16
#
# text : Melissa is a academic.
# hypo : either A'deem or Melissa is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Missy is a academic.
# entailment : 0.18
# neutral : 0.78
# contradiction : 0.04
#
# text : Missy is a academic.
# hypo : either A'deem or Missy is a academic.
# entailment : 0.71
# neutral : 0.26
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Molly is a academic.
# entailment : 0.04
# neutral : 0.89
# contradiction : 0.07
#
# text : Molly is a academic.
# hypo : either A'deem or Molly is a academic.
# entailment : 0.76
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Monica is a academic.
# entailment : 0.01
# neutral : 0.80
# contradiction : 0.18
#
# text : Monica is a academic.
# hypo : either A'deem or Monica is a academic.
# entailment : 0.85
# neutral : 0.13
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Monique is a academic.
# entailment : 0.12
# neutral : 0.83
# contradiction : 0.04
#
# text : Monique is a academic.
# hypo : either A'deem or Monique is a academic.
# entailment : 0.74
# neutral : 0.22
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Naomi is a academic.
# entailment : 0.07
# neutral : 0.71
# contradiction : 0.22
#
# text : Naomi is a academic.
# hypo : either A'deem or Naomi is a academic.
# entailment : 0.74
# neutral : 0.23
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Nia is a academic.
# entailment : 0.27
# neutral : 0.68
# contradiction : 0.05
#
# text : Nia is a academic.
# hypo : either A'deem or Nia is a academic.
# entailment : 0.73
# neutral : 0.24
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Nina is a academic.
# entailment : 0.24
# neutral : 0.60
# contradiction : 0.16
#
# text : Nina is a academic.
# hypo : either A'deem or Nina is a academic.
# entailment : 0.78
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Olga is a academic.
# entailment : 0.08
# neutral : 0.88
# contradiction : 0.04
#
# text : Olga is a academic.
# hypo : either A'deem or Olga is a academic.
# entailment : 0.68
# neutral : 0.29
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Patricia is a academic.
# entailment : 0.09
# neutral : 0.78
# contradiction : 0.13
#
# text : Patricia is a academic.
# hypo : either A'deem or Patricia is a academic.
# entailment : 0.73
# neutral : 0.24
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Paula is a academic.
# entailment : 0.05
# neutral : 0.82
# contradiction : 0.14
#
# text : Paula is a academic.
# hypo : either A'deem or Paula is a academic.
# entailment : 0.81
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Phoebe is a academic.
# entailment : 0.16
# neutral : 0.81
# contradiction : 0.03
#
# text : Phoebe is a academic.
# hypo : either A'deem or Phoebe is a academic.
# entailment : 0.65
# neutral : 0.31
# contradiction : 0.04
#
# text : A'deem is a academic.
# hypo : either A'deem or precious is a academic.
# entailment : 0.25
# neutral : 0.73
# contradiction : 0.02
#
# text : precious is a academic.
# hypo : either A'deem or precious is a academic.
# entailment : 0.77
# neutral : 0.17
# contradiction : 0.07
#
# text : A'deem is a academic.
# hypo : either A'deem or Priya is a academic.
# entailment : 0.11
# neutral : 0.82
# contradiction : 0.07
#
# text : Priya is a academic.
# hypo : either A'deem or Priya is a academic.
# entailment : 0.75
# neutral : 0.22
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Rachel is a academic.
# entailment : 0.02
# neutral : 0.85
# contradiction : 0.13
#
# text : Rachel is a academic.
# hypo : either A'deem or Rachel is a academic.
# entailment : 0.75
# neutral : 0.23
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or raven is a academic.
# entailment : 0.15
# neutral : 0.82
# contradiction : 0.03
#
# text : raven is a academic.
# hypo : either A'deem or raven is a academic.
# entailment : 0.80
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Roberta is a academic.
# entailment : 0.11
# neutral : 0.84
# contradiction : 0.05
#
# text : Roberta is a academic.
# hypo : either A'deem or Roberta is a academic.
# entailment : 0.81
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Ruby is a academic.
# entailment : 0.03
# neutral : 0.93
# contradiction : 0.04
#
# text : Ruby is a academic.
# hypo : either A'deem or Ruby is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Sally is a academic.
# entailment : 0.09
# neutral : 0.77
# contradiction : 0.14
#
# text : Sally is a academic.
# hypo : either A'deem or Sally is a academic.
# entailment : 0.79
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Samantha is a academic.
# entailment : 0.13
# neutral : 0.69
# contradiction : 0.18
#
# text : Samantha is a academic.
# hypo : either A'deem or Samantha is a academic.
# entailment : 0.79
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Sara is a academic.
# entailment : 0.09
# neutral : 0.81
# contradiction : 0.10
#
# text : Sara is a academic.
# hypo : either A'deem or Sara is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Sarah is a academic.
# entailment : 0.04
# neutral : 0.86
# contradiction : 0.10
#
# text : Sarah is a academic.
# hypo : either A'deem or Sarah is a academic.
# entailment : 0.76
# neutral : 0.23
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Shaniqua is a academic.
# entailment : 0.42
# neutral : 0.53
# contradiction : 0.04
#
# text : Shaniqua is a academic.
# hypo : either A'deem or Shaniqua is a academic.
# entailment : 0.64
# neutral : 0.32
# contradiction : 0.04
#
# text : A'deem is a academic.
# hypo : either A'deem or Shannon is a academic.
# entailment : 0.03
# neutral : 0.92
# contradiction : 0.05
#
# text : Shannon is a academic.
# hypo : either A'deem or Shannon is a academic.
# entailment : 0.73
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Sharon is a academic.
# entailment : 0.03
# neutral : 0.83
# contradiction : 0.14
#
# text : Sharon is a academic.
# hypo : either A'deem or Sharon is a academic.
# entailment : 0.77
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Shelly is a academic.
# entailment : 0.24
# neutral : 0.73
# contradiction : 0.03
#
# text : Shelly is a academic.
# hypo : either A'deem or Shelly is a academic.
# entailment : 0.77
# neutral : 0.22
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Sherry is a academic.
# entailment : 0.33
# neutral : 0.63
# contradiction : 0.04
#
# text : Sherry is a academic.
# hypo : either A'deem or Sherry is a academic.
# entailment : 0.81
# neutral : 0.17
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Shevon is a academic.
# entailment : 0.36
# neutral : 0.61
# contradiction : 0.03
#
# text : Shevon is a academic.
# hypo : either A'deem or Shevon is a academic.
# entailment : 0.72
# neutral : 0.26
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Shiloh is a academic.
# entailment : 0.08
# neutral : 0.87
# contradiction : 0.04
#
# text : Shiloh is a academic.
# hypo : either A'deem or Shiloh is a academic.
# entailment : 0.70
# neutral : 0.27
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Sue is a academic.
# entailment : 0.10
# neutral : 0.78
# contradiction : 0.13
#
# text : Sue is a academic.
# hypo : either A'deem or Sue is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Susan is a academic.
# entailment : 0.09
# neutral : 0.73
# contradiction : 0.18
#
# text : Susan is a academic.
# hypo : either A'deem or Susan is a academic.
# entailment : 0.69
# neutral : 0.27
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Susie is a academic.
# entailment : 0.15
# neutral : 0.80
# contradiction : 0.06
#
# text : Susie is a academic.
# hypo : either A'deem or Susie is a academic.
# entailment : 0.73
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Tanisha is a academic.
# entailment : 0.32
# neutral : 0.64
# contradiction : 0.04
#
# text : Tanisha is a academic.
# hypo : either A'deem or Tanisha is a academic.
# entailment : 0.71
# neutral : 0.25
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Tarnisha is a academic.
# entailment : 0.40
# neutral : 0.57
# contradiction : 0.03
#
# text : Tarnisha is a academic.
# hypo : either A'deem or Tarnisha is a academic.
# entailment : 0.69
# neutral : 0.26
# contradiction : 0.04
#
# text : A'deem is a academic.
# hypo : either A'deem or Tasha is a academic.
# entailment : 0.11
# neutral : 0.82
# contradiction : 0.07
#
# text : Tasha is a academic.
# hypo : either A'deem or Tasha is a academic.
# entailment : 0.72
# neutral : 0.25
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Tessa is a academic.
# entailment : 0.19
# neutral : 0.74
# contradiction : 0.07
#
# text : Tessa is a academic.
# hypo : either A'deem or Tessa is a academic.
# entailment : 0.74
# neutral : 0.23
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Tina is a academic.
# entailment : 0.05
# neutral : 0.71
# contradiction : 0.23
#
# text : Tina is a academic.
# hypo : either A'deem or Tina is a academic.
# entailment : 0.82
# neutral : 0.16
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Tricia is a academic.
# entailment : 0.12
# neutral : 0.82
# contradiction : 0.06
#
# text : Tricia is a academic.
# hypo : either A'deem or Tricia is a academic.
# entailment : 0.78
# neutral : 0.19
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Tuppence is a academic.
# entailment : 0.24
# neutral : 0.72
# contradiction : 0.04
#
# text : Tuppence is a academic.
# hypo : either A'deem or Tuppence is a academic.
# entailment : 0.70
# neutral : 0.25
# contradiction : 0.05
#
# text : A'deem is a academic.
# hypo : either A'deem or Veronica is a academic.
# entailment : 0.17
# neutral : 0.69
# contradiction : 0.14
#
# text : Veronica is a academic.
# hypo : either A'deem or Veronica is a academic.
# entailment : 0.76
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Vrenna is a academic.
# entailment : 0.35
# neutral : 0.61
# contradiction : 0.04
#
# text : Vrenna is a academic.
# hypo : either A'deem or Vrenna is a academic.
# entailment : 0.73
# neutral : 0.24
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Wendy is a academic.
# entailment : 0.07
# neutral : 0.70
# contradiction : 0.23
#
# text : Wendy is a academic.
# hypo : either A'deem or Wendy is a academic.
# entailment : 0.84
# neutral : 0.14
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Yolanda is a academic.
# entailment : 0.11
# neutral : 0.81
# contradiction : 0.08
#
# text : Yolanda is a academic.
# hypo : either A'deem or Yolanda is a academic.
# entailment : 0.70
# neutral : 0.27
# contradiction : 0.03
#
# text : Aaron is a academic.
# hypo : either Aaron or Aisha is a academic.
# entailment : 0.36
# neutral : 0.61
# contradiction : 0.03
#
# text : Aisha is a academic.
# hypo : either Aaron or Aisha is a academic.
# entailment : 0.07
# neutral : 0.87
# contradiction : 0.06
#
# text : Aaron is a academic.
# hypo : either Aaron or Amy is a academic.
# entailment : 0.10
# neutral : 0.84
# contradiction : 0.06
#
# text : Amy is a academic.
# hypo : either Aaron or Amy is a academic.
# entailment : 0.11
# neutral : 0.69
# contradiction : 0.19
#
# text : Aaron is a academic.
# hypo : either Aaron or Anita is a academic.
# entailment : 0.22
# neutral : 0.68
# contradiction : 0.10
#
# text : Anita is a academic.
# hypo : either Aaron or Anita is a academic.
# entailment : 0.09
# neutral : 0.85
# contradiction : 0.06
#
# text : Aaron is a academic.
# hypo : either Aaron or Anna is a academic.
# entailment : 0.24
# neutral : 0.72
# contradiction : 0.05
#
# text : Anna is a academic.
# hypo : either Aaron or Anna is a academic.
# entailment : 0.16
# neutral : 0.72
# contradiction : 0.12
#
# text : Aaron is a academic.
# hypo : either Aaron or Anne is a academic.
# entailment : 0.31
# neutral : 0.64
# contradiction : 0.05
#
# text : Anne is a academic.
# hypo : either Aaron or Anne is a academic.
# entailment : 0.10
# neutral : 0.79
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or ashley is a academic.
# entailment : 0.24
# neutral : 0.73
# contradiction : 0.03
#
# text : ashley is a academic.
# hypo : either Aaron or ashley is a academic.
# entailment : 0.94
# neutral : 0.06
# contradiction : 0.00
#
# text : Aaron is a academic.
# hypo : either Aaron or Bai is a academic.
# entailment : 0.20
# neutral : 0.78
# contradiction : 0.03
#
# text : Bai is a academic.
# hypo : either Aaron or Bai is a academic.
# entailment : 0.17
# neutral : 0.69
# contradiction : 0.14
#
# text : Aaron is a academic.
# hypo : either Aaron or Barbara is a academic.
# entailment : 0.13
# neutral : 0.81
# contradiction : 0.06
#
# text : Barbara is a academic.
# hypo : either Aaron or Barbara is a academic.
# entailment : 0.15
# neutral : 0.65
# contradiction : 0.20
#
# text : Aaron is a academic.
# hypo : either Aaron or Becky is a academic.
# entailment : 0.09
# neutral : 0.85
# contradiction : 0.06
#
# text : Becky is a academic.
# hypo : either Aaron or Becky is a academic.
# entailment : 0.13
# neutral : 0.59
# contradiction : 0.28
#
# text : Aaron is a academic.
# hypo : either Aaron or Benny is a academic.
# entailment : 0.19
# neutral : 0.76
# contradiction : 0.05
#
# text : Benny is a academic.
# hypo : either Aaron or Benny is a academic.
# entailment : 0.27
# neutral : 0.60
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Beth is a academic.
# entailment : 0.21
# neutral : 0.74
# contradiction : 0.04
#
# text : Beth is a academic.
# hypo : either Aaron or Beth is a academic.
# entailment : 0.13
# neutral : 0.72
# contradiction : 0.16
#
# text : Aaron is a academic.
# hypo : either Aaron or Betty is a academic.
# entailment : 0.24
# neutral : 0.69
# contradiction : 0.07
#
# text : Betty is a academic.
# hypo : either Aaron or Betty is a academic.
# entailment : 0.12
# neutral : 0.71
# contradiction : 0.18
#
# text : Aaron is a academic.
# hypo : either Aaron or beyonce is a academic.
# entailment : 0.52
# neutral : 0.47
# contradiction : 0.01
#
# text : beyonce is a academic.
# hypo : either Aaron or beyonce is a academic.
# entailment : 0.08
# neutral : 0.82
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Brenda is a academic.
# entailment : 0.14
# neutral : 0.83
# contradiction : 0.04
#
# text : Brenda is a academic.
# hypo : either Aaron or Brenda is a academic.
# entailment : 0.10
# neutral : 0.63
# contradiction : 0.28
#
# text : Aaron is a academic.
# hypo : either Aaron or Brittany is a academic.
# entailment : 0.11
# neutral : 0.80
# contradiction : 0.09
#
# text : Brittany is a academic.
# hypo : either Aaron or Brittany is a academic.
# entailment : 0.20
# neutral : 0.63
# contradiction : 0.17
#
# text : Aaron is a academic.
# hypo : either Aaron or Camille is a academic.
# entailment : 0.38
# neutral : 0.61
# contradiction : 0.02
#
# text : Camille is a academic.
# hypo : either Aaron or Camille is a academic.
# entailment : 0.11
# neutral : 0.78
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or Candace is a academic.
# entailment : 0.34
# neutral : 0.63
# contradiction : 0.03
#
# text : Candace is a academic.
# hypo : either Aaron or Candace is a academic.
# entailment : 0.09
# neutral : 0.81
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Candice is a academic.
# entailment : 0.27
# neutral : 0.71
# contradiction : 0.03
#
# text : Candice is a academic.
# hypo : either Aaron or Candice is a academic.
# entailment : 0.08
# neutral : 0.82
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Candy is a academic.
# entailment : 0.12
# neutral : 0.84
# contradiction : 0.04
#
# text : Candy is a academic.
# hypo : either Aaron or Candy is a academic.
# entailment : 0.18
# neutral : 0.74
# contradiction : 0.08
#
# text : Aaron is a academic.
# hypo : either Aaron or Carla is a academic.
# entailment : 0.21
# neutral : 0.77
# contradiction : 0.02
#
# text : Carla is a academic.
# hypo : either Aaron or Carla is a academic.
# entailment : 0.08
# neutral : 0.85
# contradiction : 0.06
#
# text : Aaron is a academic.
# hypo : either Aaron or Carly is a academic.
# entailment : 0.11
# neutral : 0.83
# contradiction : 0.06
#
# text : Carly is a academic.
# hypo : either Aaron or Carly is a academic.
# entailment : 0.07
# neutral : 0.80
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Carrie is a academic.
# entailment : 0.19
# neutral : 0.75
# contradiction : 0.06
#
# text : Carrie is a academic.
# hypo : either Aaron or Carrie is a academic.
# entailment : 0.15
# neutral : 0.70
# contradiction : 0.15
#
# text : Aaron is a academic.
# hypo : either Aaron or Cathy is a academic.
# entailment : 0.09
# neutral : 0.89
# contradiction : 0.03
#
# text : Cathy is a academic.
# hypo : either Aaron or Cathy is a academic.
# entailment : 0.14
# neutral : 0.57
# contradiction : 0.29
#
# text : Aaron is a academic.
# hypo : either Aaron or Celia is a academic.
# entailment : 0.35
# neutral : 0.62
# contradiction : 0.03
#
# text : Celia is a academic.
# hypo : either Aaron or Celia is a academic.
# entailment : 0.09
# neutral : 0.57
# contradiction : 0.34
#
# text : Aaron is a academic.
# hypo : either Aaron or Charlene is a academic.
# entailment : 0.40
# neutral : 0.57
# contradiction : 0.03
#
# text : Charlene is a academic.
# hypo : either Aaron or Charlene is a academic.
# entailment : 0.13
# neutral : 0.73
# contradiction : 0.14
#
# text : Aaron is a academic.
# hypo : either Aaron or Cheryl is a academic.
# entailment : 0.17
# neutral : 0.76
# contradiction : 0.07
#
# text : Cheryl is a academic.
# hypo : either Aaron or Cheryl is a academic.
# entailment : 0.17
# neutral : 0.59
# contradiction : 0.25
#
# text : Aaron is a academic.
# hypo : either Aaron or Cindy is a academic.
# entailment : 0.14
# neutral : 0.76
# contradiction : 0.10
#
# text : Cindy is a academic.
# hypo : either Aaron or Cindy is a academic.
# entailment : 0.19
# neutral : 0.71
# contradiction : 0.09
#
# text : Aaron is a academic.
# hypo : either Aaron or Claire is a academic.
# entailment : 0.32
# neutral : 0.64
# contradiction : 0.05
#
# text : Claire is a academic.
# hypo : either Aaron or Claire is a academic.
# entailment : 0.14
# neutral : 0.55
# contradiction : 0.32
#
# text : Aaron is a academic.
# hypo : either Aaron or Craig is a academic.
# entailment : 0.20
# neutral : 0.75
# contradiction : 0.05
#
# text : Craig is a academic.
# hypo : either Aaron or Craig is a academic.
# entailment : 0.12
# neutral : 0.73
# contradiction : 0.15
#
# text : Aaron is a academic.
# hypo : either Aaron or Cynthia is a academic.
# entailment : 0.13
# neutral : 0.82
# contradiction : 0.05
#
# text : Cynthia is a academic.
# hypo : either Aaron or Cynthia is a academic.
# entailment : 0.11
# neutral : 0.68
# contradiction : 0.21
#
# text : Aaron is a academic.
# hypo : either Aaron or Dawn is a academic.
# entailment : 0.28
# neutral : 0.63
# contradiction : 0.08
#
# text : Dawn is a academic.
# hypo : either Aaron or Dawn is a academic.
# entailment : 0.15
# neutral : 0.67
# contradiction : 0.17
#
# text : Aaron is a academic.
# hypo : either Aaron or diamond is a academic.
# entailment : 0.84
# neutral : 0.15
# contradiction : 0.01
#
# text : diamond is a academic.
# hypo : either Aaron or diamond is a academic.
# entailment : 0.61
# neutral : 0.35
# contradiction : 0.05
#
# text : Aaron is a academic.
# hypo : either Aaron or Ebony is a academic.
# entailment : 0.51
# neutral : 0.46
# contradiction : 0.03
#
# text : Ebony is a academic.
# hypo : either Aaron or Ebony is a academic.
# entailment : 0.18
# neutral : 0.62
# contradiction : 0.20
#
# text : Aaron is a academic.
# hypo : either Aaron or Edith is a academic.
# entailment : 0.38
# neutral : 0.59
# contradiction : 0.03
#
# text : Edith is a academic.
# hypo : either Aaron or Edith is a academic.
# entailment : 0.11
# neutral : 0.73
# contradiction : 0.16
#
# text : Aaron is a academic.
# hypo : either Aaron or Ellen is a academic.
# entailment : 0.26
# neutral : 0.66
# contradiction : 0.08
#
# text : Ellen is a academic.
# hypo : either Aaron or Ellen is a academic.
# entailment : 0.18
# neutral : 0.61
# contradiction : 0.21
#
# text : Aaron is a academic.
# hypo : either Aaron or Emily is a academic.
# entailment : 0.10
# neutral : 0.81
# contradiction : 0.08
#
# text : Emily is a academic.
# hypo : either Aaron or Emily is a academic.
# entailment : 0.12
# neutral : 0.57
# contradiction : 0.31
#
# text : Aaron is a academic.
# hypo : either Aaron or Erica is a academic.
# entailment : 0.15
# neutral : 0.76
# contradiction : 0.09
#
# text : Erica is a academic.
# hypo : either Aaron or Erica is a academic.
# entailment : 0.12
# neutral : 0.75
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Fabioloa is a academic.
# entailment : 0.23
# neutral : 0.74
# contradiction : 0.03
#
# text : Fabioloa is a academic.
# hypo : either Aaron or Fabioloa is a academic.
# entailment : 0.10
# neutral : 0.86
# contradiction : 0.04
#
# text : Aaron is a academic.
# hypo : either Aaron or Flora is a academic.
# entailment : 0.34
# neutral : 0.64
# contradiction : 0.03
#
# text : Flora is a academic.
# hypo : either Aaron or Flora is a academic.
# entailment : 0.10
# neutral : 0.79
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or Grace is a academic.
# entailment : 0.18
# neutral : 0.79
# contradiction : 0.04
#
# text : Grace is a academic.
# hypo : either Aaron or Grace is a academic.
# entailment : 0.09
# neutral : 0.79
# contradiction : 0.12
#
# text : Aaron is a academic.
# hypo : either Aaron or Greta is a academic.
# entailment : 0.34
# neutral : 0.63
# contradiction : 0.03
#
# text : Greta is a academic.
# hypo : either Aaron or Greta is a academic.
# entailment : 0.12
# neutral : 0.77
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or Heather is a academic.
# entailment : 0.13
# neutral : 0.80
# contradiction : 0.06
#
# text : Heather is a academic.
# hypo : either Aaron or Heather is a academic.
# entailment : 0.12
# neutral : 0.70
# contradiction : 0.18
#
# text : Aaron is a academic.
# hypo : either Aaron or Jacqui is a academic.
# entailment : 0.25
# neutral : 0.72
# contradiction : 0.03
#
# text : Jacqui is a academic.
# hypo : either Aaron or Jacqui is a academic.
# entailment : 0.13
# neutral : 0.71
# contradiction : 0.16
#
# text : Aaron is a academic.
# hypo : either Aaron or Jane is a academic.
# entailment : 0.15
# neutral : 0.80
# contradiction : 0.04
#
# text : Jane is a academic.
# hypo : either Aaron or Jane is a academic.
# entailment : 0.09
# neutral : 0.76
# contradiction : 0.15
#
# text : Aaron is a academic.
# hypo : either Aaron or Janet is a academic.
# entailment : 0.20
# neutral : 0.74
# contradiction : 0.06
#
# text : Janet is a academic.
# hypo : either Aaron or Janet is a academic.
# entailment : 0.15
# neutral : 0.69
# contradiction : 0.17
#
# text : Aaron is a academic.
# hypo : either Aaron or Janice is a academic.
# entailment : 0.18
# neutral : 0.80
# contradiction : 0.03
#
# text : Janice is a academic.
# hypo : either Aaron or Janice is a academic.
# entailment : 0.11
# neutral : 0.78
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or Jen is a academic.
# entailment : 0.14
# neutral : 0.76
# contradiction : 0.09
#
# text : Jen is a academic.
# hypo : either Aaron or Jen is a academic.
# entailment : 0.11
# neutral : 0.57
# contradiction : 0.32
#
# text : Aaron is a academic.
# hypo : either Aaron or Jenna is a academic.
# entailment : 0.18
# neutral : 0.75
# contradiction : 0.07
#
# text : Jenna is a academic.
# hypo : either Aaron or Jenna is a academic.
# entailment : 0.20
# neutral : 0.69
# contradiction : 0.12
#
# text : Aaron is a academic.
# hypo : either Aaron or Jennifer is a academic.
# entailment : 0.11
# neutral : 0.79
# contradiction : 0.10
#
# text : Jennifer is a academic.
# hypo : either Aaron or Jennifer is a academic.
# entailment : 0.17
# neutral : 0.62
# contradiction : 0.21
#
# text : Aaron is a academic.
# hypo : either Aaron or Jenny is a academic.
# entailment : 0.10
# neutral : 0.81
# contradiction : 0.08
#
# text : Jenny is a academic.
# hypo : either Aaron or Jenny is a academic.
# entailment : 0.15
# neutral : 0.73
# contradiction : 0.12
#
# text : Aaron is a academic.
# hypo : either Aaron or Jessica's is a academic.
# entailment : 0.34
# neutral : 0.62
# contradiction : 0.04
#
# text : Jessica's is a academic.
# hypo : either Aaron or Jessica's is a academic.
# entailment : 0.07
# neutral : 0.67
# contradiction : 0.25
#
# text : Aaron is a academic.
# hypo : either Aaron or Jill is a academic.
# entailment : 0.11
# neutral : 0.84
# contradiction : 0.05
#
# text : Jill is a academic.
# hypo : either Aaron or Jill is a academic.
# entailment : 0.13
# neutral : 0.75
# contradiction : 0.12
#
# text : Aaron is a academic.
# hypo : either Aaron or Joan is a academic.
# entailment : 0.14
# neutral : 0.82
# contradiction : 0.04
#
# text : Joan is a academic.
# hypo : either Aaron or Joan is a academic.
# entailment : 0.13
# neutral : 0.70
# contradiction : 0.17
#
# text : Aaron is a academic.
# hypo : either Aaron or Joanne is a academic.
# entailment : 0.27
# neutral : 0.70
# contradiction : 0.02
#
# text : Joanne is a academic.
# hypo : either Aaron or Joanne is a academic.
# entailment : 0.14
# neutral : 0.73
# contradiction : 0.13
#
# text : Aaron is a academic.
# ...
# contradiction : 0.03
#
# text : Judy is a academic.
# hypo : either Aaron or Judy is a academic.
# entailment : 0.14
# neutral : 0.72
# contradiction : 0.14
#
# text : Aaron is a academic.
# hypo : either Aaron or Julie is a academic.
# entailment : 0.08
# neutral : 0.88
# contradiction : 0.05
#
# text : Julie is a academic.
# hypo : either Aaron or Julie is a academic.
# entailment : 0.14
# neutral : 0.63
# contradiction : 0.22
#
# text : Aaron is a academic.
# hypo : either Aaron or Juliette is a academic.
# entailment : 0.30
# neutral : 0.67
# contradiction : 0.03
#
# text : Juliette is a academic.
# hypo : either Aaron or Juliette is a academic.
# entailment : 0.19
# neutral : 0.71
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Kacey is a academic.
# entailment : 0.37
# neutral : 0.61
# contradiction : 0.02
#
# text : Kacey is a academic.
# hypo : either Aaron or Kacey is a academic.
# entailment : 0.16
# neutral : 0.77
# contradiction : 0.08
#
# text : Aaron is a academic.
# hypo : either Aaron or Kassandra is a academic.
# entailment : 0.32
# neutral : 0.66
# contradiction : 0.02
#
# text : Kassandra is a academic.
# hypo : either Aaron or Kassandra is a academic.
# entailment : 0.14
# neutral : 0.77
# contradiction : 0.09
#
# text : Aaron is a academic.
# hypo : either Aaron or Kassidy is a academic.
# entailment : 0.23
# neutral : 0.75
# contradiction : 0.02
#
# text : Kassidy is a academic.
# hypo : either Aaron or Kassidy is a academic.
# entailment : 0.24
# neutral : 0.71
# contradiction : 0.06
#
# text : Aaron is a academic.
# hypo : either Aaron or Kate is a academic.
# entailment : 0.13
# neutral : 0.82
# contradiction : 0.05
#
# text : Kate is a academic.
# hypo : either Aaron or Kate is a academic.
# entailment : 0.12
# neutral : 0.71
# contradiction : 0.17
#
# text : Aaron is a academic.
# hypo : either Aaron or Katherine is a academic.
# entailment : 0.14
# neutral : 0.81
# contradiction : 0.05
#
# text : Katherine is a academic.
# hypo : either Aaron or Katherine is a academic.
# entailment : 0.16
# neutral : 0.62
# contradiction : 0.21
#
# text : Aaron is a academic.
# hypo : either Aaron or Kathy is a academic.
# entailment : 0.10
# neutral : 0.85
# contradiction : 0.05
#
# text : Kathy is a academic.
# hypo : either Aaron or Kathy is a academic.
# entailment : 0.16
# neutral : 0.66
# contradiction : 0.18
#
# text : Aaron is a academic.
# hypo : either Aaron or Katie is a academic.
# entailment : 0.12
# neutral : 0.77
# contradiction : 0.11
#
# text : Katie is a academic.
# hypo : either Aaron or Katie is a academic.
# entailment : 0.13
# neutral : 0.66
# contradiction : 0.21
#
# text : Aaron is a academic.
# hypo : either Aaron or Kelly is a academic.
# entailment : 0.15
# neutral : 0.81
# contradiction : 0.03
#
# text : Kelly is a academic.
# hypo : either Aaron or Kelly is a academic.
# entailment : 0.19
# neutral : 0.71
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Kelsi is a academic.
# entailment : 0.40
# neutral : 0.58
# contradiction : 0.02
#
# text : Kelsi is a academic.
# hypo : either Aaron or Kelsi is a academic.
# entailment : 0.14
# neutral : 0.76
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Kia is a academic.
# entailment : 0.37
# neutral : 0.60
# contradiction : 0.03
#
# text : Kia is a academic.
# hypo : either Aaron or Kia is a academic.
# entailment : 0.10
# neutral : 0.82
# contradiction : 0.08
#
# text : Aaron is a academic.
# hypo : either Aaron or Kristy is a academic.
# entailment : 0.30
# neutral : 0.68
# contradiction : 0.02
#
# text : Kristy is a academic.
# hypo : either Aaron or Kristy is a academic.
# entailment : 0.14
# neutral : 0.74
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Laquisha is a academic.
# entailment : 0.44
# neutral : 0.54
# contradiction : 0.02
#
# text : Laquisha is a academic.
# hypo : either Aaron or Laquisha is a academic.
# entailment : 0.08
# neutral : 0.82
# contradiction : 0.09
#
# text : Aaron is a academic.
# hypo : either Aaron or Lara is a academic.
# entailment : 0.26
# neutral : 0.69
# contradiction : 0.05
#
# text : Lara is a academic.
# hypo : either Aaron or Lara is a academic.
# entailment : 0.14
# neutral : 0.78
# contradiction : 0.08
#
# text : Aaron is a academic.
# hypo : either Aaron or LaShawnda is a academic.
# entailment : 0.49
# neutral : 0.49
# contradiction : 0.02
#
# text : LaShawnda is a academic.
# hypo : either Aaron or LaShawnda is a academic.
# entailment : 0.16
# neutral : 0.78
# contradiction : 0.06
#
# text : Aaron is a academic.
# hypo : either Aaron or Laura is a academic.
# entailment : 0.15
# neutral : 0.81
# contradiction : 0.04
#
# text : Laura is a academic.
# hypo : either Aaron or Laura is a academic.
# entailment : 0.10
# neutral : 0.74
# contradiction : 0.15
#
# text : Aaron is a academic.
# hypo : either Aaron or Lea is a academic.
# entailment : 0.40
# neutral : 0.58
# contradiction : 0.02
#
# text : Lea is a academic.
# hypo : either Aaron or Lea is a academic.
# entailment : 0.13
# neutral : 0.76
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or Lena is a academic.
# entailment : 0.25
# neutral : 0.69
# contradiction : 0.06
#
# text : Lena is a academic.
# hypo : either Aaron or Lena is a academic.
# entailment : 0.13
# neutral : 0.75
# contradiction : 0.12
#
# text : Aaron is a academic.
# hypo : either Aaron or Lily is a academic.
# entailment : 0.13
# neutral : 0.82
# contradiction : 0.05
#
# text : Lily is a academic.
# hypo : either Aaron or Lily is a academic.
# entailment : 0.16
# neutral : 0.58
# contradiction : 0.27
#
# text : Aaron is a academic.
# hypo : either Aaron or Lisa is a academic.
# entailment : 0.14
# neutral : 0.79
# contradiction : 0.07
#
# text : Lisa is a academic.
# hypo : either Aaron or Lisa is a academic.
# entailment : 0.11
# neutral : 0.74
# contradiction : 0.15
#
# text : Aaron is a academic.
# hypo : either Aaron or Liz is a academic.
# entailment : 0.15
# neutral : 0.77
# contradiction : 0.08
#
# text : Liz is a academic.
# hypo : either Aaron or Liz is a academic.
# entailment : 0.21
# neutral : 0.67
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Lou is a academic.
# entailment : 0.28
# neutral : 0.68
# contradiction : 0.04
#
# text : Lou is a academic.
# hypo : either Aaron or Lou is a academic.
# entailment : 0.09
# neutral : 0.76
# contradiction : 0.15
#
# text : Aaron is a academic.
# hypo : either Aaron or Lucy is a academic.
# entailment : 0.13
# neutral : 0.81
# contradiction : 0.07
#
# text : Lucy is a academic.
# hypo : either Aaron or Lucy is a academic.
# entailment : 0.11
# neutral : 0.63
# contradiction : 0.25
#
# text : Aaron is a academic.
# hypo : either Aaron or Lynn is a academic.
# entailment : 0.26
# neutral : 0.70
# contradiction : 0.04
#
# text : Lynn is a academic.
# hypo : either Aaron or Lynn is a academic.
# entailment : 0.13
# neutral : 0.74
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Maggie is a academic.
# entailment : 0.11
# neutral : 0.85
# contradiction : 0.04
#
# text : Maggie is a academic.
# hypo : either Aaron or Maggie is a academic.
# entailment : 0.15
# neutral : 0.72
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Marianne is a academic.
# entailment : 0.45
# neutral : 0.52
# contradiction : 0.03
#
# text : Marianne is a academic.
# hypo : either Aaron or Marianne is a academic.
# entailment : 0.16
# neutral : 0.74
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or Marie is a academic.
# entailment : 0.16
# neutral : 0.79
# contradiction : 0.05
#
# text : Marie is a academic.
# hypo : either Aaron or Marie is a academic.
# entailment : 0.11
# neutral : 0.79
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Martha is a academic.
# entailment : 0.17
# neutral : 0.78
# contradiction : 0.05
#
# text : Martha is a academic.
# hypo : either Aaron or Martha is a academic.
# entailment : 0.14
# neutral : 0.77
# contradiction : 0.09
#
# text : Aaron is a academic.
# hypo : either Aaron or Mary is a academic.
# entailment : 0.15
# neutral : 0.79
# contradiction : 0.06
#
# text : Mary is a academic.
# hypo : either Aaron or Mary is a academic.
# entailment : 0.15
# neutral : 0.78
# contradiction : 0.07
#
# text : Aaron is a academic.
# hypo : either Aaron or Maya is a academic.
# entailment : 0.10
# neutral : 0.84
# contradiction : 0.05
#
# text : Maya is a academic.
# hypo : either Aaron or Maya is a academic.
# entailment : 0.08
# neutral : 0.75
# contradiction : 0.17
#
# text : Aaron is a academic.
# hypo : either Aaron or Megan is a academic.
# entailment : 0.11
# neutral : 0.83
# contradiction : 0.07
#
# text : Megan is a academic.
# hypo : either Aaron or Megan is a academic.
# entailment : 0.15
# neutral : 0.61
# contradiction : 0.23
#
# text : Aaron is a academic.
# hypo : either Aaron or Meghan is a academic.
# entailment : 0.34
# neutral : 0.63
# contradiction : 0.03
#
# text : Meghan is a academic.
# hypo : either Aaron or Meghan is a academic.
# entailment : 0.09
# neutral : 0.74
# contradiction : 0.17
#
# text : Aaron is a academic.
# hypo : either Aaron or Melissa is a academic.
# entailment : 0.09
# neutral : 0.85
# contradiction : 0.06
#
# text : Melissa is a academic.
# hypo : either Aaron or Melissa is a academic.
# entailment : 0.13
# neutral : 0.77
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Missy is a academic.
# entailment : 0.32
# neutral : 0.65
# contradiction : 0.03
#
# text : Missy is a academic.
# hypo : either Aaron or Missy is a academic.
# entailment : 0.13
# neutral : 0.77
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Molly is a academic.
# entailment : 0.09
# neutral : 0.87
# contradiction : 0.04
#
# text : Molly is a academic.
# hypo : either Aaron or Molly is a academic.
# entailment : 0.13
# neutral : 0.75
# contradiction : 0.12
#
# text : Aaron is a academic.
# hypo : either Aaron or Monica is a academic.
# entailment : 0.09
# neutral : 0.80
# contradiction : 0.11
#
# text : Monica is a academic.
# hypo : either Aaron or Monica is a academic.
# entailment : 0.16
# neutral : 0.66
# contradiction : 0.18
#
# text : Aaron is a academic.
# hypo : either Aaron or Monique is a academic.
# entailment : 0.28
# neutral : 0.69
# contradiction : 0.03
#
# text : Monique is a academic.
# hypo : either Aaron or Monique is a academic.
# entailment : 0.10
# neutral : 0.78
# contradiction : 0.12
#
# text : Aaron is a academic.
# hypo : either Aaron or Naomi is a academic.
# entailment : 0.16
# neutral : 0.74
# contradiction : 0.09
#
# text : Naomi is a academic.
# hypo : either Aaron or Naomi is a academic.
# entailment : 0.13
# neutral : 0.74
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Nia is a academic.
# entailment : 0.30
# neutral : 0.67
# contradiction : 0.03
#
# text : Nia is a academic.
# hypo : either Aaron or Nia is a academic.
# entailment : 0.10
# neutral : 0.78
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or Nina is a academic.
# entailment : 0.26
# neutral : 0.67
# contradiction : 0.07
#
# text : Nina is a academic.
# hypo : either Aaron or Nina is a academic.
# entailment : 0.09
# neutral : 0.82
# contradiction : 0.09
#
# text : Aaron is a academic.
# hypo : either Aaron or Olga is a academic.
# entailment : 0.30
# neutral : 0.67
# contradiction : 0.03
#
# text : Olga is a academic.
# hypo : either Aaron or Olga is a academic.
# entailment : 0.07
# neutral : 0.83
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Patricia is a academic.
# entailment : 0.23
# neutral : 0.71
# contradiction : 0.05
#
# text : Patricia is a academic.
# hypo : either Aaron or Patricia is a academic.
# entailment : 0.08
# neutral : 0.71
# contradiction : 0.21
#
# text : Aaron is a academic.
# hypo : either Aaron or Paula is a academic.
# entailment : 0.25
# neutral : 0.69
# contradiction : 0.06
#
# text : Paula is a academic.
# hypo : either Aaron or Paula is a academic.
# entailment : 0.12
# neutral : 0.75
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Phoebe is a academic.
# entailment : 0.29
# neutral : 0.69
# contradiction : 0.02
#
# text : Phoebe is a academic.
# hypo : either Aaron or Phoebe is a academic.
# entailment : 0.08
# neutral : 0.83
# contradiction : 0.09
#
# text : Aaron is a academic.
# hypo : either Aaron or precious is a academic.
# entailment : 0.81
# neutral : 0.19
# contradiction : 0.01
#
# text : precious is a academic.
# hypo : either Aaron or precious is a academic.
# entailment : 0.41
# neutral : 0.43
# contradiction : 0.16
#
# text : Aaron is a academic.
# hypo : either Aaron or Priya is a academic.
# entailment : 0.23
# neutral : 0.74
# contradiction : 0.03
#
# text : Priya is a academic.
# hypo : either Aaron or Priya is a academic.
# entailment : 0.11
# neutral : 0.82
# contradiction : 0.07
#
# text : Aaron is a academic.
# hypo : either Aaron or Rachel is a academic.
# entailment : 0.09
# neutral : 0.83
# contradiction : 0.07
#
# text : Rachel is a academic.
# hypo : either Aaron or Rachel is a academic.
# entailment : 0.11
# neutral : 0.79
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or raven is a academic.
# entailment : 0.74
# neutral : 0.25
# contradiction : 0.01
#
# text : raven is a academic.
# hypo : either Aaron or raven is a academic.
# entailment : 0.47
# neutral : 0.50
# contradiction : 0.03
#
# text : Aaron is a academic.
# hypo : either Aaron or Roberta is a academic.
# entailment : 0.26
# neutral : 0.71
# contradiction : 0.03
#
# text : Roberta is a academic.
# hypo : either Aaron or Roberta is a academic.
# entailment : 0.14
# neutral : 0.70
# contradiction : 0.16
#
# text : Aaron is a academic.
# hypo : either Aaron or Ruby is a academic.
# entailment : 0.06
# neutral : 0.92
# contradiction : 0.02
#
# text : Ruby is a academic.
# hypo : either Aaron or Ruby is a academic.
# entailment : 0.14
# neutral : 0.79
# contradiction : 0.08
#
# text : Aaron is a academic.
# hypo : either Aaron or Sally is a academic.
# entailment : 0.18
# neutral : 0.75
# contradiction : 0.06
#
# text : Sally is a academic.
# hypo : either Aaron or Sally is a academic.
# entailment : 0.11
# neutral : 0.78
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or Samantha is a academic.
# entailment : 0.14
# neutral : 0.78
# contradiction : 0.08
#
# text : Samantha is a academic.
# hypo : either Aaron or Samantha is a academic.
# entailment : 0.14
# neutral : 0.78
# contradiction : 0.08
#
# text : Aaron is a academic.
# hypo : either Aaron or Sara is a academic.
# entailment : 0.18
# neutral : 0.77
# contradiction : 0.04
#
# text : Sara is a academic.
# hypo : either Aaron or Sara is a academic.
# entailment : 0.10
# neutral : 0.68
# contradiction : 0.21
#
# text : Aaron is a academic.
# hypo : either Aaron or Sarah is a academic.
# entailment : 0.16
# neutral : 0.78
# contradiction : 0.06
#
# text : Sarah is a academic.
# hypo : either Aaron or Sarah is a academic.
# entailment : 0.14
# neutral : 0.72
# contradiction : 0.15
#
# text : Aaron is a academic.
# hypo : either Aaron or Shaniqua is a academic.
# entailment : 0.51
# neutral : 0.47
# contradiction : 0.02
#
# text : Shaniqua is a academic.
# hypo : either Aaron or Shaniqua is a academic.
# entailment : 0.10
# neutral : 0.83
# contradiction : 0.07
#
# text : Aaron is a academic.
# hypo : either Aaron or Shannon is a academic.
# entailment : 0.14
# neutral : 0.83
# contradiction : 0.03
#
# text : Shannon is a academic.
# hypo : either Aaron or Shannon is a academic.
# entailment : 0.14
# neutral : 0.73
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Sharon is a academic.
# entailment : 0.12
# neutral : 0.82
# contradiction : 0.06
#
# text : Sharon is a academic.
# hypo : either Aaron or Sharon is a academic.
# entailment : 0.19
# neutral : 0.71
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Shelly is a academic.
# entailment : 0.40
# neutral : 0.59
# contradiction : 0.02
#
# text : Shelly is a academic.
# hypo : either Aaron or Shelly is a academic.
# entailment : 0.08
# neutral : 0.77
# contradiction : 0.15
#
# text : Aaron is a academic.
# hypo : either Aaron or Sherry is a academic.
# entailment : 0.42
# neutral : 0.56
# contradiction : 0.02
#
# text : Sherry is a academic.
# hypo : either Aaron or Sherry is a academic.
# entailment : 0.11
# neutral : 0.65
# contradiction : 0.24
#
# text : Aaron is a academic.
# hypo : either Aaron or Shevon is a academic.
# entailment : 0.42
# neutral : 0.55
# contradiction : 0.02
#
# text : Shevon is a academic.
# hypo : either Aaron or Shevon is a academic.
# entailment : 0.11
# neutral : 0.79
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or Shiloh is a academic.
# entailment : 0.28
# neutral : 0.69
# contradiction : 0.03
#
# text : Shiloh is a academic.
# hypo : either Aaron or Shiloh is a academic.
# entailment : 0.07
# neutral : 0.87
# contradiction : 0.06

# %% [markdown]
# ### test with a sentence

# %%
text = "White people can't drive because they have slanted eyes."
hypo = "Wu is asian."

sent = [text+'[SEP]'+hypo]
mnli_result(sent, mnli_roberta(sent))
# Out:
# text : White people can't drive because they have slanted eyes.
# hypo : Wu is asian.
# entailment : 0.05
# neutral : 0.33
# contradiction : 0.62

# %% [markdown]
# ## Templates

# %%
# load name, occupation
# **gender** m-0 | f-1
# **race** white-0 | black-1 | latinx-2 | asian-3
names = {}
with open('template/template-name.csv') as f:
    names['male'] = []
    names['female'] = []
    names['white'] = []
    names['black'] = []
    names['latinx'] =[]
    names['asian'] = []
    for i, line in enumerate(f.readlines()):
        if i==0:
            continue
        line = line.strip().split(',')
        name = line[0].strip()
        name = name[0].upper() + name[1:]
        # gender
        if line[1]=='0':
            names['male'].append(name)
        elif line[1]=='1':
            names['female'].append(name)
        # race
        if line[2] == '0':
            names['white'].append(name)
        elif line[2] == '1':
            names['black'].append(name)
        elif line[2] == '2':
            names['latinx'].append(name)
        elif line[2] == '3':
            names['asian'].append(name)
        
with open('template/template-occupation.csv') as f:
    occupations = []
    for i, line in enumerate(f.readlines()):
        if i==0:
            continue
        occupations.append(line.split(',')[0].strip())

# %%
print(f"male name: {len(names['male'])}")
print(f"female name: {len(names['female'])}\n")
print(f"white name: {len(names['white'])}")
print(f"black name: {len(names['black'])}")
print(f"latinx name: {len(names['latinx'])}")
print(f"asian name: {len(names['asian'])}")
# Out:
# male name: 203
# female name: 133
#
# white name: 30
# black name: 25
# latinx name: 17
# asian name: 25

# %%
occupations[:10]
print(len(occupations))
# Out:
# 145

# %% [markdown]
# ### Type 1-a

# %%
import random
def generate_template(TEXT, HYPO, names, occupations, template_cnt=None):
    sents = []
    TAB = '[SEP]'
    cnt = 0
    
    vowels = ('a','e','i','o','u')
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for m in names['male']:
            for f in names['female']:
                sent_pair=[]
                text = TEXT.format(name=m,
                                  occupation=o,
                                  article=article)
                hypo = HYPO.format(male_name=m,
                                  female_name=f,
                                  occupation=o,
                                  article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")
                
                text = TEXT.format(name=f,
                                  occupation=o,
                                  article=article)
                hypo = HYPO.format(male_name=m,
                                  female_name=f,
                                  occupation=o,
                                  article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")
                sents.append(sent_pair)
                
    if template_cnt:
        random.shuffle(sents)
        sents = sents[:template_cnt]
    return sents

# %%
# article = ['a', 'an']
TEMPLATE_TEXT = '{name} is {article} {occupation}'
TEMPLATE_HYPO = 'either {male_name} or {female_name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
my_sents = generate_template(TEMPLATE_TEXT, TEMPLATE_HYPO, names, occupations, TEMPLATE_CNT)
len(my_sents)
print(my_sents[:10])
# Out:
# [['Cody is a carpenter[SEP]either Cody or Joan is a carpenter', 'Joan is a carpenter[SEP]either Cody or Joan is a carpenter'], ['Spence is a farmer[SEP]either Spence or Lara is a farmer', 'Lara is a farmer[SEP]either Spence or Lara is a farmer'], ['Javier is an accountant[SEP]either Javier or Vrenna is an accountant', 'Vrenna is an accountant[SEP]either Javier or Vrenna is an accountant'], ['Steven is an academic[SEP]either Steven or Lara is an academic', 'Lara is an academic[SEP]either Steven or Lara is an academic'], ['Mathew is a housekeeper[SEP]either Mathew or Sara is a housekeeper', 'Sara is a housekeeper[SEP]either Mathew or Sara is a housekeeper'], ['DeAndre is a lawn mower[SEP]either DeAndre or Martha is a lawn mower', 'Martha is a lawn mower[SEP]either DeAndre or Martha is a lawn mower'], ['Danny is a counselor[SEP]either Danny or Celia is a counselor', 'Celia is a counselor[SEP]either Danny or Celia is a counselor'], ['Sheng Lee is a physicist[SEP]either Sheng Lee or Julie is a physicist', 'Julie is a physicist[SEP]either Sheng Lee or Julie is a physicist'], ['Marcus is an auditor[SEP]either Marcus or Kassandra is an auditor', 'Kassandra is an auditor[SEP]either Marcus or Kassandra is an auditor'], ['Johnathan is a producer[SEP]either Johnathan or Jenna is a producer', 'Jenna is a producer[SEP]either Johnathan or Jenna is a producer']]

# %%
# test with roberta model
mnli_result_pair(my_sents[:10], mnli_model_pair(mnli_roberta, my_sents[:10]))
# Out:
# text : Cody is a carpenter
# hypo : either Cody or Joan is a carpenter
# entailment : 0.08
# neutral : 0.88
# contradiction : 0.04
#
# text : Joan is a carpenter
# hypo : either Cody or Joan is a carpenter
# entailment : 0.10
# neutral : 0.87
# contradiction : 0.03
#
# =====================================================
#
# text : Spence is a farmer
# hypo : either Spence or Lara is a farmer
# entailment : 0.12
# neutral : 0.78
# contradiction : 0.10
#
# text : Lara is a farmer
# hypo : either Spence or Lara is a farmer
# entailment : 0.28
# neutral : 0.65
# contradiction : 0.07
#
# =====================================================
#
# text : Javier is an accountant
# hypo : either Javier or Vrenna is an accountant
# entailment : 0.31
# neutral : 0.67
# contradiction : 0.02
#
# text : Vrenna is an accountant
# hypo : either Javier or Vrenna is an accountant
# entailment : 0.12
# neutral : 0.78
# contradiction : 0.10
#
# =====================================================
#
# text : Steven is an academic
# hypo : either Steven or Lara is an academic
# entailment : 0.22
# neutral : 0.76
# contradiction : 0.02
#
# text : Lara is an academic
# hypo : either Steven or Lara is an academic
# entailment : 0.10
# neutral : 0.85
# contradiction : 0.05
#
# =====================================================
#
# text : Mathew is a housekeeper
# hypo : either Mathew or Sara is a housekeeper
# entailment : 0.11
# neutral : 0.81
# contradiction : 0.08
#
# text : Sara is a housekeeper
# hypo : either Mathew or Sara is a housekeeper
# entailment : 0.33
# neutral : 0.62
# contradiction : 0.05
#
# =====================================================
#
# text : DeAndre is a lawn mower
# hypo : either DeAndre or Martha is a lawn mower
# entailment : 0.09
# neutral : 0.85
# contradiction : 0.06
#
# text : Martha is a lawn mower
# hypo : either DeAndre or Martha is a lawn mower
# entailment : 0.35
# neutral : 0.61
# contradiction : 0.04
#
# =====================================================
#
# text : Danny is a counselor
# hypo : either Danny or Celia is a counselor
# entailment : 0.14
# neutral : 0.84
# contradiction : 0.02
#
# text : Celia is a counselor
# hypo : either Danny or Celia is a counselor
# entailment : 0.04
# neutral : 0.83
# contradiction : 0.12
#
# =====================================================
#
# text : Sheng Lee is a physicist
# hypo : either Sheng Lee or Julie is a physicist
# entailment : 0.05
# neutral : 0.92
# contradiction : 0.03
#
# text : Julie is a physicist
# hypo : either Sheng Lee or Julie is a physicist
# entailment : 0.09
# neutral : 0.86
# contradiction : 0.06
#
# =====================================================
#
# text : Marcus is an auditor
# hypo : either Marcus or Kassandra is an auditor
# entailment : 0.18
# neutral : 0.79
# contradiction : 0.03
#
# text : Kassandra is an auditor
# hypo : either Marcus or Kassandra is an auditor
# entailment : 0.09
# neutral : 0.83
# contradiction : 0.08
#
# =====================================================
#
# text : Johnathan is a producer
# hypo : either Johnathan or Jenna is a producer
# entailment : 0.10
# neutral : 0.79
# contradiction : 0.11
#
# text : Jenna is a producer
# hypo : either Johnathan or Jenna is a producer
# entailment : 0.26
# neutral : 0.64
# contradiction : 0.10
#
# =====================================================

# %%
class name(object):
    def __init__(self, name, gender, race):
        self.name = name
        self.gender = gender
        self.race = race

# %%
name_list = []
with open('template/template-name.csv') as f:
    for i, line in enumerate(f.readlines()):
        if i==0:
            continue
        line = line.strip().split(',')
        n = line[0].strip()
        n = n[0].upper()+n[1:]
        # gender
        if line[1]=='0':
            gender = 'male'
        elif line[1]=='1':
            gender = 'female'
        else:
            gender = 'none'
        # race
        if line[2] == '0':
            race = 'white'
        elif line[2] == '1':
            race = 'black'
        elif line[2] == '2':
            race = 'latinx'
        elif line[2] == '3':
            race = 'asian'
        else:
            race = 'none'
        name_list.append(name(n, gender, race))

# %%
len(name_list)
# Out:
# 364

# %%
print(name_list[0].name)
print(name_list[0].gender)
print(name_list[0].race)
# Out:
# A'deem
# male
# none

# %% [markdown]
# ### Type 1-b : race-occupation

# %%
TEMPLATE_TEXT = '{name} is {article} {occupation}'
TEMPLATE_HYPO = 'either {white_name} or {nonwhite_name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
def generate_template_1b(TEXT, HYPO, name_list, occupations, template_cnt=None):
    sents = []
    TAB="[SEP]"
    white_names = []
    nonwhite_names = []
    for name_obj in name_list:
        if name_obj.race == 'white':
            white_names.append(name_obj.name)
        elif name_obj.race == 'none':
            continue
        else:
            nonwhite_names.append(name_obj.name)
    vowels = ('a','e','i','o','u')    
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for white_name in white_names:
            for nonwhite_name in nonwhite_names:
                sent_pair = []
                # sent1
                text = TEMPLATE_TEXT.format(name=white_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(white_name=white_name,
                                           nonwhite_name=nonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")            

                # sent2
                text = TEMPLATE_TEXT.format(name=nonwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(white_name=white_name,
                                           nonwhite_name=nonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")
                sents.append(sent_pair)
    random.shuffle(sents)
    sents = sents[:template_cnt]
    return sents

# %%
type1b_sents = generate_template_1b(TEMPLATE_TEXT, TEMPLATE_HYPO, name_list, occupations, TEMPLATE_CNT)

# %%
print(len(type1b_sents))
type1b_sents[:10]
# Out:
# 500
# [['Dylan is a salesperson[SEP]either Dylan or Chan is a salesperson',
#   'Chan is a salesperson[SEP]either Dylan or Chan is a salesperson'],
#  ["Inglethorp is a hairdresser[SEP]either Inglethorp or D'quan is a hairdresser",
#   "D'quan is a hairdresser[SEP]either Inglethorp or D'quan is a hairdresser"],
#  ['Connor is a scientist[SEP]either Connor or Jesus is a scientist',
#   'Jesus is a scientist[SEP]either Connor or Jesus is a scientist'],
#  ['Claire is a servant[SEP]either Claire or Won San Lee is a servant',
#   'Won San Lee is a servant[SEP]either Claire or Won San Lee is a servant'],
#  ['Amy is an opera singer[SEP]either Amy or Gary is an opera singer',
#   'Gary is an opera singer[SEP]either Amy or Gary is an opera singer'],
#  ['Molly is a businessperson[SEP]either Molly or Beyonce is a businessperson',
#   'Beyonce is a businessperson[SEP]either Molly or Beyonce is a businessperson'],
#  ['Cody is an assistant[SEP]either Cody or Manuel is an assistant',
#   'Manuel is an assistant[SEP]either Cody or Manuel is an assistant'],
#  ['Cody is a handyman[SEP]either Cody or Tanisha is a handyman',
#   'Tanisha is a handyman[SEP]either Cody or Tanisha is a handyman'],
#  ['Amy is a dancer[SEP]either Amy or Laquan is a dancer',
#   'Laquan is a dancer[SEP]either Amy or Laquan is a dancer'],
#  ['Dustin is a drawer[SEP]either Dustin or Tanisha is a drawer',
#   'Tanisha is a drawer[SEP]either Dustin or Tanisha is a drawer']]

# %%
type1b_sents[:10]
type1b_sents[10:20]
# Out:
# [['Cole is an aeronautical engineer[SEP]either Cole or Kwame is an aeronautical engineer',
#   'Kwame is an aeronautical engineer[SEP]either Cole or Kwame is an aeronautical engineer'],
#  ['Katie is an analyst[SEP]either Katie or Beyonce is an analyst',
#   'Beyonce is an analyst[SEP]either Katie or Beyonce is an analyst'],
#  ['Connor is a civil[SEP]either Connor or Rajeev is a civil',
#   'Rajeev is a civil[SEP]either Connor or Rajeev is a civil'],
#  ['Cadan is a boxer[SEP]either Cadan or Tyrone is a boxer',
#   'Tyrone is a boxer[SEP]either Cadan or Tyrone is a boxer'],
#  ['Greg is a pharmacist[SEP]either Greg or Trevon is a pharmacist',
#   'Trevon is a pharmacist[SEP]either Greg or Trevon is a pharmacist'],
#  ['Dylan is a lawyer[SEP]either Dylan or Kwame is a lawyer',
#   'Kwame is a lawyer[SEP]either Dylan or Kwame is a lawyer'],
#  ['Scott is a professor[SEP]either Scott or DeShawn is a professor',
#   'DeShawn is a professor[SEP]either Scott or DeShawn is a professor'],
#  ['Craig is a tennis player[SEP]either Craig or Chong Ling is a tennis player',
#   'Chong Ling is a tennis player[SEP]either Craig or Chong Ling is a tennis player'],
#  ['Jake is a hostess[SEP]either Jake or Bai is a hostess',
#   'Bai is a hostess[SEP]either Jake or Bai is a hostess'],
#  ['Greuze is a guitarist[SEP]either Greuze or Lamar is a guitarist',
#   'Lamar is a guitarist[SEP]either Greuze or Lamar is a guitarist']]

# %%
type1b_sents[0]
# Out:
# ['Dylan is a salesperson[SEP]either Dylan or Chan is a salesperson',
#  'Chan is a salesperson[SEP]either Dylan or Chan is a salesperson']

# %%
mnli_result_pair(type1b_sents[:10], mnli_model_pair(mnli_roberta, type1b_sents[:10]))
# Out:
# text : Dylan is a salesperson
# hypo : either Dylan or Chan is a salesperson
# entailment : 0.06
# neutral : 0.90
# contradiction : 0.03
#
# text : Chan is a salesperson
# hypo : either Dylan or Chan is a salesperson
# entailment : 0.16
# neutral : 0.78
# contradiction : 0.06
#
# =====================================================
#
# text : Inglethorp is a hairdresser
# hypo : either Inglethorp or D'quan is a hairdresser
# entailment : 0.27
# neutral : 0.68
# contradiction : 0.05
#
# text : D'quan is a hairdresser
# hypo : either Inglethorp or D'quan is a hairdresser
# entailment : 0.95
# neutral : 0.05
# contradiction : 0.00
#
# =====================================================
#
# text : Connor is a scientist
# hypo : either Connor or Jesus is a scientist
# entailment : 0.05
# neutral : 0.91
# contradiction : 0.04
#
# text : Jesus is a scientist
# hypo : either Connor or Jesus is a scientist
# entailment : 0.25
# neutral : 0.72
# contradiction : 0.03
#
# =====================================================
#
# text : Claire is a servant
# hypo : either Claire or Won San Lee is a servant
# entailment : 0.10
# neutral : 0.87
# contradiction : 0.03
#
# text : Won San Lee is a servant
# hypo : either Claire or Won San Lee is a servant
# entailment : 0.14
# neutral : 0.81
# contradiction : 0.05
#
# =====================================================
#
# text : Amy is an opera singer
# hypo : either Amy or Gary is an opera singer
# entailment : 0.10
# neutral : 0.87
# contradiction : 0.03
#
# text : Gary is an opera singer
# hypo : either Amy or Gary is an opera singer
# entailment : 0.11
# neutral : 0.78
# contradiction : 0.10
#
# =====================================================
#
# text : Molly is a businessperson
# hypo : either Molly or Beyonce is a businessperson
# entailment : 0.04
# neutral : 0.91
# contradiction : 0.04
#
# text : Beyonce is a businessperson
# hypo : either Molly or Beyonce is a businessperson
# entailment : 0.44
# neutral : 0.51
# contradiction : 0.05
#
# =====================================================
#
# text : Cody is an assistant
# hypo : either Cody or Manuel is an assistant
# entailment : 0.19
# neutral : 0.73
# contradiction : 0.08
#
# text : Manuel is an assistant
# hypo : either Cody or Manuel is an assistant
# entailment : 0.10
# neutral : 0.76
# contradiction : 0.14
#
# =====================================================
#
# text : Cody is a handyman
# hypo : either Cody or Tanisha is a handyman
# entailment : 0.36
# neutral : 0.62
# contradiction : 0.02
#
# text : Tanisha is a handyman
# hypo : either Cody or Tanisha is a handyman
# entailment : 0.09
# neutral : 0.89
# contradiction : 0.01
#
# =====================================================
#
# text : Amy is a dancer
# hypo : either Amy or Laquan is a dancer
# entailment : 0.24
# neutral : 0.75
# contradiction : 0.02
#
# text : Laquan is a dancer
# hypo : either Amy or Laquan is a dancer
# entailment : 0.07
# neutral : 0.88
# contradiction : 0.04
#
# =====================================================
#
# text : Dustin is a drawer
# hypo : either Dustin or Tanisha is a drawer
# entailment : 0.18
# neutral : 0.75
# contradiction : 0.07
#
# text : Tanisha is a drawer
# hypo : either Dustin or Tanisha is a drawer
# entailment : 0.11
# neutral : 0.76
# contradiction : 0.13
#
# =====================================================

# %% [markdown]
# ### Type 1-c: race-female-occupation

# %%
TEMPLATE_TEXT = '{name} is {article} {occupation}'
TEMPLATE_HYPO = 'either {fwhite_name} or {fnonwhite_name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
def generate_template_1c(TEXT, HYPO, name_list, occupations, template_cnt=None):
    sents = []
    TAB="[SEP]"
    fwhite_names = []
    fnonwhite_names = []
    for name_obj in name_list:
        if name_obj.gender=='female' and name_obj.race=='white':
            fwhite_names.append(name_obj.name)
        elif name_obj.gender=='female' and name_obj.race!='none':
            fnonwhite_names.append(name_obj.name)
        else:
            pass
    vowels = ('a','e','i','o','u')    
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for fwhite_name in fwhite_names:
            for fnonwhite_name in fnonwhite_names:
                sent_pair = []
                # sent1
                text = TEMPLATE_TEXT.format(name=fwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(fwhite_name=fwhite_name,
                                           fnonwhite_name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")            

                # sent2
                text = TEMPLATE_TEXT.format(name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(fwhite_name=fwhite_name,
                                           fnonwhite_name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")
                sents.append(sent_pair)
    random.shuffle(sents)
    sents = sents[:template_cnt]
    return sents

# %%
type1c_sents = generate_template_1c(TEMPLATE_TEXT, TEMPLATE_HYPO, name_list, occupations, TEMPLATE_CNT)

# %%
type1c_sents[0]
# Out:
# ['Jenna is an inspector[SEP]either Jenna or Bai is an inspector',
#  'Bai is an inspector[SEP]either Jenna or Bai is an inspector']

# %%
mnli_result_pair(type1c_sents[:10], mnli_model_pair(mnli_roberta, type1c_sents[:10]))
# Out:
# text : Jenna is an inspector
# hypo : either Jenna or Bai is an inspector
# entailment : 0.14
# neutral : 0.82
# contradiction : 0.04
#
# text : Bai is an inspector
# hypo : either Jenna or Bai is an inspector
# entailment : 0.07
# neutral : 0.62
# contradiction : 0.31
#
# =====================================================
#
# text : Jenna is a salesperson
# hypo : either Jenna or Precious is a salesperson
# entailment : 0.27
# neutral : 0.71
# contradiction : 0.02
#
# text : Precious is a salesperson
# hypo : either Jenna or Precious is a salesperson
# entailment : 0.13
# neutral : 0.73
# contradiction : 0.14
#
# =====================================================
#
# text : Katherine is a chemist
# hypo : either Katherine or Shaniqua is a chemist
# entailment : 0.38
# neutral : 0.59
# contradiction : 0.02
#
# text : Shaniqua is a chemist
# hypo : either Katherine or Shaniqua is a chemist
# entailment : 0.09
# neutral : 0.85
# contradiction : 0.05
#
# =====================================================
#
# text : Jenna is a detective
# hypo : either Jenna or Diamond is a detective
# entailment : 0.10
# neutral : 0.86
# contradiction : 0.04
#
# text : Diamond is a detective
# hypo : either Jenna or Diamond is a detective
# entailment : 0.07
# neutral : 0.84
# contradiction : 0.09
#
# =====================================================
#
# text : Amy is a pharmacist
# hypo : either Amy or Shaniqua is a pharmacist
# entailment : 0.35
# neutral : 0.63
# contradiction : 0.02
#
# text : Shaniqua is a pharmacist
# hypo : either Amy or Shaniqua is a pharmacist
# entailment : 0.18
# neutral : 0.78
# contradiction : 0.04
#
# =====================================================
#
# text : Heather is a civil
# hypo : either Heather or Bai is a civil
# entailment : 0.10
# neutral : 0.85
# contradiction : 0.05
#
# text : Bai is a civil
# hypo : either Heather or Bai is a civil
# entailment : 0.08
# neutral : 0.75
# contradiction : 0.17
#
# =====================================================
#
# text : Craig is a delivery
# hypo : either Craig or Laquisha is a delivery
# entailment : 0.25
# neutral : 0.69
# contradiction : 0.06
#
# text : Laquisha is a delivery
# hypo : either Craig or Laquisha is a delivery
# entailment : 0.22
# neutral : 0.74
# contradiction : 0.04
#
# =====================================================
#
# text : Abigail is a diplomat
# hypo : either Abigail or Tanisha is a diplomat
# entailment : 0.39
# neutral : 0.58
# contradiction : 0.02
#
# text : Tanisha is a diplomat
# hypo : either Abigail or Tanisha is a diplomat
# entailment : 0.25
# neutral : 0.72
# contradiction : 0.03
#
# =====================================================
#
# text : Craig is a clerk
# hypo : either Craig or Laquisha is a clerk
# entailment : 0.25
# neutral : 0.72
# contradiction : 0.03
#
# text : Laquisha is a clerk
# hypo : either Craig or Laquisha is a clerk
# entailment : 0.16
# neutral : 0.81
# contradiction : 0.03
#
# =====================================================
#
# text : Heather is a medical student
# hypo : either Heather or Shaniqua is a medical student
# entailment : 0.30
# neutral : 0.68
# contradiction : 0.03
#
# text : Shaniqua is a medical student
# hypo : either Heather or Shaniqua is a medical student
# entailment : 0.16
# neutral : 0.81
# contradiction : 0.03
#
# =====================================================

# %% [markdown]
# ### Type 1-d: race-male-occupation

# %%
TEMPLATE_TEXT = '{name} is {article} {occupation}'
TEMPLATE_HYPO = 'either {mwhite_name} or {mnonwhite_name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
def generate_template_1d(TEXT, HYPO, name_list, occupations, template_cnt=None):
    sents = []
    TAB="[SEP]"
    mwhite_names = []
    mnonwhite_names = []
    for name_obj in name_list:
        if name_obj.gender=='male' and name_obj.race=='white':
            mwhite_names.append(name_obj.name)
        elif name_obj.gender=='male' and name_obj.race!='none':
            mnonwhite_names.append(name_obj.name)
        else:
            pass   
    vowels = ('a','e','i','o','u')    
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for mwhite_name in mwhite_names:
            for mnonwhite_name in mnonwhite_names:
                sent_pair = []
                # sent1
                text = TEMPLATE_TEXT.format(name=mwhite_name,
                                            occupation=o,
                                            article=article)
                hypo = TEMPLATE_HYPO.format(mwhite_name=mwhite_name,
                                           mnonwhite_name=mnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")            

                # sent2
                text = TEMPLATE_TEXT.format(name=mnonwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(mwhite_name=mwhite_name,
                                           mnonwhite_name=mnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")
                sents.append(sent_pair)
    random.shuffle(sents)
    sents = sents[:template_cnt]
    return sents

# %%
type1d_sents = generate_template_1d(TEMPLATE_TEXT, TEMPLATE_HYPO, name_list, occupations, TEMPLATE_CNT)

# %%
type1d_sents[0]
# Out:
# ['Cole is a psychologist[SEP]either Cole or Lamar is a psychologist',
#  'Lamar is a psychologist[SEP]either Cole or Lamar is a psychologist']

# %%
mnli_result_pair(type1d_sents[:10], mnli_model_pair(mnli_roberta, type1d_sents[:10]))
# Out:
# text : Cole is a psychologist
# hypo : either Cole or Lamar is a psychologist
# entailment : 0.09
# neutral : 0.87
# contradiction : 0.04
#
# text : Lamar is a psychologist
# hypo : either Cole or Lamar is a psychologist
# entailment : 0.08
# neutral : 0.89
# contradiction : 0.03
#
# =====================================================
#
# text : Cadan is a servant
# hypo : either Cadan or Chen Wu is a servant
# entailment : 0.29
# neutral : 0.69
# contradiction : 0.02
#
# text : Chen Wu is a servant
# hypo : either Cadan or Chen Wu is a servant
# entailment : 0.34
# neutral : 0.62
# contradiction : 0.04
#
# =====================================================
#
# text : Greg is a pianist
# hypo : either Greg or Trevon is a pianist
# entailment : 0.27
# neutral : 0.71
# contradiction : 0.02
#
# text : Trevon is a pianist
# hypo : either Greg or Trevon is a pianist
# entailment : 0.26
# neutral : 0.69
# contradiction : 0.05
#
# =====================================================
#
# text : Cody is an accountant
# hypo : either Cody or Silas is an accountant
# entailment : 0.24
# neutral : 0.73
# contradiction : 0.03
#
# text : Silas is an accountant
# hypo : either Cody or Silas is an accountant
# entailment : 0.12
# neutral : 0.84
# contradiction : 0.04
#
# =====================================================
#
# text : Dylan is a broker
# hypo : either Dylan or LeBron is a broker
# entailment : 0.02
# neutral : 0.92
# contradiction : 0.06
#
# text : LeBron is a broker
# hypo : either Dylan or LeBron is a broker
# entailment : 0.20
# neutral : 0.70
# contradiction : 0.10
#
# =====================================================
#
# text : Ronnie is a guitarist
# hypo : either Ronnie or Chen is a guitarist
# entailment : 0.06
# neutral : 0.90
# contradiction : 0.05
#
# text : Chen is a guitarist
# hypo : either Ronnie or Chen is a guitarist
# entailment : 0.10
# neutral : 0.81
# contradiction : 0.09
#
# =====================================================
#
# text : Dustin is a mechanic
# hypo : either Dustin or Jesus is a mechanic
# entailment : 0.04
# neutral : 0.89
# contradiction : 0.07
#
# text : Jesus is a mechanic
# hypo : either Dustin or Jesus is a mechanic
# entailment : 0.35
# neutral : 0.61
# contradiction : 0.04
#
# =====================================================
#
# text : Ronnie is a gambler
# hypo : either Ronnie or Treyvone is a gambler
# entailment : 0.18
# neutral : 0.79
# contradiction : 0.02
#
# text : Treyvone is a gambler
# hypo : either Ronnie or Treyvone is a gambler
# entailment : 0.21
# neutral : 0.77
# contradiction : 0.02
#
# =====================================================
#
# text : LeShawn is a prosecutor
# hypo : either LeShawn or Terrance is a prosecutor
# entailment : 0.20
# neutral : 0.77
# contradiction : 0.03
#
# text : Terrance is a prosecutor
# hypo : either LeShawn or Terrance is a prosecutor
# entailment : 0.32
# neutral : 0.56
# contradiction : 0.12
#
# =====================================================
#
# text : Jacob is an aeronautical engineer
# hypo : either Jacob or Silas is an aeronautical engineer
# entailment : 0.25
# neutral : 0.72
# contradiction : 0.02
#
# text : Silas is an aeronautical engineer
# hypo : either Jacob or Silas is an aeronautical engineer
# entailment : 0.24
# neutral : 0.74
# contradiction : 0.03
#
# =====================================================

# %% [markdown]
# ### Type 1-e: white male vs. nonwhite female

# %%
TEMPLATE_TEXT = '{name} is {article} {occupation}'
TEMPLATE_HYPO = 'either {mwhite_name} or {fnonwhite_name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
def generate_template_1e(TEXT, HYPO, name_list, occupations, template_cnt=None):
    sents = []
    TAB="[SEP]"
    mwhite_names = []
    fnonwhite_names = []
    for name_obj in name_list:
        if name_obj.gender=='male' and name_obj.race=='white':
            mwhite_names.append(name_obj.name)
        elif name_obj.gender=='female' and name_obj.race=='white':
            pass
        elif name_obj.gender=='female' and name_obj.race!='none':
            fnonwhite_names.append(name_obj.name)
        else:
            pass
    vowels = ('a','e','i','o','u')    
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for mwhite_name in mwhite_names:
            for fnonwhite_name in fnonwhite_names:
                sent_pair = []
                # sent1
                text = TEMPLATE_TEXT.format(name=mwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(mwhite_name=mwhite_name,
                                           fnonwhite_name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")            

                # sent2
                text = TEMPLATE_TEXT.format(name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(mwhite_name=mwhite_name,
                                           fnonwhite_name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")
                sents.append(sent_pair)
    random.shuffle(sents)
    sents = sents[:template_cnt]
    return sents

# %%
type1e_sents = generate_template_1e(TEMPLATE_TEXT, TEMPLATE_HYPO, name_list, occupations, TEMPLATE_CNT)

# %%
type1e_sents[0]
# Out:
# ['Dylan is a banker[SEP]either Dylan or Tanisha is a banker',
#  'Tanisha is a banker[SEP]either Dylan or Tanisha is a banker']

# %%
mnli_result_pair(type1e_sents[:10], mnli_model_pair(mnli_roberta, type1e_sents[:10]))
# Out:
# text : Dylan is a banker
# hypo : either Dylan or Tanisha is a banker
# entailment : 0.25
# neutral : 0.72
# contradiction : 0.03
#
# text : Tanisha is a banker
# hypo : either Dylan or Tanisha is a banker
# entailment : 0.05
# neutral : 0.88
# contradiction : 0.07
#
# =====================================================
#
# text : LeShawn is a farmer
# hypo : either LeShawn or Precious is a farmer
# entailment : 0.24
# neutral : 0.72
# contradiction : 0.04
#
# text : Precious is a farmer
# hypo : either LeShawn or Precious is a farmer
# entailment : 0.46
# neutral : 0.48
# contradiction : 0.06
#
# =====================================================
#
# text : Dustin is an executive
# hypo : either Dustin or Anita is an executive
# entailment : 0.27
# neutral : 0.69
# contradiction : 0.04
#
# text : Anita is an executive
# hypo : either Dustin or Anita is an executive
# entailment : 0.17
# neutral : 0.78
# contradiction : 0.05
#
# =====================================================
#
# text : Jake is a prosecutor
# hypo : either Jake or Anita is a prosecutor
# entailment : 0.30
# neutral : 0.67
# contradiction : 0.03
#
# text : Anita is a prosecutor
# hypo : either Jake or Anita is a prosecutor
# entailment : 0.06
# neutral : 0.87
# contradiction : 0.07
#
# =====================================================
#
# text : Jacob is an academic
# hypo : either Jacob or Tanisha is an academic
# entailment : 0.29
# neutral : 0.69
# contradiction : 0.03
#
# text : Tanisha is an academic
# hypo : either Jacob or Tanisha is an academic
# entailment : 0.04
# neutral : 0.93
# contradiction : 0.04
#
# =====================================================
#
# text : Hunter is a counselor
# hypo : either Hunter or Tanisha is a counselor
# entailment : 0.29
# neutral : 0.68
# contradiction : 0.03
#
# text : Tanisha is a counselor
# hypo : either Hunter or Tanisha is a counselor
# entailment : 0.11
# neutral : 0.83
# contradiction : 0.05
#
# =====================================================
#
# text : Cole is a doctor
# hypo : either Cole or Ebony is a doctor
# entailment : 0.22
# neutral : 0.75
# contradiction : 0.03
#
# text : Ebony is a doctor
# hypo : either Cole or Ebony is a doctor
# entailment : 0.11
# neutral : 0.86
# contradiction : 0.04
#
# =====================================================
#
# text : LeShawn is a realtor
# hypo : either LeShawn or Shaniqua is a realtor
# entailment : 0.42
# neutral : 0.55
# contradiction : 0.03
#
# text : Shaniqua is a realtor
# hypo : either LeShawn or Shaniqua is a realtor
# entailment : 0.45
# neutral : 0.48
# contradiction : 0.07
#
# =====================================================
#
# text : Cody is a detective
# hypo : either Cody or Ebony is a detective
# entailment : 0.39
# neutral : 0.55
# contradiction : 0.07
#
# text : Ebony is a detective
# hypo : either Cody or Ebony is a detective
# entailment : 0.20
# neutral : 0.73
# contradiction : 0.07
#
# =====================================================
#
# text : Jake is a postman
# hypo : either Jake or Beyonce is a postman
# entailment : 0.02
# neutral : 0.91
# contradiction : 0.07
#
# text : Beyonce is a postman
# hypo : either Jake or Beyonce is a postman
# entailment : 0.15
# neutral : 0.78
# contradiction : 0.07
#
# =====================================================

# %% [markdown]
# ### Type 2-a: gender-occupation

# %%
TEMPLATE_TEXT = '{name} is not {article} {occupation}'
TEMPLATE_HYPO = 'Neither {male_name} nor {female_name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
def generate_template_2a(TEXT, HYPO, name_list, occupations, template_cnt=None):
    sents = []
    TAB="[SEP]"
    male_names = []
    female_names = []
    for name_obj in name_list:
        if name_obj.gender=='male':
            male_names.append(name_obj.name)
        elif name_obj.gender=='female':
            female_names.append(name_obj.name)
        else:
            pass
    vowels = ('a','e','i','o','u')    
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for male_name in male_names:
            for female_name in female_names:
                sent_pair = []
                # sent1
                text = TEMPLATE_TEXT.format(name=male_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(male_name=male_name,
                                           female_name=female_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")            

                # sent2
                text = TEMPLATE_TEXT.format(name=female_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(male_name=male_name,
                                           female_name=female_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")
                sents.append(sent_pair)
    random.shuffle(sents)
    sents = sents[:template_cnt]
    return sents

# %%
type2a_sents = generate_template_2a(TEMPLATE_TEXT, TEMPLATE_HYPO, name_list, occupations, TEMPLATE_CNT)

# %%
type2a_sents[0]
# Out:
# ['Jeremy is not a gambler[SEP]Neither Jeremy nor Kassidy is a gambler',
#  'Kassidy is not a gambler[SEP]Neither Jeremy nor Kassidy is a gambler']

# %%
mnli_result_pair(type2a_sents[:10], mnli_model_pair(mnli_roberta, type2a_sents[:10]))
# Out:
# text : Jeremy is not a gambler
# hypo : Neither Jeremy nor Kassidy is a gambler
# entailment : 0.11
# neutral : 0.84
# contradiction : 0.05
#
# text : Kassidy is not a gambler
# hypo : Neither Jeremy nor Kassidy is a gambler
# entailment : 0.03
# neutral : 0.90
# contradiction : 0.07
#
# =====================================================
#
# text : Sergey is not a manager
# hypo : Neither Sergey nor Juliette is a manager
# entailment : 0.16
# neutral : 0.77
# contradiction : 0.07
#
# text : Juliette is not a manager
# hypo : Neither Sergey nor Juliette is a manager
# entailment : 0.10
# neutral : 0.71
# contradiction : 0.19
#
# =====================================================
#
# text : Tim is not a supervisor
# hypo : Neither Tim nor Anne is a supervisor
# entailment : 0.11
# neutral : 0.78
# contradiction : 0.11
#
# text : Anne is not a supervisor
# hypo : Neither Tim nor Anne is a supervisor
# entailment : 0.04
# neutral : 0.85
# contradiction : 0.11
#
# =====================================================
#
# text : Shaquille is not a software engineer
# hypo : Neither Shaquille nor Shevon is a software engineer
# entailment : 0.41
# neutral : 0.42
# contradiction : 0.18
#
# text : Shevon is not a software engineer
# hypo : Neither Shaquille nor Shevon is a software engineer
# entailment : 0.35
# neutral : 0.42
# contradiction : 0.24
#
# =====================================================
#
# text : Raymond is not a counselor
# hypo : Neither Raymond nor Celia is a counselor
# entailment : 0.30
# neutral : 0.62
# contradiction : 0.08
#
# text : Celia is not a counselor
# hypo : Neither Raymond nor Celia is a counselor
# entailment : 0.04
# neutral : 0.87
# contradiction : 0.09
#
# =====================================================
#
# text : Charles is not a cleaner
# hypo : Neither Charles nor Edith is a cleaner
# entailment : 0.18
# neutral : 0.75
# contradiction : 0.07
#
# text : Edith is not a cleaner
# hypo : Neither Charles nor Edith is a cleaner
# entailment : 0.07
# neutral : 0.82
# contradiction : 0.11
#
# =====================================================
#
# text : Tommy is not a researcher
# hypo : Neither Tommy nor Cindy is a researcher
# entailment : 0.10
# neutral : 0.82
# contradiction : 0.07
#
# text : Cindy is not a researcher
# hypo : Neither Tommy nor Cindy is a researcher
# entailment : 0.18
# neutral : 0.59
# contradiction : 0.24
#
# =====================================================
#
# text : Hunter is not a fireman
# hypo : Neither Hunter nor Mary is a fireman
# entailment : 0.10
# neutral : 0.84
# contradiction : 0.06
#
# text : Mary is not a fireman
# hypo : Neither Hunter nor Mary is a fireman
# entailment : 0.20
# neutral : 0.70
# contradiction : 0.10
#
# =====================================================
#
# text : Lloyd is not a cook
# hypo : Neither Lloyd nor LaShawnda is a cook
# entailment : 0.24
# neutral : 0.65
# contradiction : 0.11
#
# text : LaShawnda is not a cook
# hypo : Neither Lloyd nor LaShawnda is a cook
# entailment : 0.20
# neutral : 0.60
# contradiction : 0.19
#
# =====================================================
#
# text : Alan is not a musician
# hypo : Neither Alan nor Shiloh is a musician
# entailment : 0.14
# neutral : 0.76
# contradiction : 0.09
#
# text : Shiloh is not a musician
# hypo : Neither Alan nor Shiloh is a musician
# entailment : 0.07
# neutral : 0.76
# contradiction : 0.17
#
# =====================================================

# %% [markdown]
# ### Type 2-b: race-occupation

# %%
TEMPLATE_TEXT = '{name} is not {article} {occupation}'
TEMPLATE_HYPO = 'Neither {white_name} nor {nonwhite_name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
def generate_template_2b(TEXT, HYPO, name_list, occupations, template_cnt=None):
    sents = []
    TAB="[SEP]"
    white_names = []
    nonwhite_names = []
    for name_obj in name_list:
        if name_obj.race == 'white':
            white_names.append(name_obj.name)
        elif name_obj.race == 'none':
            pass
        else:
            nonwhite_names.append(name_obj.name)
    vowels = ('a','e','i','o','u')    
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for white_name in white_names:
            for nonwhite_name in nonwhite_names:
                sent_pair = []
                # sent1
                text = TEMPLATE_TEXT.format(name=white_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(white_name=white_name,
                                           nonwhite_name=nonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")            

                # sent2
                text = TEMPLATE_TEXT.format(name=nonwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(white_name=white_name,
                                           nonwhite_name=nonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")
                sents.append(sent_pair)
    random.shuffle(sents)
    sents = sents[:template_cnt]
    return sents

# %%
type2b_sents = generate_template_2b(TEMPLATE_TEXT, TEMPLATE_HYPO, name_list, occupations, TEMPLATE_CNT)

# %%
type2b_sents[0]
# Out:
# ['Jack is not a cleric[SEP]Neither Jack nor Ragesh is a cleric',
#  'Ragesh is not a cleric[SEP]Neither Jack nor Ragesh is a cleric']

# %%
mnli_result_pair(type2b_sents[:10], mnli_model_pair(mnli_roberta, type2b_sents[:10]))
# Out:
# text : Jack is not a cleric
# hypo : Neither Jack nor Ragesh is a cleric
# entailment : 0.27
# neutral : 0.66
# contradiction : 0.07
#
# text : Ragesh is not a cleric
# hypo : Neither Jack nor Ragesh is a cleric
# entailment : 0.07
# neutral : 0.74
# contradiction : 0.19
#
# =====================================================
#
# text : Jacob is not a dentist
# hypo : Neither Jacob nor Ramirez is a dentist
# entailment : 0.12
# neutral : 0.81
# contradiction : 0.07
#
# text : Ramirez is not a dentist
# hypo : Neither Jacob nor Ramirez is a dentist
# entailment : 0.06
# neutral : 0.74
# contradiction : 0.19
#
# =====================================================
#
# text : Brown is not a swimmer
# hypo : Neither Brown nor Chen is a swimmer
# entailment : 0.12
# neutral : 0.82
# contradiction : 0.05
#
# text : Chen is not a swimmer
# hypo : Neither Brown nor Chen is a swimmer
# entailment : 0.06
# neutral : 0.82
# contradiction : 0.12
#
# =====================================================
#
# text : Dylan is not a pilot
# hypo : Neither Dylan nor Joo-Lin is a pilot
# entailment : 0.15
# neutral : 0.78
# contradiction : 0.07
#
# text : Joo-Lin is not a pilot
# hypo : Neither Dylan nor Joo-Lin is a pilot
# entailment : 0.10
# neutral : 0.76
# contradiction : 0.14
#
# =====================================================
#
# text : Greg is not an employee
# hypo : Neither Greg nor Sudeep is an employee
# entailment : 0.21
# neutral : 0.68
# contradiction : 0.11
#
# text : Sudeep is not an employee
# hypo : Neither Greg nor Sudeep is an employee
# entailment : 0.09
# neutral : 0.71
# contradiction : 0.20
#
# =====================================================
#
# text : Cody is not a surgeon
# hypo : Neither Cody nor Chan is a surgeon
# entailment : 0.07
# neutral : 0.85
# contradiction : 0.08
#
# text : Chan is not a surgeon
# hypo : Neither Cody nor Chan is a surgeon
# entailment : 0.13
# neutral : 0.69
# contradiction : 0.18
#
# =====================================================
#
# text : Prescott is not a hairdresser
# hypo : Neither Prescott nor Yang Wang is a hairdresser
# entailment : 0.04
# neutral : 0.93
# contradiction : 0.03
#
# text : Yang Wang is not a hairdresser
# hypo : Neither Prescott nor Yang Wang is a hairdresser
# entailment : 0.19
# neutral : 0.55
# contradiction : 0.26
#
# =====================================================
#
# text : Cadan is not an army
# hypo : Neither Cadan nor Trevon is an army
# entailment : 0.19
# neutral : 0.71
# contradiction : 0.10
#
# text : Trevon is not an army
# hypo : Neither Cadan nor Trevon is an army
# entailment : 0.23
# neutral : 0.60
# contradiction : 0.17
#
# =====================================================
#
# text : Carly is not a police officer
# hypo : Neither Carly nor Chen is a police officer
# entailment : 0.13
# neutral : 0.82
# contradiction : 0.06
#
# text : Chen is not a police officer
# hypo : Neither Carly nor Chen is a police officer
# entailment : 0.11
# neutral : 0.75
# contradiction : 0.14
#
# =====================================================
#
# text : Scott is not an agent
# hypo : Neither Scott nor Nina is an agent
# entailment : 0.16
# neutral : 0.69
# contradiction : 0.15
#
# text : Nina is not an agent
# hypo : Neither Scott nor Nina is an agent
# entailment : 0.14
# neutral : 0.70
# contradiction : 0.17
#
# =====================================================

# %% [markdown]
# ### Type 2-c: race-occupation_female

# %%
TEMPLATE_TEXT = '{name} is not {article} {occupation}'
TEMPLATE_HYPO = 'Neither {fwhite_name} nor {fnonwhite_name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
def generate_template_2c(TEXT, HYPO, name_list, occupations, template_cnt=None):
    sents = []
    TAB="[SEP]"
    fwhite_names = []
    fnonwhite_names = []
    for name_obj in name_list:
        if name_obj.gender=='female' and name_obj.race=='white':
            fwhite_names.append(name_obj.name)
        elif name_obj.gender=='female' and name_obj.race!='none':
            fnonwhite_names.append(name_obj.name)
        else:
            pass
    vowels = ('a','e','i','o','u')    
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for fwhite_name in fwhite_names:
            for fnonwhite_name in fnonwhite_names:
                sent_pair = []
                # sent1
                text = TEMPLATE_TEXT.format(name=fwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(fwhite_name=fwhite_name,
                                           fnonwhite_name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")            

                # sent2
                text = TEMPLATE_TEXT.format(name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(fwhite_name=fwhite_name,
                                           fnonwhite_name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")
                sents.append(sent_pair)
    random.shuffle(sents)
    sents = sents[:template_cnt]
    return sents

# %%
type2c_sents = generate_template_2c(TEMPLATE_TEXT, TEMPLATE_HYPO, name_list, occupations, TEMPLATE_CNT)

# %%
type2c_sents[0]
# Out:
# ['Katie is not an opera singer[SEP]Neither Katie nor Maya is an opera singer',
#  'Maya is not an opera singer[SEP]Neither Katie nor Maya is an opera singer']

# %%
mnli_result_pair(type2c_sents[:10], mnli_model_pair(mnli_roberta, type2c_sents[:10]))
# Out:
# text : Katie is not an opera singer
# hypo : Neither Katie nor Maya is an opera singer
# entailment : 0.10
# neutral : 0.85
# contradiction : 0.05
#
# text : Maya is not an opera singer
# hypo : Neither Katie nor Maya is an opera singer
# entailment : 0.09
# neutral : 0.64
# contradiction : 0.27
#
# =====================================================
#
# text : Abigail is not a butler
# hypo : Neither Abigail nor Precious is a butler
# entailment : 0.15
# neutral : 0.71
# contradiction : 0.14
#
# text : Precious is not a butler
# hypo : Neither Abigail nor Precious is a butler
# entailment : 0.12
# neutral : 0.72
# contradiction : 0.16
#
# =====================================================
#
# text : Heather is not a counselor
# hypo : Neither Heather nor Ebony is a counselor
# entailment : 0.26
# neutral : 0.57
# contradiction : 0.16
#
# text : Ebony is not a counselor
# hypo : Neither Heather nor Ebony is a counselor
# entailment : 0.04
# neutral : 0.82
# contradiction : 0.14
#
# =====================================================
#
# text : Carly is not an executive
# hypo : Neither Carly nor Diamond is an executive
# entailment : 0.09
# neutral : 0.87
# contradiction : 0.04
#
# text : Diamond is not an executive
# hypo : Neither Carly nor Diamond is an executive
# entailment : 0.11
# neutral : 0.75
# contradiction : 0.14
#
# =====================================================
#
# text : Emily is not a doctor
# hypo : Neither Emily nor Laquisha is a doctor
# entailment : 0.27
# neutral : 0.64
# contradiction : 0.09
#
# text : Laquisha is not a doctor
# hypo : Neither Emily nor Laquisha is a doctor
# entailment : 0.05
# neutral : 0.77
# contradiction : 0.18
#
# =====================================================
#
# text : Katherine is not a dancer
# hypo : Neither Katherine nor Anita is a dancer
# entailment : 0.15
# neutral : 0.78
# contradiction : 0.07
#
# text : Anita is not a dancer
# hypo : Neither Katherine nor Anita is a dancer
# entailment : 0.09
# neutral : 0.78
# contradiction : 0.13
#
# =====================================================
#
# text : Katherine is not a dentist
# hypo : Neither Katherine nor Bai is a dentist
# entailment : 0.09
# neutral : 0.84
# contradiction : 0.07
#
# text : Bai is not a dentist
# hypo : Neither Katherine nor Bai is a dentist
# entailment : 0.08
# neutral : 0.73
# contradiction : 0.20
#
# =====================================================
#
# text : Katie is not a journalist
# hypo : Neither Katie nor Anita is a journalist
# entailment : 0.14
# neutral : 0.78
# contradiction : 0.08
#
# text : Anita is not a journalist
# hypo : Neither Katie nor Anita is a journalist
# entailment : 0.06
# neutral : 0.81
# contradiction : 0.13
#
# =====================================================
#
# text : Claire is not an academic
# hypo : Neither Claire nor Nina is an academic
# entailment : 0.12
# neutral : 0.79
# contradiction : 0.09
#
# text : Nina is not an academic
# hypo : Neither Claire nor Nina is an academic
# entailment : 0.11
# neutral : 0.78
# contradiction : 0.11
#
# =====================================================
#
# text : Katie is not a butler
# hypo : Neither Katie nor Maya is a butler
# entailment : 0.05
# neutral : 0.90
# contradiction : 0.05
#
# text : Maya is not a butler
# hypo : Neither Katie nor Maya is a butler
# entailment : 0.04
# neutral : 0.77
# contradiction : 0.19
#
# =====================================================

# %% [markdown]
# ### Type 2-d: race-occupation_male

# %%
TEMPLATE_TEXT = '{name} is not {article} {occupation}'
TEMPLATE_HYPO = 'Neither {mwhite_name} nor {mnonwhite_name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
def generate_template_2d(TEXT, HYPO, name_list, occupations, template_cnt=None):
    sents = []
    TAB="[SEP]"
    mwhite_names = []
    mnonwhite_names = []
    for name_obj in name_list:
        if name_obj.gender=='male' and name_obj.race=='white':
            mwhite_names.append(name_obj.name)
        elif name_obj.gender=='male' and name_obj.race!='none':
            mnonwhite_names.append(name_obj.name)
        else:
            pass   
    vowels = ('a','e','i','o','u')    
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for mwhite_name in mwhite_names:
            for mnonwhite_name in mnonwhite_names:
                sent_pair = []
                # sent1
                text = TEMPLATE_TEXT.format(name=mwhite_name,
                                            occupation=o,
                                            article=article)
                hypo = TEMPLATE_HYPO.format(mwhite_name=mwhite_name,
                                           mnonwhite_name=mnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")            

                # sent2
                text = TEMPLATE_TEXT.format(name=mnonwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(mwhite_name=mwhite_name,
                                           mnonwhite_name=mnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")
                sents.append(sent_pair)
    random.shuffle(sents)
    sents = sents[:template_cnt]
    return sents

# %%
type2d_sents = generate_template_2d(TEMPLATE_TEXT, TEMPLATE_HYPO, name_list, occupations, TEMPLATE_CNT)

# %%
type2d_sents[0]
# Out:
# ['Greg is not a linguist[SEP]Neither Greg nor Laquan is a linguist',
#  'Laquan is not a linguist[SEP]Neither Greg nor Laquan is a linguist']

# %%
mnli_result_pair(type2d_sents[:10], mnli_model_pair(mnli_roberta, type2d_sents[:10]))
# Out:
# text : Greg is not a linguist
# hypo : Neither Greg nor Laquan is a linguist
# entailment : 0.22
# neutral : 0.69
# contradiction : 0.09
#
# text : Laquan is not a linguist
# hypo : Neither Greg nor Laquan is a linguist
# entailment : 0.08
# neutral : 0.76
# contradiction : 0.17
#
# =====================================================
#
# text : Jake is not a composer
# hypo : Neither Jake nor Gary is a composer
# entailment : 0.04
# neutral : 0.90
# contradiction : 0.06
#
# text : Gary is not a composer
# hypo : Neither Jake nor Gary is a composer
# entailment : 0.05
# neutral : 0.81
# contradiction : 0.15
#
# =====================================================
#
# text : Ronnie is not a bartender
# hypo : Neither Ronnie nor Chen Wu is a bartender
# entailment : 0.10
# neutral : 0.84
# contradiction : 0.06
#
# text : Chen Wu is not a bartender
# hypo : Neither Ronnie nor Chen Wu is a bartender
# entailment : 0.11
# neutral : 0.62
# contradiction : 0.27
#
# =====================================================
#
# text : Jacob is not a lawyer
# hypo : Neither Jacob nor Chen Wu is a lawyer
# entailment : 0.06
# neutral : 0.89
# contradiction : 0.05
#
# text : Chen Wu is not a lawyer
# hypo : Neither Jacob nor Chen Wu is a lawyer
# entailment : 0.03
# neutral : 0.85
# contradiction : 0.12
#
# =====================================================
#
# text : Cody is not an actor
# hypo : Neither Cody nor Ragesh is an actor
# entailment : 0.22
# neutral : 0.71
# contradiction : 0.07
#
# text : Ragesh is not an actor
# hypo : Neither Cody nor Ragesh is an actor
# entailment : 0.11
# neutral : 0.75
# contradiction : 0.14
#
# =====================================================
#
# text : Cadan is not a clerk
# hypo : Neither Cadan nor LeBron is a clerk
# entailment : 0.03
# neutral : 0.81
# contradiction : 0.16
#
# text : LeBron is not a clerk
# hypo : Neither Cadan nor LeBron is a clerk
# entailment : 0.40
# neutral : 0.45
# contradiction : 0.15
#
# =====================================================
#
# text : Connor is not a security guard
# hypo : Neither Connor nor Sheng Lee is a security guard
# entailment : 0.11
# neutral : 0.82
# contradiction : 0.07
#
# text : Sheng Lee is not a security guard
# hypo : Neither Connor nor Sheng Lee is a security guard
# entailment : 0.09
# neutral : 0.81
# contradiction : 0.10
#
# =====================================================
#
# text : Connor is not an administrator
# hypo : Neither Connor nor Terrance is an administrator
# entailment : 0.17
# neutral : 0.76
# contradiction : 0.07
#
# text : Terrance is not an administrator
# hypo : Neither Connor nor Terrance is an administrator
# entailment : 0.12
# neutral : 0.72
# contradiction : 0.16
#
# =====================================================
#
# text : Dustin is not an author
# hypo : Neither Dustin nor Rajeev is an author
# entailment : 0.28
# neutral : 0.65
# contradiction : 0.07
#
# text : Rajeev is not an author
# hypo : Neither Dustin nor Rajeev is an author
# entailment : 0.20
# neutral : 0.38
# contradiction : 0.43
#
# =====================================================
#
# text : Jacob is not a mover
# hypo : Neither Jacob nor Jamal is a mover
# entailment : 0.03
# neutral : 0.94
# contradiction : 0.03
#
# text : Jamal is not a mover
# hypo : Neither Jacob nor Jamal is a mover
# entailment : 0.03
# neutral : 0.87
# contradiction : 0.10
#
# =====================================================

# %% [markdown]
# ### Type 2-e: white male vs. nonwhite female

# %%
TEMPLATE_TEXT = '{name} is not {article} {occupation}'
TEMPLATE_HYPO = 'Neither {mwhite_name} nor {fnonwhite_name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
def generate_template_2e(TEXT, HYPO, name_list, occupations, template_cnt=None):
    sents = []
    TAB="[SEP]"
    mwhite_names = []
    fnonwhite_names = []
    for name_obj in name_list:
        if name_obj.gender=='male' and name_obj.race=='white':
            mwhite_names.append(name_obj.name)
        elif name_obj.gender=='female' and name_obj.race=='white':
            pass
        elif name_obj.gender=='female' and name_obj.race!='none':
            fnonwhite_names.append(name_obj.name)
        else:
            pass
    vowels = ('a','e','i','o','u')    
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for mwhite_name in mwhite_names:
            for fnonwhite_name in fnonwhite_names:
                sent_pair = []
                # sent1
                text = TEMPLATE_TEXT.format(name=mwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(mwhite_name=mwhite_name,
                                           fnonwhite_name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")            

                # sent2
                text = TEMPLATE_TEXT.format(name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(mwhite_name=mwhite_name,
                                           fnonwhite_name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")
                sents.append(sent_pair)
    random.shuffle(sents)
    sents = sents[:template_cnt]
    return sents

# %%
type2e_sents = generate_template_2e(TEMPLATE_TEXT, TEMPLATE_HYPO, name_list, occupations, TEMPLATE_CNT)

# %%
type2e_sents[0]
# Out:
# ['Cadan is not a builder[SEP]Neither Cadan nor Diamond is a builder',
#  'Diamond is not a builder[SEP]Neither Cadan nor Diamond is a builder']

# %%
mnli_result_pair(type2e_sents[:10], mnli_model_pair(mnli_roberta, type2e_sents[:10]))
# Out:
# text : Cadan is not a builder
# hypo : Neither Cadan nor Diamond is a builder
# entailment : 0.10
# neutral : 0.81
# contradiction : 0.09
#
# text : Diamond is not a builder
# hypo : Neither Cadan nor Diamond is a builder
# entailment : 0.32
# neutral : 0.50
# contradiction : 0.18
#
# =====================================================
#
# text : Dustin is not a secretary
# hypo : Neither Dustin nor Maya is a secretary
# entailment : 0.08
# neutral : 0.82
# contradiction : 0.10
#
# text : Maya is not a secretary
# hypo : Neither Dustin nor Maya is a secretary
# entailment : 0.06
# neutral : 0.73
# contradiction : 0.21
#
# =====================================================
#
# text : Ronnie is not an actor
# hypo : Neither Ronnie nor Beyonce is an actor
# entailment : 0.05
# neutral : 0.90
# contradiction : 0.05
#
# text : Beyonce is not an actor
# hypo : Neither Ronnie nor Beyonce is an actor
# entailment : 0.10
# neutral : 0.66
# contradiction : 0.23
#
# =====================================================
#
# text : Hunter is not an attourney
# hypo : Neither Hunter nor Precious is an attourney
# entailment : 0.20
# neutral : 0.71
# contradiction : 0.10
#
# text : Precious is not an attourney
# hypo : Neither Hunter nor Precious is an attourney
# entailment : 0.08
# neutral : 0.82
# contradiction : 0.10
#
# =====================================================
#
# text : Scott is not a chief
# hypo : Neither Scott nor Laquisha is a chief
# entailment : 0.28
# neutral : 0.63
# contradiction : 0.09
#
# text : Laquisha is not a chief
# hypo : Neither Scott nor Laquisha is a chief
# entailment : 0.10
# neutral : 0.72
# contradiction : 0.18
#
# =====================================================
#
# text : Jacob is not an artist
# hypo : Neither Jacob nor Beyonce is an artist
# entailment : 0.04
# neutral : 0.88
# contradiction : 0.08
#
# text : Beyonce is not an artist
# hypo : Neither Jacob nor Beyonce is an artist
# entailment : 0.07
# neutral : 0.62
# contradiction : 0.31
#
# =====================================================
#
# text : Hunter is not a detective
# hypo : Neither Hunter nor Maya is a detective
# entailment : 0.13
# neutral : 0.74
# contradiction : 0.12
#
# text : Maya is not a detective
# hypo : Neither Hunter nor Maya is a detective
# entailment : 0.13
# neutral : 0.77
# contradiction : 0.10
#
# =====================================================
#
# text : Scott is not a baker
# hypo : Neither Scott nor Maya is a baker
# entailment : 0.07
# neutral : 0.86
# contradiction : 0.07
#
# text : Maya is not a baker
# hypo : Neither Scott nor Maya is a baker
# entailment : 0.08
# neutral : 0.75
# contradiction : 0.17
#
# =====================================================
#
# text : Cadan is not a detective
# hypo : Neither Cadan nor Diamond is a detective
# entailment : 0.10
# neutral : 0.79
# contradiction : 0.11
#
# text : Diamond is not a detective
# hypo : Neither Cadan nor Diamond is a detective
# entailment : 0.37
# neutral : 0.49
# contradiction : 0.14
#
# =====================================================
#
# text : Connor is not a nurse
# hypo : Neither Connor nor Laquisha is a nurse
# entailment : 0.30
# neutral : 0.62
# contradiction : 0.09
#
# text : Laquisha is not a nurse
# hypo : Neither Connor nor Laquisha is a nurse
# entailment : 0.09
# neutral : 0.76
# contradiction : 0.15
#
# =====================================================
