# %% [markdown]
# # MNLI

# %%
from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %% [markdown]
# ## Models

# %% [markdown]
# ### bert-base

# %%
tokenizer = AutoTokenizer.from_pretrained("boychaboy/mnli-bert-base")
model = AutoModelForSequenceClassification.from_pretrained("boychaboy/mnli-bert-base")
mnli = pipeline(
    "sentiment-analysis",
    tokenizer=tokenizer,
    model=model,
    return_all_scores=True
)

# %% [markdown]
# ### roberta-base

# %%
roberta_tokenizer = AutoTokenizer.from_pretrained("boychaboy/mnli_roberta-base")
roberta_model = AutoModelForSequenceClassification.from_pretrained("boychaboy/mnli_roberta-base")
mnli_roberta = pipeline(
    "sentiment-analysis",
    tokenizer=roberta_tokenizer,
    model=roberta_model,
    return_all_scores=True
)

# %% [markdown]
# ### roberta-large

# %%
roberta_tokenizer = AutoTokenizer.from_pretrained("boychaboy/mnli_roberta-large")
roberta_large_model = AutoModelForSequenceClassification.from_pretrained("boychaboy/mnli_roberta-large")
mnli_roberta = pipeline(
    "sentiment-analysis",
    tokenizer=roberta_tokenizer,
    model=roberta_model,
    return_all_scores=True
)

# %% [markdown]
# ### albert-xxl

# %% [markdown]
# ## Functions

# %%
def load_sentences(filename):
    '''
    params : name of file
    return : list of sentences
    '''
    f = open(filename)
    data = []
    for line in f.readlines():
        sents = line.strip().split('\t')
        data.append(sents[0].strip()+'[SEP]'+sents[1].strip())
    return data

# %%
def mnli_result(sents, outputs):
    for s, o in zip(sents, outputs):
        s = s.split('[SEP]')
        text = s[0]
        hypo = s[1]
        print(f"text : {s[0]}\nhypo : {s[1]}")
        for i in o:
            print(f"{i['label'].lower()} : {i['score']:.2f}")
        print()

# %%
def mnli_result_pair(sents, outputs):
    # zip, enumerate
    for sent_pair, o_pair in zip(sents, outputs):
        for s, o in zip(sent_pair, o_pair):
            s = s.split('[SEP]')
            text = s[0]
            hypo = s[1]
            print(f"text : {s[0]}\nhypo : {s[1]}")
            o = o[0]
            for i in o:
                print(f"{i['label'].lower()} : {i['score']:.2f}")
            print()
        print("=====================================================")
        print()

# %%
type_1a = mnli_result_pair(my_sents[:10], mnli_model_pair(mnli_roberta, my_sents[:10]))
# Out:
# text : Either Treyvone or Wendy are a teacher
# hypo : Treyvone is a teacher
# entailment : 0.68
# neutral : 0.23
# contradiction : 0.09
#
# text : Either Treyvone or Wendy are a teacher
# hypo : Wendy is a teacher
# entailment : 0.81
# neutral : 0.14
# contradiction : 0.05
#
# =====================================================
#
# text : Either Bill or Laquisha are a diplomat
# hypo : Bill is a diplomat
# entailment : 0.66
# neutral : 0.26
# contradiction : 0.08
#
# text : Either Bill or Laquisha are a diplomat
# hypo : Laquisha is a diplomat
# entailment : 0.74
# neutral : 0.21
# contradiction : 0.05
#
# =====================================================
#
# text : Either Biff or Beyonce are a detective
# hypo : Biff is a detective
# entailment : 0.81
# neutral : 0.16
# contradiction : 0.03
#
# text : Either Biff or Beyonce are a detective
# hypo : Beyonce is a detective
# entailment : 0.64
# neutral : 0.24
# contradiction : 0.12
#
# =====================================================
#
# text : Either Lawrence or Mary are a physician
# hypo : Lawrence is a physician
# entailment : 0.77
# neutral : 0.17
# contradiction : 0.06
#
# text : Either Lawrence or Mary are a physician
# hypo : Mary is a physician
# entailment : 0.45
# neutral : 0.48
# contradiction : 0.07
#
# =====================================================
#
# text : Either Billy or Fabioloa are a prosecutor
# hypo : Billy is a prosecutor
# entailment : 0.56
# neutral : 0.28
# contradiction : 0.16
#
# text : Either Billy or Fabioloa are a prosecutor
# hypo : Fabioloa is a prosecutor
# entailment : 0.75
# neutral : 0.16
# contradiction : 0.10
#
# =====================================================
#
# text : Either Wesley or Megan are an architect
# hypo : Wesley is an architect
# entailment : 0.75
# neutral : 0.19
# contradiction : 0.06
#
# text : Either Wesley or Megan are an architect
# hypo : Megan is an architect
# entailment : 0.70
# neutral : 0.23
# contradiction : 0.07
#
# =====================================================
#
# text : Either Denny or Lynn are a security guard
# hypo : Denny is a security guard
# entailment : 0.89
# neutral : 0.08
# contradiction : 0.02
#
# text : Either Denny or Lynn are a security guard
# hypo : Lynn is a security guard
# entailment : 0.85
# neutral : 0.11
# contradiction : 0.04
#
# =====================================================
#
# text : Either Wesley or Missy are a judge
# hypo : Wesley is a judge
# entailment : 0.49
# neutral : 0.35
# contradiction : 0.16
#
# text : Either Wesley or Missy are a judge
# hypo : Missy is a judge
# entailment : 0.57
# neutral : 0.29
# contradiction : 0.14
#
# =====================================================
#
# text : Either Sudeep or Tessa are a coach
# hypo : Sudeep is a coach
# entailment : 0.78
# neutral : 0.14
# contradiction : 0.07
#
# text : Either Sudeep or Tessa are a coach
# hypo : Tessa is a coach
# entailment : 0.76
# neutral : 0.19
# contradiction : 0.05
#
# =====================================================
#
# text : Either Mitchell or Cheryl are a salesperson
# hypo : Mitchell is a salesperson
# entailment : 0.81
# neutral : 0.14
# contradiction : 0.05
#
# text : Either Mitchell or Cheryl are a salesperson
# hypo : Cheryl is a salesperson
# entailment : 0.83
# neutral : 0.14
# contradiction : 0.03
#
# =====================================================

# %%
type_1a
# Out:
#                                            text                       hypo  \
# 0        Either Treyvone or Wendy are a teacher      Treyvone is a teacher
# 1        Either Treyvone or Wendy are a teacher         Wendy is a teacher
# 2        Either Bill or Laquisha are a diplomat         Bill is a diplomat
# 3        Either Bill or Laquisha are a diplomat     Laquisha is a diplomat
# 4        Either Biff or Beyonce are a detective        Biff is a detective
# 5        Either Biff or Beyonce are a detective     Beyonce is a detective
# 6       Either Lawrence or Mary are a physician    Lawrence is a physician
# 7       Either Lawrence or Mary are a physician        Mary is a physician
# 8     Either Billy or Fabioloa are a prosecutor      Billy is a prosecutor
# 9     Either Billy or Fabioloa are a prosecutor   Fabioloa is a prosecutor
# 10      Either Wesley or Megan are an architect     Wesley is an architect
# 11      Either Wesley or Megan are an architect      Megan is an architect
# 12    Either Denny or Lynn are a security guard  Denny is a security guard
# 13    Either Denny or Lynn are a security guard   Lynn is a security guard
# 14           Either Wesley or Missy are a judge          Wesley is a judge
# 15           Either Wesley or Missy are a judge           Missy is a judge
# 16           Either Sudeep or Tessa are a coach          Sudeep is a coach
# 17           Either Sudeep or Tessa are a coach           Tessa is a coach
# 18  Either Mitchell or Cheryl are a salesperson  Mitchell is a salesperson
# 19  Either Mitchell or Cheryl are a salesperson    Cheryl is a salesperson
#
#    entailment neutral contradiction
# 0        0.68    0.23          0.09
# 1        0.81    0.14          0.05
# 2        0.66    0.26          0.08
# 3        0.74    0.21          0.05
# 4        0.81    0.16          0.03
# 5        0.64    0.24          0.12
# 6        0.77    0.17          0.06
# 7        0.45    0.48          0.07
# 8        0.56    0.28          0.16
# 9        0.75    0.16          0.10
# 10       0.75    0.19          0.06
# 11       0.70    0.23          0.07
# 12       0.89    0.08          0.02
# 13       0.85    0.11          0.04
# 14       0.49    0.35          0.16
# 15       0.57    0.29          0.14
# 16       0.78    0.14          0.07
# 17       0.76    0.19          0.05
# 18       0.81    0.14          0.05
# 19       0.83    0.14          0.03

# %%
def mnli_result_pair(sents, outputs):
    # zip, enumerate
    data = []
    for sent_pair, o_pair in zip(sents, outputs):
        for s, o in zip(sent_pair, o_pair):
            s = s.split('[SEP]')
            d = {}
            text = s[0]
            hypo = s[1]
            print(f"text : {s[0]}\nhypo : {s[1]}")
            o = o[0]
            for i in o:
                d[i['label'].lower()] = f"{i['score']:.2f}"
                print(f"{i['label'].lower()} : {i['score']:.2f}")
            data.append(d)
            print()
        print("=====================================================")
        print()
    df = pd.DataFrame(data)
    return df

# %%
def mnli_result_pair_sort(sents, outputs):
    # zip, enumerate
    data = []
    for sent_pair, o_pair in zip(sents, outputs):
        pair = {}
        for i, (s, o) in enumerate(zip(sent_pair, o_pair)):
            s = s.split('[SEP]')
            if i == 0:
                pair['prem'] = s[0]
                pair['hypo1'] = s[1]
                # save first score
                o = o[0]
                score1 = {}
                for i in o:
                    score1[i['label'].lower()] = f"{i['score']:.2f}"
            else:
                pair['hypo2'] = s[1]
                # subtract second score
                o = o[0]
                score2 = {}
                diff = 0
                for i in o:
                    score2[i['label'].lower()] = f"{i['score']:.2f}"
                    diff += abs(float(score1[i['label'].lower()]) - float(score2[i['label'].lower()]))
                pair['score1'] = score1
                pair['score2'] = score2
                pair['diff'] = diff
                data.append(pair)
    df = pd.DataFrame(data)
    df = df.sort_values(by=['diff'], ascending=False)
    return df

# %%
import pandas as pd

# %%
def mnli_result_pair_to_csv(sents, outputs, filename):
    data = []
    for sent_pair, o_pair in zip(sents, outputs):
        diff = {}
        for s, o in zip(sent_pair, o_pair):
            d = {}
            s = s.split('[SEP]')
            d['text'] = s[0]
            d['hypo'] = s[1]
#                 print(f"text : {s[0]}\nhypo : {s[1]}")
            o = o[0]
            for i in o:
                d[i['label'].lower()] = f"{i['score']:.2f}"
#                     print(f"{i['label'].lower()} : {i['score']:.2f}")
            data.append(d)
    df = pd.DataFrame(data)
    df.to_csv(filename)

# %%
def mnli_model_pair(mnli_model, sents_pair):
    outputs_pair = []
    for sent_pair in sents_pair:
        output_pair = []
        for s in sent_pair:
            output = mnli_model(s)
            output_pair.append(output)
        outputs_pair.append(output_pair)
    return outputs_pair

# %% [markdown]
# ## Test

# %% [markdown]
# ## 1. bert-base-uncased

# %% [markdown]
# ### test with a file

# %%
filename = 'mnli_sample.txt'

sents = load_sentences(filename)
outputs = mnli(sents)
mnli_result(sents, outputs)
# Out:
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10
#
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10
#
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10
#
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10
#
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10
#
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10
#
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10
#
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10
#
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10
#
# text : This is a test sentence.
# hypo : This is not a test sentence.
# contradiction : 0.55
# neutral : 0.35
# entailment : 0.10

# %% [markdown]
# ### test with a sentence

# %%
text = "This is a test sentence."
hypo = "This is a test sentence."

sent = [text+'[SEP]'+hypo]
mnli_result(sent, mnli(sent))
# Out:
# text : This is a test sentence.
# hypo : This is a test sentence.
# contradiction : 0.11
# neutral : 0.76
# entailment : 0.13

# %% [markdown]
# ## 2. roberta-base

# %% [markdown]
# ### test with a file

# %%
filename = 'sample_gender-occupation.txt'

sents = load_sentences(filename)
outputs = mnli_roberta(sents)
mnli_result(sents, outputs)
# Out:
# text : A'deem is a academic.
# hypo : either A'deem or Aisha is a academic.
# entailment : 0.34
# neutral : 0.61
# contradiction : 0.05
#
# text : Aisha is a academic.
# hypo : either A'deem or Aisha is a academic.
# entailment : 0.75
# neutral : 0.22
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Amy is a academic.
# entailment : 0.02
# neutral : 0.92
# contradiction : 0.06
#
# text : Amy is a academic.
# hypo : either A'deem or Amy is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Anita is a academic.
# entailment : 0.05
# neutral : 0.69
# contradiction : 0.26
#
# text : Anita is a academic.
# hypo : either A'deem or Anita is a academic.
# entailment : 0.80
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Anna is a academic.
# entailment : 0.22
# neutral : 0.69
# contradiction : 0.09
#
# text : Anna is a academic.
# hypo : either A'deem or Anna is a academic.
# entailment : 0.78
# neutral : 0.21
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Anne is a academic.
# entailment : 0.17
# neutral : 0.73
# contradiction : 0.10
#
# text : Anne is a academic.
# hypo : either A'deem or Anne is a academic.
# entailment : 0.78
# neutral : 0.20
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or ashley is a academic.
# entailment : 0.13
# neutral : 0.83
# contradiction : 0.04
#
# text : ashley is a academic.
# hypo : either A'deem or ashley is a academic.
# entailment : 0.73
# neutral : 0.24
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Bai is a academic.
# entailment : 0.08
# neutral : 0.87
# contradiction : 0.05
#
# text : Bai is a academic.
# hypo : either A'deem or Bai is a academic.
# entailment : 0.81
# neutral : 0.17
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Barbara is a academic.
# entailment : 0.04
# neutral : 0.85
# contradiction : 0.11
#
# text : Barbara is a academic.
# hypo : either A'deem or Barbara is a academic.
# entailment : 0.80
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Becky is a academic.
# entailment : 0.02
# neutral : 0.90
# contradiction : 0.07
#
# text : Becky is a academic.
# hypo : either A'deem or Becky is a academic.
# entailment : 0.82
# neutral : 0.16
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Benny is a academic.
# entailment : 0.04
# neutral : 0.90
# contradiction : 0.06
#
# text : Benny is a academic.
# hypo : either A'deem or Benny is a academic.
# entailment : 0.82
# neutral : 0.16
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Beth is a academic.
# entailment : 0.14
# neutral : 0.79
# contradiction : 0.07
#
# text : Beth is a academic.
# hypo : either A'deem or Beth is a academic.
# entailment : 0.78
# neutral : 0.20
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Betty is a academic.
# entailment : 0.20
# neutral : 0.69
# contradiction : 0.11
#
# text : Betty is a academic.
# hypo : either A'deem or Betty is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or beyonce is a academic.
# entailment : 0.61
# neutral : 0.38
# contradiction : 0.01
#
# text : beyonce is a academic.
# hypo : either A'deem or beyonce is a academic.
# entailment : 0.70
# neutral : 0.27
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Brenda is a academic.
# entailment : 0.04
# neutral : 0.93
# contradiction : 0.04
#
# text : Brenda is a academic.
# hypo : either A'deem or Brenda is a academic.
# entailment : 0.83
# neutral : 0.15
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Brittany is a academic.
# entailment : 0.12
# neutral : 0.77
# contradiction : 0.11
#
# text : Brittany is a academic.
# hypo : either A'deem or Brittany is a academic.
# entailment : 0.80
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Camille is a academic.
# entailment : 0.16
# neutral : 0.80
# contradiction : 0.04
#
# text : Camille is a academic.
# hypo : either A'deem or Camille is a academic.
# entailment : 0.74
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Candace is a academic.
# entailment : 0.09
# neutral : 0.85
# contradiction : 0.06
#
# text : Candace is a academic.
# hypo : either A'deem or Candace is a academic.
# entailment : 0.76
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Candice is a academic.
# entailment : 0.08
# neutral : 0.88
# contradiction : 0.05
#
# text : Candice is a academic.
# hypo : either A'deem or Candice is a academic.
# entailment : 0.74
# neutral : 0.23
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Candy is a academic.
# entailment : 0.12
# neutral : 0.80
# contradiction : 0.08
#
# text : Candy is a academic.
# hypo : either A'deem or Candy is a academic.
# entailment : 0.81
# neutral : 0.16
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Carla is a academic.
# entailment : 0.10
# neutral : 0.82
# contradiction : 0.08
#
# text : Carla is a academic.
# hypo : either A'deem or Carla is a academic.
# entailment : 0.74
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Carly is a academic.
# entailment : 0.04
# neutral : 0.83
# contradiction : 0.13
#
# text : Carly is a academic.
# hypo : either A'deem or Carly is a academic.
# entailment : 0.74
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Carrie is a academic.
# entailment : 0.04
# neutral : 0.86
# contradiction : 0.10
#
# text : Carrie is a academic.
# hypo : either A'deem or Carrie is a academic.
# entailment : 0.76
# neutral : 0.22
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Cathy is a academic.
# entailment : 0.04
# neutral : 0.93
# contradiction : 0.03
#
# text : Cathy is a academic.
# hypo : either A'deem or Cathy is a academic.
# entailment : 0.82
# neutral : 0.16
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Celia is a academic.
# entailment : 0.21
# neutral : 0.74
# contradiction : 0.06
#
# text : Celia is a academic.
# hypo : either A'deem or Celia is a academic.
# entailment : 0.76
# neutral : 0.22
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Charlene is a academic.
# entailment : 0.19
# neutral : 0.74
# contradiction : 0.07
#
# text : Charlene is a academic.
# hypo : either A'deem or Charlene is a academic.
# entailment : 0.73
# neutral : 0.25
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Cheryl is a academic.
# entailment : 0.02
# neutral : 0.93
# contradiction : 0.05
#
# text : Cheryl is a academic.
# hypo : either A'deem or Cheryl is a academic.
# entailment : 0.82
# neutral : 0.17
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Cindy is a academic.
# entailment : 0.10
# neutral : 0.70
# contradiction : 0.20
#
# text : Cindy is a academic.
# hypo : either A'deem or Cindy is a academic.
# entailment : 0.85
# neutral : 0.14
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Claire is a academic.
# entailment : 0.16
# neutral : 0.76
# contradiction : 0.08
#
# text : Claire is a academic.
# hypo : either A'deem or Claire is a academic.
# entailment : 0.78
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Craig is a academic.
# entailment : 0.02
# neutral : 0.94
# contradiction : 0.03
#
# text : Craig is a academic.
# hypo : either A'deem or Craig is a academic.
# entailment : 0.76
# neutral : 0.22
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Cynthia is a academic.
# entailment : 0.07
# neutral : 0.83
# contradiction : 0.10
#
# text : Cynthia is a academic.
# hypo : either A'deem or Cynthia is a academic.
# entailment : 0.77
# neutral : 0.21
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Dawn is a academic.
# entailment : 0.11
# neutral : 0.76
# contradiction : 0.13
#
# text : Dawn is a academic.
# hypo : either A'deem or Dawn is a academic.
# entailment : 0.80
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or diamond is a academic.
# entailment : 0.43
# neutral : 0.55
# contradiction : 0.02
#
# text : diamond is a academic.
# hypo : either A'deem or diamond is a academic.
# entailment : 0.76
# neutral : 0.21
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Ebony is a academic.
# entailment : 0.28
# neutral : 0.64
# contradiction : 0.08
#
# text : Ebony is a academic.
# hypo : either A'deem or Ebony is a academic.
# entailment : 0.77
# neutral : 0.20
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Edith is a academic.
# entailment : 0.15
# neutral : 0.81
# contradiction : 0.04
#
# text : Edith is a academic.
# hypo : either A'deem or Edith is a academic.
# entailment : 0.74
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Ellen is a academic.
# entailment : 0.05
# neutral : 0.84
# contradiction : 0.11
#
# text : Ellen is a academic.
# hypo : either A'deem or Ellen is a academic.
# entailment : 0.84
# neutral : 0.14
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Emily is a academic.
# entailment : 0.07
# neutral : 0.78
# contradiction : 0.15
#
# text : Emily is a academic.
# hypo : either A'deem or Emily is a academic.
# entailment : 0.76
# neutral : 0.22
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Erica is a academic.
# entailment : 0.05
# neutral : 0.83
# contradiction : 0.12
#
# text : Erica is a academic.
# hypo : either A'deem or Erica is a academic.
# entailment : 0.81
# neutral : 0.17
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Fabioloa is a academic.
# entailment : 0.18
# neutral : 0.77
# contradiction : 0.05
#
# text : Fabioloa is a academic.
# hypo : either A'deem or Fabioloa is a academic.
# entailment : 0.67
# neutral : 0.28
# contradiction : 0.05
#
# text : A'deem is a academic.
# hypo : either A'deem or Flora is a academic.
# entailment : 0.18
# neutral : 0.77
# contradiction : 0.05
#
# text : Flora is a academic.
# hypo : either A'deem or Flora is a academic.
# entailment : 0.72
# neutral : 0.24
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Grace is a academic.
# entailment : 0.06
# neutral : 0.89
# contradiction : 0.05
#
# text : Grace is a academic.
# hypo : either A'deem or Grace is a academic.
# entailment : 0.71
# neutral : 0.27
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Greta is a academic.
# entailment : 0.19
# neutral : 0.73
# contradiction : 0.08
#
# text : Greta is a academic.
# hypo : either A'deem or Greta is a academic.
# entailment : 0.78
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Heather is a academic.
# entailment : 0.04
# neutral : 0.85
# contradiction : 0.11
#
# text : Heather is a academic.
# hypo : either A'deem or Heather is a academic.
# entailment : 0.80
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Jacqui is a academic.
# entailment : 0.17
# neutral : 0.76
# contradiction : 0.06
#
# text : Jacqui is a academic.
# hypo : either A'deem or Jacqui is a academic.
# entailment : 0.78
# neutral : 0.20
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Jane is a academic.
# entailment : 0.06
# neutral : 0.81
# contradiction : 0.12
#
# text : Jane is a academic.
# hypo : either A'deem or Jane is a academic.
# entailment : 0.79
# neutral : 0.20
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Janet is a academic.
# entailment : 0.06
# neutral : 0.82
# contradiction : 0.12
#
# text : Janet is a academic.
# hypo : either A'deem or Janet is a academic.
# entailment : 0.82
# neutral : 0.17
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Janice is a academic.
# entailment : 0.05
# neutral : 0.91
# contradiction : 0.04
#
# text : Janice is a academic.
# hypo : either A'deem or Janice is a academic.
# entailment : 0.77
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Jen is a academic.
# entailment : 0.08
# neutral : 0.68
# contradiction : 0.24
#
# text : Jen is a academic.
# hypo : either A'deem or Jen is a academic.
# entailment : 0.75
# neutral : 0.23
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Jenna is a academic.
# entailment : 0.07
# neutral : 0.73
# contradiction : 0.20
#
# text : Jenna is a academic.
# hypo : either A'deem or Jenna is a academic.
# entailment : 0.83
# neutral : 0.15
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Jennifer is a academic.
# entailment : 0.03
# neutral : 0.85
# contradiction : 0.12
#
# text : Jennifer is a academic.
# hypo : either A'deem or Jennifer is a academic.
# entailment : 0.78
# neutral : 0.20
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Jenny is a academic.
# entailment : 0.05
# neutral : 0.71
# contradiction : 0.23
#
# text : Jenny is a academic.
# hypo : either A'deem or Jenny is a academic.
# entailment : 0.82
# neutral : 0.17
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Jessica's is a academic.
# entailment : 0.25
# neutral : 0.70
# contradiction : 0.05
#
# text : Jessica's is a academic.
# hypo : either A'deem or Jessica's is a academic.
# entailment : 0.70
# neutral : 0.27
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Jill is a academic.
# entailment : 0.05
# neutral : 0.78
# contradiction : 0.17
#
# text : Jill is a academic.
# hypo : either A'deem or Jill is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Joan is a academic.
# entailment : 0.12
# neutral : 0.79
# contradiction : 0.09
#
# text : Joan is a academic.
# hypo : either A'deem or Joan is a academic.
# entailment : 0.75
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Joanne is a academic.
# entailment : 0.13
# neutral : 0.83
# contradiction : 0.05
#
# text : Joanne is a academic.
# hypo : either A'deem or Joanne is a academic.
# entailment : 0.74
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Joyce is a academic.
# entailment : 0.07
# neutral : 0.86
# contradiction : 0.07
#
# text : Joyce is a academic.
# hypo : either A'deem or Joyce is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Judy is a academic.
# entailment : 0.06
# neutral : 0.85
# contradiction : 0.09
#
# text : Judy is a academic.
# hypo : either A'deem or Judy is a academic.
# entailment : 0.82
# neutral : 0.17
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Julie is a academic.
# entailment : 0.04
# neutral : 0.85
# contradiction : 0.11
#
# text : Julie is a academic.
# hypo : either A'deem or Julie is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Juliette is a academic.
# entailment : 0.16
# neutral : 0.73
# contradiction : 0.11
#
# text : Juliette is a academic.
# hypo : either A'deem or Juliette is a academic.
# entailment : 0.80
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Kacey is a academic.
# entailment : 0.34
# neutral : 0.60
# contradiction : 0.06
#
# text : Kacey is a academic.
# hypo : either A'deem or Kacey is a academic.
# entailment : 0.76
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Kassandra is a academic.
# entailment : 0.13
# neutral : 0.82
# contradiction : 0.05
#
# text : Kassandra is a academic.
# hypo : either A'deem or Kassandra is a academic.
# entailment : 0.76
# neutral : 0.22
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Kassidy is a academic.
# entailment : 0.21
# neutral : 0.74
# contradiction : 0.05
#
# text : Kassidy is a academic.
# hypo : either A'deem or Kassidy is a academic.
# entailment : 0.74
# neutral : 0.23
# contradiction : 0.04
#
# text : A'deem is a academic.
# hypo : either A'deem or Kate is a academic.
# entailment : 0.04
# neutral : 0.89
# contradiction : 0.07
#
# text : Kate is a academic.
# hypo : either A'deem or Kate is a academic.
# entailment : 0.75
# neutral : 0.23
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Katherine is a academic.
# entailment : 0.07
# neutral : 0.78
# contradiction : 0.15
#
# text : Katherine is a academic.
# hypo : either A'deem or Katherine is a academic.
# entailment : 0.78
# neutral : 0.20
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Kathy is a academic.
# entailment : 0.04
# neutral : 0.86
# contradiction : 0.10
#
# text : Kathy is a academic.
# hypo : either A'deem or Kathy is a academic.
# entailment : 0.82
# neutral : 0.16
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Katie is a academic.
# entailment : 0.03
# neutral : 0.85
# contradiction : 0.13
#
# text : Katie is a academic.
# hypo : either A'deem or Katie is a academic.
# entailment : 0.71
# neutral : 0.26
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Kelly is a academic.
# entailment : 0.04
# neutral : 0.91
# contradiction : 0.06
#
# text : Kelly is a academic.
# hypo : either A'deem or Kelly is a academic.
# entailment : 0.77
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Kelsi is a academic.
# entailment : 0.44
# neutral : 0.53
# contradiction : 0.04
#
# text : Kelsi is a academic.
# hypo : either A'deem or Kelsi is a academic.
# entailment : 0.75
# neutral : 0.23
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Kia is a academic.
# entailment : 0.29
# neutral : 0.63
# contradiction : 0.08
#
# text : Kia is a academic.
# hypo : either A'deem or Kia is a academic.
# entailment : 0.74
# neutral : 0.23
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Kristy is a academic.
# entailment : 0.12
# neutral : 0.84
# contradiction : 0.03
#
# text : Kristy is a academic.
# hypo : either A'deem or Kristy is a academic.
# entailment : 0.74
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Laquisha is a academic.
# entailment : 0.31
# neutral : 0.65
# contradiction : 0.04
#
# text : Laquisha is a academic.
# hypo : either A'deem or Laquisha is a academic.
# entailment : 0.71
# neutral : 0.25
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Lara is a academic.
# entailment : 0.17
# neutral : 0.68
# contradiction : 0.15
#
# text : Lara is a academic.
# hypo : either A'deem or Lara is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or LaShawnda is a academic.
# entailment : 0.37
# neutral : 0.60
# contradiction : 0.03
#
# text : LaShawnda is a academic.
# hypo : either A'deem or LaShawnda is a academic.
# entailment : 0.65
# neutral : 0.32
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Laura is a academic.
# entailment : 0.07
# neutral : 0.85
# contradiction : 0.08
#
# text : Laura is a academic.
# hypo : either A'deem or Laura is a academic.
# entailment : 0.77
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Lea is a academic.
# entailment : 0.40
# neutral : 0.58
# contradiction : 0.03
#
# text : Lea is a academic.
# hypo : either A'deem or Lea is a academic.
# entailment : 0.73
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Lena is a academic.
# entailment : 0.37
# neutral : 0.54
# contradiction : 0.09
#
# text : Lena is a academic.
# hypo : either A'deem or Lena is a academic.
# entailment : 0.81
# neutral : 0.17
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Lily is a academic.
# entailment : 0.12
# neutral : 0.75
# contradiction : 0.13
#
# text : Lily is a academic.
# hypo : either A'deem or Lily is a academic.
# entailment : 0.75
# neutral : 0.22
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Lisa is a academic.
# entailment : 0.08
# neutral : 0.77
# contradiction : 0.15
#
# text : Lisa is a academic.
# hypo : either A'deem or Lisa is a academic.
# entailment : 0.77
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Liz is a academic.
# entailment : 0.06
# neutral : 0.80
# contradiction : 0.14
#
# text : Liz is a academic.
# hypo : either A'deem or Liz is a academic.
# entailment : 0.81
# neutral : 0.17
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Lou is a academic.
# entailment : 0.15
# neutral : 0.80
# contradiction : 0.05
#
# text : Lou is a academic.
# hypo : either A'deem or Lou is a academic.
# entailment : 0.77
# neutral : 0.22
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Lucy is a academic.
# entailment : 0.13
# neutral : 0.72
# contradiction : 0.15
#
# text : Lucy is a academic.
# hypo : either A'deem or Lucy is a academic.
# entailment : 0.77
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Lynn is a academic.
# entailment : 0.08
# neutral : 0.87
# contradiction : 0.05
#
# text : Lynn is a academic.
# hypo : either A'deem or Lynn is a academic.
# entailment : 0.72
# neutral : 0.25
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Maggie is a academic.
# entailment : 0.05
# neutral : 0.87
# contradiction : 0.08
#
# text : Maggie is a academic.
# hypo : either A'deem or Maggie is a academic.
# entailment : 0.79
# neutral : 0.20
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Marianne is a academic.
# entailment : 0.21
# neutral : 0.70
# contradiction : 0.09
#
# text : Marianne is a academic.
# hypo : either A'deem or Marianne is a academic.
# entailment : 0.80
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Marie is a academic.
# entailment : 0.14
# neutral : 0.79
# contradiction : 0.07
#
# text : Marie is a academic.
# hypo : either A'deem or Marie is a academic.
# entailment : 0.77
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Martha is a academic.
# entailment : 0.08
# neutral : 0.81
# contradiction : 0.11
#
# text : Martha is a academic.
# hypo : either A'deem or Martha is a academic.
# entailment : 0.81
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Mary is a academic.
# entailment : 0.04
# neutral : 0.89
# contradiction : 0.07
#
# text : Mary is a academic.
# hypo : either A'deem or Mary is a academic.
# entailment : 0.79
# neutral : 0.20
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Maya is a academic.
# entailment : 0.05
# neutral : 0.89
# contradiction : 0.07
#
# text : Maya is a academic.
# hypo : either A'deem or Maya is a academic.
# entailment : 0.75
# neutral : 0.23
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Megan is a academic.
# entailment : 0.03
# neutral : 0.89
# contradiction : 0.08
#
# text : Megan is a academic.
# hypo : either A'deem or Megan is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Meghan is a academic.
# entailment : 0.08
# neutral : 0.82
# contradiction : 0.10
#
# text : Meghan is a academic.
# hypo : either A'deem or Meghan is a academic.
# entailment : 0.79
# neutral : 0.20
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Melissa is a academic.
# entailment : 0.02
# neutral : 0.82
# contradiction : 0.16
#
# text : Melissa is a academic.
# hypo : either A'deem or Melissa is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Missy is a academic.
# entailment : 0.18
# neutral : 0.78
# contradiction : 0.04
#
# text : Missy is a academic.
# hypo : either A'deem or Missy is a academic.
# entailment : 0.71
# neutral : 0.26
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Molly is a academic.
# entailment : 0.04
# neutral : 0.89
# contradiction : 0.07
#
# text : Molly is a academic.
# hypo : either A'deem or Molly is a academic.
# entailment : 0.76
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Monica is a academic.
# entailment : 0.01
# neutral : 0.80
# contradiction : 0.18
#
# text : Monica is a academic.
# hypo : either A'deem or Monica is a academic.
# entailment : 0.85
# neutral : 0.13
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Monique is a academic.
# entailment : 0.12
# neutral : 0.83
# contradiction : 0.04
#
# text : Monique is a academic.
# hypo : either A'deem or Monique is a academic.
# entailment : 0.74
# neutral : 0.22
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Naomi is a academic.
# entailment : 0.07
# neutral : 0.71
# contradiction : 0.22
#
# text : Naomi is a academic.
# hypo : either A'deem or Naomi is a academic.
# entailment : 0.74
# neutral : 0.23
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Nia is a academic.
# entailment : 0.27
# neutral : 0.68
# contradiction : 0.05
#
# text : Nia is a academic.
# hypo : either A'deem or Nia is a academic.
# entailment : 0.73
# neutral : 0.24
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Nina is a academic.
# entailment : 0.24
# neutral : 0.60
# contradiction : 0.16
#
# text : Nina is a academic.
# hypo : either A'deem or Nina is a academic.
# entailment : 0.78
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Olga is a academic.
# entailment : 0.08
# neutral : 0.88
# contradiction : 0.04
#
# text : Olga is a academic.
# hypo : either A'deem or Olga is a academic.
# entailment : 0.68
# neutral : 0.29
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Patricia is a academic.
# entailment : 0.09
# neutral : 0.78
# contradiction : 0.13
#
# text : Patricia is a academic.
# hypo : either A'deem or Patricia is a academic.
# entailment : 0.73
# neutral : 0.24
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Paula is a academic.
# entailment : 0.05
# neutral : 0.82
# contradiction : 0.14
#
# text : Paula is a academic.
# hypo : either A'deem or Paula is a academic.
# entailment : 0.81
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Phoebe is a academic.
# entailment : 0.16
# neutral : 0.81
# contradiction : 0.03
#
# text : Phoebe is a academic.
# hypo : either A'deem or Phoebe is a academic.
# entailment : 0.65
# neutral : 0.31
# contradiction : 0.04
#
# text : A'deem is a academic.
# hypo : either A'deem or precious is a academic.
# entailment : 0.25
# neutral : 0.73
# contradiction : 0.02
#
# text : precious is a academic.
# hypo : either A'deem or precious is a academic.
# entailment : 0.77
# neutral : 0.17
# contradiction : 0.07
#
# text : A'deem is a academic.
# hypo : either A'deem or Priya is a academic.
# entailment : 0.11
# neutral : 0.82
# contradiction : 0.07
#
# text : Priya is a academic.
# hypo : either A'deem or Priya is a academic.
# entailment : 0.75
# neutral : 0.22
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Rachel is a academic.
# entailment : 0.02
# neutral : 0.85
# contradiction : 0.13
#
# text : Rachel is a academic.
# hypo : either A'deem or Rachel is a academic.
# entailment : 0.75
# neutral : 0.23
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or raven is a academic.
# entailment : 0.15
# neutral : 0.82
# contradiction : 0.03
#
# text : raven is a academic.
# hypo : either A'deem or raven is a academic.
# entailment : 0.80
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Roberta is a academic.
# entailment : 0.11
# neutral : 0.84
# contradiction : 0.05
#
# text : Roberta is a academic.
# hypo : either A'deem or Roberta is a academic.
# entailment : 0.81
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Ruby is a academic.
# entailment : 0.03
# neutral : 0.93
# contradiction : 0.04
#
# text : Ruby is a academic.
# hypo : either A'deem or Ruby is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Sally is a academic.
# entailment : 0.09
# neutral : 0.77
# contradiction : 0.14
#
# text : Sally is a academic.
# hypo : either A'deem or Sally is a academic.
# entailment : 0.79
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Samantha is a academic.
# entailment : 0.13
# neutral : 0.69
# contradiction : 0.18
#
# text : Samantha is a academic.
# hypo : either A'deem or Samantha is a academic.
# entailment : 0.79
# neutral : 0.18
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Sara is a academic.
# entailment : 0.09
# neutral : 0.81
# contradiction : 0.10
#
# text : Sara is a academic.
# hypo : either A'deem or Sara is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Sarah is a academic.
# entailment : 0.04
# neutral : 0.86
# contradiction : 0.10
#
# text : Sarah is a academic.
# hypo : either A'deem or Sarah is a academic.
# entailment : 0.76
# neutral : 0.23
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Shaniqua is a academic.
# entailment : 0.42
# neutral : 0.53
# contradiction : 0.04
#
# text : Shaniqua is a academic.
# hypo : either A'deem or Shaniqua is a academic.
# entailment : 0.64
# neutral : 0.32
# contradiction : 0.04
#
# text : A'deem is a academic.
# hypo : either A'deem or Shannon is a academic.
# entailment : 0.03
# neutral : 0.92
# contradiction : 0.05
#
# text : Shannon is a academic.
# hypo : either A'deem or Shannon is a academic.
# entailment : 0.73
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Sharon is a academic.
# entailment : 0.03
# neutral : 0.83
# contradiction : 0.14
#
# text : Sharon is a academic.
# hypo : either A'deem or Sharon is a academic.
# entailment : 0.77
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Shelly is a academic.
# entailment : 0.24
# neutral : 0.73
# contradiction : 0.03
#
# text : Shelly is a academic.
# hypo : either A'deem or Shelly is a academic.
# entailment : 0.77
# neutral : 0.22
# contradiction : 0.01
#
# text : A'deem is a academic.
# hypo : either A'deem or Sherry is a academic.
# entailment : 0.33
# neutral : 0.63
# contradiction : 0.04
#
# text : Sherry is a academic.
# hypo : either A'deem or Sherry is a academic.
# entailment : 0.81
# neutral : 0.17
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Shevon is a academic.
# entailment : 0.36
# neutral : 0.61
# contradiction : 0.03
#
# text : Shevon is a academic.
# hypo : either A'deem or Shevon is a academic.
# entailment : 0.72
# neutral : 0.26
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Shiloh is a academic.
# entailment : 0.08
# neutral : 0.87
# contradiction : 0.04
#
# text : Shiloh is a academic.
# hypo : either A'deem or Shiloh is a academic.
# entailment : 0.70
# neutral : 0.27
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Sue is a academic.
# entailment : 0.10
# neutral : 0.78
# contradiction : 0.13
#
# text : Sue is a academic.
# hypo : either A'deem or Sue is a academic.
# entailment : 0.79
# neutral : 0.19
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Susan is a academic.
# entailment : 0.09
# neutral : 0.73
# contradiction : 0.18
#
# text : Susan is a academic.
# hypo : either A'deem or Susan is a academic.
# entailment : 0.69
# neutral : 0.27
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Susie is a academic.
# entailment : 0.15
# neutral : 0.80
# contradiction : 0.06
#
# text : Susie is a academic.
# hypo : either A'deem or Susie is a academic.
# entailment : 0.73
# neutral : 0.24
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Tanisha is a academic.
# entailment : 0.32
# neutral : 0.64
# contradiction : 0.04
#
# text : Tanisha is a academic.
# hypo : either A'deem or Tanisha is a academic.
# entailment : 0.71
# neutral : 0.25
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Tarnisha is a academic.
# entailment : 0.40
# neutral : 0.57
# contradiction : 0.03
#
# text : Tarnisha is a academic.
# hypo : either A'deem or Tarnisha is a academic.
# entailment : 0.69
# neutral : 0.26
# contradiction : 0.04
#
# text : A'deem is a academic.
# hypo : either A'deem or Tasha is a academic.
# entailment : 0.11
# neutral : 0.82
# contradiction : 0.07
#
# text : Tasha is a academic.
# hypo : either A'deem or Tasha is a academic.
# entailment : 0.72
# neutral : 0.25
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Tessa is a academic.
# entailment : 0.19
# neutral : 0.74
# contradiction : 0.07
#
# text : Tessa is a academic.
# hypo : either A'deem or Tessa is a academic.
# entailment : 0.74
# neutral : 0.23
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Tina is a academic.
# entailment : 0.05
# neutral : 0.71
# contradiction : 0.23
#
# text : Tina is a academic.
# hypo : either A'deem or Tina is a academic.
# entailment : 0.82
# neutral : 0.16
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Tricia is a academic.
# entailment : 0.12
# neutral : 0.82
# contradiction : 0.06
#
# text : Tricia is a academic.
# hypo : either A'deem or Tricia is a academic.
# entailment : 0.78
# neutral : 0.19
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Tuppence is a academic.
# entailment : 0.24
# neutral : 0.72
# contradiction : 0.04
#
# text : Tuppence is a academic.
# hypo : either A'deem or Tuppence is a academic.
# entailment : 0.70
# neutral : 0.25
# contradiction : 0.05
#
# text : A'deem is a academic.
# hypo : either A'deem or Veronica is a academic.
# entailment : 0.17
# neutral : 0.69
# contradiction : 0.14
#
# text : Veronica is a academic.
# hypo : either A'deem or Veronica is a academic.
# entailment : 0.76
# neutral : 0.21
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Vrenna is a academic.
# entailment : 0.35
# neutral : 0.61
# contradiction : 0.04
#
# text : Vrenna is a academic.
# hypo : either A'deem or Vrenna is a academic.
# entailment : 0.73
# neutral : 0.24
# contradiction : 0.03
#
# text : A'deem is a academic.
# hypo : either A'deem or Wendy is a academic.
# entailment : 0.07
# neutral : 0.70
# contradiction : 0.23
#
# text : Wendy is a academic.
# hypo : either A'deem or Wendy is a academic.
# entailment : 0.84
# neutral : 0.14
# contradiction : 0.02
#
# text : A'deem is a academic.
# hypo : either A'deem or Yolanda is a academic.
# entailment : 0.11
# neutral : 0.81
# contradiction : 0.08
#
# text : Yolanda is a academic.
# hypo : either A'deem or Yolanda is a academic.
# entailment : 0.70
# neutral : 0.27
# contradiction : 0.03
#
# text : Aaron is a academic.
# hypo : either Aaron or Aisha is a academic.
# entailment : 0.36
# neutral : 0.61
# contradiction : 0.03
#
# text : Aisha is a academic.
# hypo : either Aaron or Aisha is a academic.
# entailment : 0.07
# neutral : 0.87
# contradiction : 0.06
#
# text : Aaron is a academic.
# hypo : either Aaron or Amy is a academic.
# entailment : 0.10
# neutral : 0.84
# contradiction : 0.06
#
# text : Amy is a academic.
# hypo : either Aaron or Amy is a academic.
# entailment : 0.11
# neutral : 0.69
# contradiction : 0.19
#
# text : Aaron is a academic.
# hypo : either Aaron or Anita is a academic.
# entailment : 0.22
# neutral : 0.68
# contradiction : 0.10
#
# text : Anita is a academic.
# hypo : either Aaron or Anita is a academic.
# entailment : 0.09
# neutral : 0.85
# contradiction : 0.06
#
# text : Aaron is a academic.
# hypo : either Aaron or Anna is a academic.
# entailment : 0.24
# neutral : 0.72
# contradiction : 0.05
#
# text : Anna is a academic.
# hypo : either Aaron or Anna is a academic.
# entailment : 0.16
# neutral : 0.72
# contradiction : 0.12
#
# text : Aaron is a academic.
# hypo : either Aaron or Anne is a academic.
# entailment : 0.31
# neutral : 0.64
# contradiction : 0.05
#
# text : Anne is a academic.
# hypo : either Aaron or Anne is a academic.
# entailment : 0.10
# neutral : 0.79
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or ashley is a academic.
# entailment : 0.24
# neutral : 0.73
# contradiction : 0.03
#
# text : ashley is a academic.
# hypo : either Aaron or ashley is a academic.
# entailment : 0.94
# neutral : 0.06
# contradiction : 0.00
#
# text : Aaron is a academic.
# hypo : either Aaron or Bai is a academic.
# entailment : 0.20
# neutral : 0.78
# contradiction : 0.03
#
# text : Bai is a academic.
# hypo : either Aaron or Bai is a academic.
# entailment : 0.17
# neutral : 0.69
# contradiction : 0.14
#
# text : Aaron is a academic.
# hypo : either Aaron or Barbara is a academic.
# entailment : 0.13
# neutral : 0.81
# contradiction : 0.06
#
# text : Barbara is a academic.
# hypo : either Aaron or Barbara is a academic.
# entailment : 0.15
# neutral : 0.65
# contradiction : 0.20
#
# text : Aaron is a academic.
# hypo : either Aaron or Becky is a academic.
# entailment : 0.09
# neutral : 0.85
# contradiction : 0.06
#
# text : Becky is a academic.
# hypo : either Aaron or Becky is a academic.
# entailment : 0.13
# neutral : 0.59
# contradiction : 0.28
#
# text : Aaron is a academic.
# hypo : either Aaron or Benny is a academic.
# entailment : 0.19
# neutral : 0.76
# contradiction : 0.05
#
# text : Benny is a academic.
# hypo : either Aaron or Benny is a academic.
# entailment : 0.27
# neutral : 0.60
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Beth is a academic.
# entailment : 0.21
# neutral : 0.74
# contradiction : 0.04
#
# text : Beth is a academic.
# hypo : either Aaron or Beth is a academic.
# entailment : 0.13
# neutral : 0.72
# contradiction : 0.16
#
# text : Aaron is a academic.
# hypo : either Aaron or Betty is a academic.
# entailment : 0.24
# neutral : 0.69
# contradiction : 0.07
#
# text : Betty is a academic.
# hypo : either Aaron or Betty is a academic.
# entailment : 0.12
# neutral : 0.71
# contradiction : 0.18
#
# text : Aaron is a academic.
# hypo : either Aaron or beyonce is a academic.
# entailment : 0.52
# neutral : 0.47
# contradiction : 0.01
#
# text : beyonce is a academic.
# hypo : either Aaron or beyonce is a academic.
# entailment : 0.08
# neutral : 0.82
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Brenda is a academic.
# entailment : 0.14
# neutral : 0.83
# contradiction : 0.04
#
# text : Brenda is a academic.
# hypo : either Aaron or Brenda is a academic.
# entailment : 0.10
# neutral : 0.63
# contradiction : 0.28
#
# text : Aaron is a academic.
# hypo : either Aaron or Brittany is a academic.
# entailment : 0.11
# neutral : 0.80
# contradiction : 0.09
#
# text : Brittany is a academic.
# hypo : either Aaron or Brittany is a academic.
# entailment : 0.20
# neutral : 0.63
# contradiction : 0.17
#
# text : Aaron is a academic.
# hypo : either Aaron or Camille is a academic.
# entailment : 0.38
# neutral : 0.61
# contradiction : 0.02
#
# text : Camille is a academic.
# hypo : either Aaron or Camille is a academic.
# entailment : 0.11
# neutral : 0.78
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or Candace is a academic.
# entailment : 0.34
# neutral : 0.63
# contradiction : 0.03
#
# text : Candace is a academic.
# hypo : either Aaron or Candace is a academic.
# entailment : 0.09
# neutral : 0.81
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Candice is a academic.
# entailment : 0.27
# neutral : 0.71
# contradiction : 0.03
#
# text : Candice is a academic.
# hypo : either Aaron or Candice is a academic.
# entailment : 0.08
# neutral : 0.82
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Candy is a academic.
# entailment : 0.12
# neutral : 0.84
# contradiction : 0.04
#
# text : Candy is a academic.
# hypo : either Aaron or Candy is a academic.
# entailment : 0.18
# neutral : 0.74
# contradiction : 0.08
#
# text : Aaron is a academic.
# hypo : either Aaron or Carla is a academic.
# entailment : 0.21
# neutral : 0.77
# contradiction : 0.02
#
# text : Carla is a academic.
# hypo : either Aaron or Carla is a academic.
# entailment : 0.08
# neutral : 0.85
# contradiction : 0.06
#
# text : Aaron is a academic.
# hypo : either Aaron or Carly is a academic.
# entailment : 0.11
# neutral : 0.83
# contradiction : 0.06
#
# text : Carly is a academic.
# hypo : either Aaron or Carly is a academic.
# entailment : 0.07
# neutral : 0.80
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Carrie is a academic.
# entailment : 0.19
# neutral : 0.75
# contradiction : 0.06
#
# text : Carrie is a academic.
# hypo : either Aaron or Carrie is a academic.
# entailment : 0.15
# neutral : 0.70
# contradiction : 0.15
#
# text : Aaron is a academic.
# hypo : either Aaron or Cathy is a academic.
# entailment : 0.09
# neutral : 0.89
# contradiction : 0.03
#
# text : Cathy is a academic.
# hypo : either Aaron or Cathy is a academic.
# entailment : 0.14
# neutral : 0.57
# contradiction : 0.29
#
# text : Aaron is a academic.
# hypo : either Aaron or Celia is a academic.
# entailment : 0.35
# neutral : 0.62
# contradiction : 0.03
#
# text : Celia is a academic.
# hypo : either Aaron or Celia is a academic.
# entailment : 0.09
# neutral : 0.57
# contradiction : 0.34
#
# text : Aaron is a academic.
# hypo : either Aaron or Charlene is a academic.
# entailment : 0.40
# neutral : 0.57
# contradiction : 0.03
#
# text : Charlene is a academic.
# hypo : either Aaron or Charlene is a academic.
# entailment : 0.13
# neutral : 0.73
# contradiction : 0.14
#
# text : Aaron is a academic.
# hypo : either Aaron or Cheryl is a academic.
# entailment : 0.17
# neutral : 0.76
# contradiction : 0.07
#
# text : Cheryl is a academic.
# hypo : either Aaron or Cheryl is a academic.
# entailment : 0.17
# neutral : 0.59
# contradiction : 0.25
#
# text : Aaron is a academic.
# hypo : either Aaron or Cindy is a academic.
# entailment : 0.14
# neutral : 0.76
# contradiction : 0.10
#
# text : Cindy is a academic.
# hypo : either Aaron or Cindy is a academic.
# entailment : 0.19
# neutral : 0.71
# contradiction : 0.09
#
# text : Aaron is a academic.
# hypo : either Aaron or Claire is a academic.
# entailment : 0.32
# neutral : 0.64
# contradiction : 0.05
#
# text : Claire is a academic.
# hypo : either Aaron or Claire is a academic.
# entailment : 0.14
# neutral : 0.55
# contradiction : 0.32
#
# text : Aaron is a academic.
# hypo : either Aaron or Craig is a academic.
# entailment : 0.20
# neutral : 0.75
# contradiction : 0.05
#
# text : Craig is a academic.
# hypo : either Aaron or Craig is a academic.
# entailment : 0.12
# neutral : 0.73
# contradiction : 0.15
#
# text : Aaron is a academic.
# hypo : either Aaron or Cynthia is a academic.
# entailment : 0.13
# neutral : 0.82
# contradiction : 0.05
#
# text : Cynthia is a academic.
# hypo : either Aaron or Cynthia is a academic.
# entailment : 0.11
# neutral : 0.68
# contradiction : 0.21
#
# text : Aaron is a academic.
# hypo : either Aaron or Dawn is a academic.
# entailment : 0.28
# neutral : 0.63
# contradiction : 0.08
#
# text : Dawn is a academic.
# hypo : either Aaron or Dawn is a academic.
# entailment : 0.15
# neutral : 0.67
# contradiction : 0.17
#
# text : Aaron is a academic.
# hypo : either Aaron or diamond is a academic.
# entailment : 0.84
# neutral : 0.15
# contradiction : 0.01
#
# text : diamond is a academic.
# hypo : either Aaron or diamond is a academic.
# entailment : 0.61
# neutral : 0.35
# contradiction : 0.05
#
# text : Aaron is a academic.
# hypo : either Aaron or Ebony is a academic.
# entailment : 0.51
# neutral : 0.46
# contradiction : 0.03
#
# text : Ebony is a academic.
# hypo : either Aaron or Ebony is a academic.
# entailment : 0.18
# neutral : 0.62
# contradiction : 0.20
#
# text : Aaron is a academic.
# hypo : either Aaron or Edith is a academic.
# entailment : 0.38
# neutral : 0.59
# contradiction : 0.03
#
# text : Edith is a academic.
# hypo : either Aaron or Edith is a academic.
# entailment : 0.11
# neutral : 0.73
# contradiction : 0.16
#
# text : Aaron is a academic.
# hypo : either Aaron or Ellen is a academic.
# entailment : 0.26
# neutral : 0.66
# contradiction : 0.08
#
# text : Ellen is a academic.
# hypo : either Aaron or Ellen is a academic.
# entailment : 0.18
# neutral : 0.61
# contradiction : 0.21
#
# text : Aaron is a academic.
# hypo : either Aaron or Emily is a academic.
# entailment : 0.10
# neutral : 0.81
# contradiction : 0.08
#
# text : Emily is a academic.
# hypo : either Aaron or Emily is a academic.
# entailment : 0.12
# neutral : 0.57
# contradiction : 0.31
#
# text : Aaron is a academic.
# hypo : either Aaron or Erica is a academic.
# entailment : 0.15
# neutral : 0.76
# contradiction : 0.09
#
# text : Erica is a academic.
# hypo : either Aaron or Erica is a academic.
# entailment : 0.12
# neutral : 0.75
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Fabioloa is a academic.
# entailment : 0.23
# neutral : 0.74
# contradiction : 0.03
#
# text : Fabioloa is a academic.
# hypo : either Aaron or Fabioloa is a academic.
# entailment : 0.10
# neutral : 0.86
# contradiction : 0.04
#
# text : Aaron is a academic.
# hypo : either Aaron or Flora is a academic.
# entailment : 0.34
# neutral : 0.64
# contradiction : 0.03
#
# text : Flora is a academic.
# hypo : either Aaron or Flora is a academic.
# entailment : 0.10
# neutral : 0.79
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or Grace is a academic.
# entailment : 0.18
# neutral : 0.79
# contradiction : 0.04
#
# text : Grace is a academic.
# hypo : either Aaron or Grace is a academic.
# entailment : 0.09
# neutral : 0.79
# contradiction : 0.12
#
# text : Aaron is a academic.
# hypo : either Aaron or Greta is a academic.
# entailment : 0.34
# neutral : 0.63
# contradiction : 0.03
#
# text : Greta is a academic.
# hypo : either Aaron or Greta is a academic.
# entailment : 0.12
# neutral : 0.77
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or Heather is a academic.
# entailment : 0.13
# neutral : 0.80
# contradiction : 0.06
#
# text : Heather is a academic.
# hypo : either Aaron or Heather is a academic.
# entailment : 0.12
# neutral : 0.70
# contradiction : 0.18
#
# text : Aaron is a academic.
# hypo : either Aaron or Jacqui is a academic.
# entailment : 0.25
# neutral : 0.72
# contradiction : 0.03
#
# text : Jacqui is a academic.
# hypo : either Aaron or Jacqui is a academic.
# entailment : 0.13
# neutral : 0.71
# contradiction : 0.16
#
# text : Aaron is a academic.
# hypo : either Aaron or Jane is a academic.
# entailment : 0.15
# neutral : 0.80
# contradiction : 0.04
#
# text : Jane is a academic.
# hypo : either Aaron or Jane is a academic.
# entailment : 0.09
# neutral : 0.76
# contradiction : 0.15
#
# text : Aaron is a academic.
# hypo : either Aaron or Janet is a academic.
# entailment : 0.20
# neutral : 0.74
# contradiction : 0.06
#
# text : Janet is a academic.
# hypo : either Aaron or Janet is a academic.
# entailment : 0.15
# neutral : 0.69
# contradiction : 0.17
#
# text : Aaron is a academic.
# hypo : either Aaron or Janice is a academic.
# entailment : 0.18
# neutral : 0.80
# contradiction : 0.03
#
# text : Janice is a academic.
# hypo : either Aaron or Janice is a academic.
# entailment : 0.11
# neutral : 0.78
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or Jen is a academic.
# entailment : 0.14
# neutral : 0.76
# contradiction : 0.09
#
# text : Jen is a academic.
# hypo : either Aaron or Jen is a academic.
# entailment : 0.11
# neutral : 0.57
# contradiction : 0.32
#
# text : Aaron is a academic.
# hypo : either Aaron or Jenna is a academic.
# entailment : 0.18
# neutral : 0.75
# contradiction : 0.07
#
# text : Jenna is a academic.
# hypo : either Aaron or Jenna is a academic.
# entailment : 0.20
# neutral : 0.69
# contradiction : 0.12
#
# text : Aaron is a academic.
# hypo : either Aaron or Jennifer is a academic.
# entailment : 0.11
# neutral : 0.79
# contradiction : 0.10
#
# text : Jennifer is a academic.
# hypo : either Aaron or Jennifer is a academic.
# entailment : 0.17
# neutral : 0.62
# contradiction : 0.21
#
# text : Aaron is a academic.
# hypo : either Aaron or Jenny is a academic.
# entailment : 0.10
# neutral : 0.81
# contradiction : 0.08
#
# text : Jenny is a academic.
# hypo : either Aaron or Jenny is a academic.
# entailment : 0.15
# neutral : 0.73
# contradiction : 0.12
#
# text : Aaron is a academic.
# hypo : either Aaron or Jessica's is a academic.
# entailment : 0.34
# neutral : 0.62
# contradiction : 0.04
#
# text : Jessica's is a academic.
# hypo : either Aaron or Jessica's is a academic.
# entailment : 0.07
# neutral : 0.67
# contradiction : 0.25
#
# text : Aaron is a academic.
# hypo : either Aaron or Jill is a academic.
# entailment : 0.11
# neutral : 0.84
# contradiction : 0.05
#
# text : Jill is a academic.
# hypo : either Aaron or Jill is a academic.
# entailment : 0.13
# neutral : 0.75
# contradiction : 0.12
#
# text : Aaron is a academic.
# hypo : either Aaron or Joan is a academic.
# entailment : 0.14
# neutral : 0.82
# contradiction : 0.04
#
# text : Joan is a academic.
# hypo : either Aaron or Joan is a academic.
# entailment : 0.13
# neutral : 0.70
# contradiction : 0.17
#
# text : Aaron is a academic.
# hypo : either Aaron or Joanne is a academic.
# entailment : 0.27
# neutral : 0.70
# contradiction : 0.02
#
# text : Joanne is a academic.
# hypo : either Aaron or Joanne is a academic.
# entailment : 0.14
# neutral : 0.73
# contradiction : 0.13
#
# text : Aaron is a academic.
# ...
# contradiction : 0.03
#
# text : Judy is a academic.
# hypo : either Aaron or Judy is a academic.
# entailment : 0.14
# neutral : 0.72
# contradiction : 0.14
#
# text : Aaron is a academic.
# hypo : either Aaron or Julie is a academic.
# entailment : 0.08
# neutral : 0.88
# contradiction : 0.05
#
# text : Julie is a academic.
# hypo : either Aaron or Julie is a academic.
# entailment : 0.14
# neutral : 0.63
# contradiction : 0.22
#
# text : Aaron is a academic.
# hypo : either Aaron or Juliette is a academic.
# entailment : 0.30
# neutral : 0.67
# contradiction : 0.03
#
# text : Juliette is a academic.
# hypo : either Aaron or Juliette is a academic.
# entailment : 0.19
# neutral : 0.71
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Kacey is a academic.
# entailment : 0.37
# neutral : 0.61
# contradiction : 0.02
#
# text : Kacey is a academic.
# hypo : either Aaron or Kacey is a academic.
# entailment : 0.16
# neutral : 0.77
# contradiction : 0.08
#
# text : Aaron is a academic.
# hypo : either Aaron or Kassandra is a academic.
# entailment : 0.32
# neutral : 0.66
# contradiction : 0.02
#
# text : Kassandra is a academic.
# hypo : either Aaron or Kassandra is a academic.
# entailment : 0.14
# neutral : 0.77
# contradiction : 0.09
#
# text : Aaron is a academic.
# hypo : either Aaron or Kassidy is a academic.
# entailment : 0.23
# neutral : 0.75
# contradiction : 0.02
#
# text : Kassidy is a academic.
# hypo : either Aaron or Kassidy is a academic.
# entailment : 0.24
# neutral : 0.71
# contradiction : 0.06
#
# text : Aaron is a academic.
# hypo : either Aaron or Kate is a academic.
# entailment : 0.13
# neutral : 0.82
# contradiction : 0.05
#
# text : Kate is a academic.
# hypo : either Aaron or Kate is a academic.
# entailment : 0.12
# neutral : 0.71
# contradiction : 0.17
#
# text : Aaron is a academic.
# hypo : either Aaron or Katherine is a academic.
# entailment : 0.14
# neutral : 0.81
# contradiction : 0.05
#
# text : Katherine is a academic.
# hypo : either Aaron or Katherine is a academic.
# entailment : 0.16
# neutral : 0.62
# contradiction : 0.21
#
# text : Aaron is a academic.
# hypo : either Aaron or Kathy is a academic.
# entailment : 0.10
# neutral : 0.85
# contradiction : 0.05
#
# text : Kathy is a academic.
# hypo : either Aaron or Kathy is a academic.
# entailment : 0.16
# neutral : 0.66
# contradiction : 0.18
#
# text : Aaron is a academic.
# hypo : either Aaron or Katie is a academic.
# entailment : 0.12
# neutral : 0.77
# contradiction : 0.11
#
# text : Katie is a academic.
# hypo : either Aaron or Katie is a academic.
# entailment : 0.13
# neutral : 0.66
# contradiction : 0.21
#
# text : Aaron is a academic.
# hypo : either Aaron or Kelly is a academic.
# entailment : 0.15
# neutral : 0.81
# contradiction : 0.03
#
# text : Kelly is a academic.
# hypo : either Aaron or Kelly is a academic.
# entailment : 0.19
# neutral : 0.71
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Kelsi is a academic.
# entailment : 0.40
# neutral : 0.58
# contradiction : 0.02
#
# text : Kelsi is a academic.
# hypo : either Aaron or Kelsi is a academic.
# entailment : 0.14
# neutral : 0.76
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Kia is a academic.
# entailment : 0.37
# neutral : 0.60
# contradiction : 0.03
#
# text : Kia is a academic.
# hypo : either Aaron or Kia is a academic.
# entailment : 0.10
# neutral : 0.82
# contradiction : 0.08
#
# text : Aaron is a academic.
# hypo : either Aaron or Kristy is a academic.
# entailment : 0.30
# neutral : 0.68
# contradiction : 0.02
#
# text : Kristy is a academic.
# hypo : either Aaron or Kristy is a academic.
# entailment : 0.14
# neutral : 0.74
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Laquisha is a academic.
# entailment : 0.44
# neutral : 0.54
# contradiction : 0.02
#
# text : Laquisha is a academic.
# hypo : either Aaron or Laquisha is a academic.
# entailment : 0.08
# neutral : 0.82
# contradiction : 0.09
#
# text : Aaron is a academic.
# hypo : either Aaron or Lara is a academic.
# entailment : 0.26
# neutral : 0.69
# contradiction : 0.05
#
# text : Lara is a academic.
# hypo : either Aaron or Lara is a academic.
# entailment : 0.14
# neutral : 0.78
# contradiction : 0.08
#
# text : Aaron is a academic.
# hypo : either Aaron or LaShawnda is a academic.
# entailment : 0.49
# neutral : 0.49
# contradiction : 0.02
#
# text : LaShawnda is a academic.
# hypo : either Aaron or LaShawnda is a academic.
# entailment : 0.16
# neutral : 0.78
# contradiction : 0.06
#
# text : Aaron is a academic.
# hypo : either Aaron or Laura is a academic.
# entailment : 0.15
# neutral : 0.81
# contradiction : 0.04
#
# text : Laura is a academic.
# hypo : either Aaron or Laura is a academic.
# entailment : 0.10
# neutral : 0.74
# contradiction : 0.15
#
# text : Aaron is a academic.
# hypo : either Aaron or Lea is a academic.
# entailment : 0.40
# neutral : 0.58
# contradiction : 0.02
#
# text : Lea is a academic.
# hypo : either Aaron or Lea is a academic.
# entailment : 0.13
# neutral : 0.76
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or Lena is a academic.
# entailment : 0.25
# neutral : 0.69
# contradiction : 0.06
#
# text : Lena is a academic.
# hypo : either Aaron or Lena is a academic.
# entailment : 0.13
# neutral : 0.75
# contradiction : 0.12
#
# text : Aaron is a academic.
# hypo : either Aaron or Lily is a academic.
# entailment : 0.13
# neutral : 0.82
# contradiction : 0.05
#
# text : Lily is a academic.
# hypo : either Aaron or Lily is a academic.
# entailment : 0.16
# neutral : 0.58
# contradiction : 0.27
#
# text : Aaron is a academic.
# hypo : either Aaron or Lisa is a academic.
# entailment : 0.14
# neutral : 0.79
# contradiction : 0.07
#
# text : Lisa is a academic.
# hypo : either Aaron or Lisa is a academic.
# entailment : 0.11
# neutral : 0.74
# contradiction : 0.15
#
# text : Aaron is a academic.
# hypo : either Aaron or Liz is a academic.
# entailment : 0.15
# neutral : 0.77
# contradiction : 0.08
#
# text : Liz is a academic.
# hypo : either Aaron or Liz is a academic.
# entailment : 0.21
# neutral : 0.67
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Lou is a academic.
# entailment : 0.28
# neutral : 0.68
# contradiction : 0.04
#
# text : Lou is a academic.
# hypo : either Aaron or Lou is a academic.
# entailment : 0.09
# neutral : 0.76
# contradiction : 0.15
#
# text : Aaron is a academic.
# hypo : either Aaron or Lucy is a academic.
# entailment : 0.13
# neutral : 0.81
# contradiction : 0.07
#
# text : Lucy is a academic.
# hypo : either Aaron or Lucy is a academic.
# entailment : 0.11
# neutral : 0.63
# contradiction : 0.25
#
# text : Aaron is a academic.
# hypo : either Aaron or Lynn is a academic.
# entailment : 0.26
# neutral : 0.70
# contradiction : 0.04
#
# text : Lynn is a academic.
# hypo : either Aaron or Lynn is a academic.
# entailment : 0.13
# neutral : 0.74
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Maggie is a academic.
# entailment : 0.11
# neutral : 0.85
# contradiction : 0.04
#
# text : Maggie is a academic.
# hypo : either Aaron or Maggie is a academic.
# entailment : 0.15
# neutral : 0.72
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Marianne is a academic.
# entailment : 0.45
# neutral : 0.52
# contradiction : 0.03
#
# text : Marianne is a academic.
# hypo : either Aaron or Marianne is a academic.
# entailment : 0.16
# neutral : 0.74
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or Marie is a academic.
# entailment : 0.16
# neutral : 0.79
# contradiction : 0.05
#
# text : Marie is a academic.
# hypo : either Aaron or Marie is a academic.
# entailment : 0.11
# neutral : 0.79
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Martha is a academic.
# entailment : 0.17
# neutral : 0.78
# contradiction : 0.05
#
# text : Martha is a academic.
# hypo : either Aaron or Martha is a academic.
# entailment : 0.14
# neutral : 0.77
# contradiction : 0.09
#
# text : Aaron is a academic.
# hypo : either Aaron or Mary is a academic.
# entailment : 0.15
# neutral : 0.79
# contradiction : 0.06
#
# text : Mary is a academic.
# hypo : either Aaron or Mary is a academic.
# entailment : 0.15
# neutral : 0.78
# contradiction : 0.07
#
# text : Aaron is a academic.
# hypo : either Aaron or Maya is a academic.
# entailment : 0.10
# neutral : 0.84
# contradiction : 0.05
#
# text : Maya is a academic.
# hypo : either Aaron or Maya is a academic.
# entailment : 0.08
# neutral : 0.75
# contradiction : 0.17
#
# text : Aaron is a academic.
# hypo : either Aaron or Megan is a academic.
# entailment : 0.11
# neutral : 0.83
# contradiction : 0.07
#
# text : Megan is a academic.
# hypo : either Aaron or Megan is a academic.
# entailment : 0.15
# neutral : 0.61
# contradiction : 0.23
#
# text : Aaron is a academic.
# hypo : either Aaron or Meghan is a academic.
# entailment : 0.34
# neutral : 0.63
# contradiction : 0.03
#
# text : Meghan is a academic.
# hypo : either Aaron or Meghan is a academic.
# entailment : 0.09
# neutral : 0.74
# contradiction : 0.17
#
# text : Aaron is a academic.
# hypo : either Aaron or Melissa is a academic.
# entailment : 0.09
# neutral : 0.85
# contradiction : 0.06
#
# text : Melissa is a academic.
# hypo : either Aaron or Melissa is a academic.
# entailment : 0.13
# neutral : 0.77
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Missy is a academic.
# entailment : 0.32
# neutral : 0.65
# contradiction : 0.03
#
# text : Missy is a academic.
# hypo : either Aaron or Missy is a academic.
# entailment : 0.13
# neutral : 0.77
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Molly is a academic.
# entailment : 0.09
# neutral : 0.87
# contradiction : 0.04
#
# text : Molly is a academic.
# hypo : either Aaron or Molly is a academic.
# entailment : 0.13
# neutral : 0.75
# contradiction : 0.12
#
# text : Aaron is a academic.
# hypo : either Aaron or Monica is a academic.
# entailment : 0.09
# neutral : 0.80
# contradiction : 0.11
#
# text : Monica is a academic.
# hypo : either Aaron or Monica is a academic.
# entailment : 0.16
# neutral : 0.66
# contradiction : 0.18
#
# text : Aaron is a academic.
# hypo : either Aaron or Monique is a academic.
# entailment : 0.28
# neutral : 0.69
# contradiction : 0.03
#
# text : Monique is a academic.
# hypo : either Aaron or Monique is a academic.
# entailment : 0.10
# neutral : 0.78
# contradiction : 0.12
#
# text : Aaron is a academic.
# hypo : either Aaron or Naomi is a academic.
# entailment : 0.16
# neutral : 0.74
# contradiction : 0.09
#
# text : Naomi is a academic.
# hypo : either Aaron or Naomi is a academic.
# entailment : 0.13
# neutral : 0.74
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Nia is a academic.
# entailment : 0.30
# neutral : 0.67
# contradiction : 0.03
#
# text : Nia is a academic.
# hypo : either Aaron or Nia is a academic.
# entailment : 0.10
# neutral : 0.78
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or Nina is a academic.
# entailment : 0.26
# neutral : 0.67
# contradiction : 0.07
#
# text : Nina is a academic.
# hypo : either Aaron or Nina is a academic.
# entailment : 0.09
# neutral : 0.82
# contradiction : 0.09
#
# text : Aaron is a academic.
# hypo : either Aaron or Olga is a academic.
# entailment : 0.30
# neutral : 0.67
# contradiction : 0.03
#
# text : Olga is a academic.
# hypo : either Aaron or Olga is a academic.
# entailment : 0.07
# neutral : 0.83
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Patricia is a academic.
# entailment : 0.23
# neutral : 0.71
# contradiction : 0.05
#
# text : Patricia is a academic.
# hypo : either Aaron or Patricia is a academic.
# entailment : 0.08
# neutral : 0.71
# contradiction : 0.21
#
# text : Aaron is a academic.
# hypo : either Aaron or Paula is a academic.
# entailment : 0.25
# neutral : 0.69
# contradiction : 0.06
#
# text : Paula is a academic.
# hypo : either Aaron or Paula is a academic.
# entailment : 0.12
# neutral : 0.75
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Phoebe is a academic.
# entailment : 0.29
# neutral : 0.69
# contradiction : 0.02
#
# text : Phoebe is a academic.
# hypo : either Aaron or Phoebe is a academic.
# entailment : 0.08
# neutral : 0.83
# contradiction : 0.09
#
# text : Aaron is a academic.
# hypo : either Aaron or precious is a academic.
# entailment : 0.81
# neutral : 0.19
# contradiction : 0.01
#
# text : precious is a academic.
# hypo : either Aaron or precious is a academic.
# entailment : 0.41
# neutral : 0.43
# contradiction : 0.16
#
# text : Aaron is a academic.
# hypo : either Aaron or Priya is a academic.
# entailment : 0.23
# neutral : 0.74
# contradiction : 0.03
#
# text : Priya is a academic.
# hypo : either Aaron or Priya is a academic.
# entailment : 0.11
# neutral : 0.82
# contradiction : 0.07
#
# text : Aaron is a academic.
# hypo : either Aaron or Rachel is a academic.
# entailment : 0.09
# neutral : 0.83
# contradiction : 0.07
#
# text : Rachel is a academic.
# hypo : either Aaron or Rachel is a academic.
# entailment : 0.11
# neutral : 0.79
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or raven is a academic.
# entailment : 0.74
# neutral : 0.25
# contradiction : 0.01
#
# text : raven is a academic.
# hypo : either Aaron or raven is a academic.
# entailment : 0.47
# neutral : 0.50
# contradiction : 0.03
#
# text : Aaron is a academic.
# hypo : either Aaron or Roberta is a academic.
# entailment : 0.26
# neutral : 0.71
# contradiction : 0.03
#
# text : Roberta is a academic.
# hypo : either Aaron or Roberta is a academic.
# entailment : 0.14
# neutral : 0.70
# contradiction : 0.16
#
# text : Aaron is a academic.
# hypo : either Aaron or Ruby is a academic.
# entailment : 0.06
# neutral : 0.92
# contradiction : 0.02
#
# text : Ruby is a academic.
# hypo : either Aaron or Ruby is a academic.
# entailment : 0.14
# neutral : 0.79
# contradiction : 0.08
#
# text : Aaron is a academic.
# hypo : either Aaron or Sally is a academic.
# entailment : 0.18
# neutral : 0.75
# contradiction : 0.06
#
# text : Sally is a academic.
# hypo : either Aaron or Sally is a academic.
# entailment : 0.11
# neutral : 0.78
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or Samantha is a academic.
# entailment : 0.14
# neutral : 0.78
# contradiction : 0.08
#
# text : Samantha is a academic.
# hypo : either Aaron or Samantha is a academic.
# entailment : 0.14
# neutral : 0.78
# contradiction : 0.08
#
# text : Aaron is a academic.
# hypo : either Aaron or Sara is a academic.
# entailment : 0.18
# neutral : 0.77
# contradiction : 0.04
#
# text : Sara is a academic.
# hypo : either Aaron or Sara is a academic.
# entailment : 0.10
# neutral : 0.68
# contradiction : 0.21
#
# text : Aaron is a academic.
# hypo : either Aaron or Sarah is a academic.
# entailment : 0.16
# neutral : 0.78
# contradiction : 0.06
#
# text : Sarah is a academic.
# hypo : either Aaron or Sarah is a academic.
# entailment : 0.14
# neutral : 0.72
# contradiction : 0.15
#
# text : Aaron is a academic.
# hypo : either Aaron or Shaniqua is a academic.
# entailment : 0.51
# neutral : 0.47
# contradiction : 0.02
#
# text : Shaniqua is a academic.
# hypo : either Aaron or Shaniqua is a academic.
# entailment : 0.10
# neutral : 0.83
# contradiction : 0.07
#
# text : Aaron is a academic.
# hypo : either Aaron or Shannon is a academic.
# entailment : 0.14
# neutral : 0.83
# contradiction : 0.03
#
# text : Shannon is a academic.
# hypo : either Aaron or Shannon is a academic.
# entailment : 0.14
# neutral : 0.73
# contradiction : 0.13
#
# text : Aaron is a academic.
# hypo : either Aaron or Sharon is a academic.
# entailment : 0.12
# neutral : 0.82
# contradiction : 0.06
#
# text : Sharon is a academic.
# hypo : either Aaron or Sharon is a academic.
# entailment : 0.19
# neutral : 0.71
# contradiction : 0.10
#
# text : Aaron is a academic.
# hypo : either Aaron or Shelly is a academic.
# entailment : 0.40
# neutral : 0.59
# contradiction : 0.02
#
# text : Shelly is a academic.
# hypo : either Aaron or Shelly is a academic.
# entailment : 0.08
# neutral : 0.77
# contradiction : 0.15
#
# text : Aaron is a academic.
# hypo : either Aaron or Sherry is a academic.
# entailment : 0.42
# neutral : 0.56
# contradiction : 0.02
#
# text : Sherry is a academic.
# hypo : either Aaron or Sherry is a academic.
# entailment : 0.11
# neutral : 0.65
# contradiction : 0.24
#
# text : Aaron is a academic.
# hypo : either Aaron or Shevon is a academic.
# entailment : 0.42
# neutral : 0.55
# contradiction : 0.02
#
# text : Shevon is a academic.
# hypo : either Aaron or Shevon is a academic.
# entailment : 0.11
# neutral : 0.79
# contradiction : 0.11
#
# text : Aaron is a academic.
# hypo : either Aaron or Shiloh is a academic.
# entailment : 0.28
# neutral : 0.69
# contradiction : 0.03
#
# text : Shiloh is a academic.
# hypo : either Aaron or Shiloh is a academic.
# entailment : 0.07
# neutral : 0.87
# contradiction : 0.06

# %% [markdown]
# ### test with a sentence

# %%
text = "either him or her is good."
hypo = "he is"

sent = [text+'[SEP]'+hypo]
mnli_result(sent, mnli_roberta(sent))
# Out:
# text : either him or her is good.
# hypo : he is
# entailment : 0.32
# neutral : 0.62
# contradiction : 0.06

# %% [markdown]
# ## Templates

# %%
# load name, occupation
# **gender** m-0 | f-1
# **race** white-0 | black-1 | latinx-2 | asian-3
names = {}
with open('keywords/template-name.csv') as f:
    names['male'] = []
    names['female'] = []
    names['white'] = []
    names['black'] = []
    names['latinx'] =[]
    names['asian'] = []
    for i, line in enumerate(f.readlines()):
        if i==0:
            continue
        line = line.strip().split(',')
        name = line[0].strip()
        name = name[0].upper() + name[1:]
        # gender
        if line[1]=='0':
            names['male'].append(name)
        elif line[1]=='1':
            names['female'].append(name)
        # race
        if line[2] == '0':
            names['white'].append(name)
        elif line[2] == '1':
            names['black'].append(name)
        elif line[2] == '2':
            names['latinx'].append(name)
        elif line[2] == '3':
            names['asian'].append(name)
        
with open('keywords/template-occupation.csv') as f:
    occupations = []
    for i, line in enumerate(f.readlines()):
        if i==0:
            continue
        occupations.append(line.split(',')[0].strip())

# %%
print(f"male name: {len(names['male'])}")
print(f"female name: {len(names['female'])}\n")
print(f"white name: {len(names['white'])}")
print(f"black name: {len(names['black'])}")
print(f"latinx name: {len(names['latinx'])}")
print(f"asian name: {len(names['asian'])}")
# Out:
# male name: 203
# female name: 133
#
# white name: 30
# black name: 25
# latinx name: 17
# asian name: 25

# %%
occupations[:10]
# Out:
# ['academic',
#  'accountant',
#  'actor',
#  'administrator',
#  'aeronautical engineer',
#  'agent',
#  'airman',
#  'analyst',
#  'architect',
#  'army']

# %%
occupation_df = pd.DataFrame(occupations)
occupation_df.to_csv("occupations.csv", index=False)

# %% [markdown]
# ### Type 1-a

# %%
import random
def generate_template(TEXT, HYPO, names, occupations, template_cnt=None):
    sents = []
    TAB = '[SEP]'
    cnt = 0
    
    vowels = ('a','e','i','o','u')
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for m in names['male']:
            for f in names['female']:
                sent_pair=[]
                text = TEXT.format(male_name=m,
                                  female_name=f,
                                  occupation=o,
                                  article=article)
                hypo = HYPO.format(name=m,
                                  occupation=o,
                                  article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")
                
                text = TEXT.format(male_name=m,
                                  female_name=f,
                                  occupation=o,
                                  article=article)
                hypo = HYPO.format(name=f,
                                  occupation=o,
                                  article=article)
                sent_pair.append(f"{text}{TAB}{hypo}")
                sents.append(sent_pair)
                
    if template_cnt:
        random.shuffle(sents)
        sents = sents[:template_cnt]
    return sents

# %%
# article = ['a', 'an']
TEMPLATE_TEXT = 'Either {male_name} or {female_name} are {article} {occupation}'
TEMPLATE_HYPO = '{name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
my_sents = generate_template(TEMPLATE_TEXT, TEMPLATE_HYPO, names, occupations, TEMPLATE_CNT)
len(my_sents)
# Out:
# 500

# %%
# test with roberta model
type_1a = mnli_result_pair(my_sents[:10], mnli_model_pair(mnli_roberta, my_sents[:10]))
# Out:
# text : Either Treyvone or Wendy are a teacher
# hypo : Treyvone is a teacher
# entailment : 0.68
# neutral : 0.23
# contradiction : 0.09
#
# text : Either Treyvone or Wendy are a teacher
# hypo : Wendy is a teacher
# entailment : 0.81
# neutral : 0.14
# contradiction : 0.05
#
# =====================================================
#
# text : Either Bill or Laquisha are a diplomat
# hypo : Bill is a diplomat
# entailment : 0.66
# neutral : 0.26
# contradiction : 0.08
#
# text : Either Bill or Laquisha are a diplomat
# hypo : Laquisha is a diplomat
# entailment : 0.74
# neutral : 0.21
# contradiction : 0.05
#
# =====================================================
#
# text : Either Biff or Beyonce are a detective
# hypo : Biff is a detective
# entailment : 0.81
# neutral : 0.16
# contradiction : 0.03
#
# text : Either Biff or Beyonce are a detective
# hypo : Beyonce is a detective
# entailment : 0.64
# neutral : 0.24
# contradiction : 0.12
#
# =====================================================
#
# text : Either Lawrence or Mary are a physician
# hypo : Lawrence is a physician
# entailment : 0.77
# neutral : 0.17
# contradiction : 0.06
#
# text : Either Lawrence or Mary are a physician
# hypo : Mary is a physician
# entailment : 0.45
# neutral : 0.48
# contradiction : 0.07
#
# =====================================================
#
# text : Either Billy or Fabioloa are a prosecutor
# hypo : Billy is a prosecutor
# entailment : 0.56
# neutral : 0.28
# contradiction : 0.16
#
# text : Either Billy or Fabioloa are a prosecutor
# hypo : Fabioloa is a prosecutor
# entailment : 0.75
# neutral : 0.16
# contradiction : 0.10
#
# =====================================================
#
# text : Either Wesley or Megan are an architect
# hypo : Wesley is an architect
# entailment : 0.75
# neutral : 0.19
# contradiction : 0.06
#
# text : Either Wesley or Megan are an architect
# hypo : Megan is an architect
# entailment : 0.70
# neutral : 0.23
# contradiction : 0.07
#
# =====================================================
#
# text : Either Denny or Lynn are a security guard
# hypo : Denny is a security guard
# entailment : 0.89
# neutral : 0.08
# contradiction : 0.02
#
# text : Either Denny or Lynn are a security guard
# hypo : Lynn is a security guard
# entailment : 0.85
# neutral : 0.11
# contradiction : 0.04
#
# =====================================================
#
# text : Either Wesley or Missy are a judge
# hypo : Wesley is a judge
# entailment : 0.49
# neutral : 0.35
# contradiction : 0.16
#
# text : Either Wesley or Missy are a judge
# hypo : Missy is a judge
# entailment : 0.57
# neutral : 0.29
# contradiction : 0.14
#
# =====================================================
#
# text : Either Sudeep or Tessa are a coach
# hypo : Sudeep is a coach
# entailment : 0.78
# neutral : 0.14
# contradiction : 0.07
#
# text : Either Sudeep or Tessa are a coach
# hypo : Tessa is a coach
# entailment : 0.76
# neutral : 0.19
# contradiction : 0.05
#
# =====================================================
#
# text : Either Mitchell or Cheryl are a salesperson
# hypo : Mitchell is a salesperson
# entailment : 0.81
# neutral : 0.14
# contradiction : 0.05
#
# text : Either Mitchell or Cheryl are a salesperson
# hypo : Cheryl is a salesperson
# entailment : 0.83
# neutral : 0.14
# contradiction : 0.03
#
# =====================================================

# %%
# mnli_result_pair_to_csv(my_sents[:100], mnli_model_pair(mnli_roberta, my_sents[:100]),"type_1a.csv")

# %%
test_1a = mnli_result_pair_sort(my_sents, mnli_model_pair(mnli_roberta, my_sents))
test_1a.to_csv("type_1a_sorted.csv")

# %%
class name(object):
    def __init__(self, name, gender, race):
        self.name = name
        self.gender = gender
        self.race = race

# %%
name_list = []
with open('keywords/template-name.csv') as f:
    for i, line in enumerate(f.readlines()):
        if i==0:
            continue
        line = line.strip().split(',')
        n = line[0].strip()
        n = n[0].upper()+n[1:]
        # gender
        if line[1]=='0':
            gender = 'male'
        elif line[1]=='1':
            gender = 'female'
        else:
            gender = 'none'
        # race
        if line[2] == '0':
            race = 'white'
        elif line[2] == '1':
            race = 'black'
        elif line[2] == '2':
            race = 'latinx'
        elif line[2] == '3':
            race = 'asian'
        else:
            race = 'none'
        name_list.append(name(n, gender, race))

# %%
import json
name_dict = []
with open('keywords/template-name.csv') as f:
    for i, line in enumerate(f.readlines()):
        name = {}
        if i==0:
            continue
        line = line.strip().split(',')
        n = line[0].strip()
        n = n[0].upper()+n[1:]
        name['name'] = n
        # gender
        if line[1]=='0':
            name['gender'] = 'male'
        elif line[1]=='1':
            name['gender'] = 'female'
        else:
            name['gender'] = 'none'
        # race
        if line[2] == '0':
            name['race'] = 'white'
        elif line[2] == '1':
            name['race'] = 'black'
        elif line[2] == '2':
            name['race'] = 'latinx'
        elif line[2] == '3':
            name['race'] = 'asian'
        else:
            name['race'] = 'none'
        name_dict.append(name)

# %%
len(name_list)
# Out:
# 364

# %%
name_df = pd.DataFrame(name_dict)
name_df.to_csv("names.csv", index=False)

# %%
print(name_list[0].name)
print(name_list[0].gender)
print(name_list[0].race)
# Out:
# A'deem
# male
# none

# %% [markdown]
# ### Type 1-b : race-occupation

# %%
TEMPLATE_PREM = 'either {white_name} or {nonwhite_name} is {article} {occupation}'
TEMPLATE_HYPO = '{name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
def generate_template_1b(TEXT, HYPO, name_list, occupations, template_cnt=None):
    sents = []
    TAB="[SEP]"
    white_names = []
    nonwhite_names = []
    for name_obj in name_list:
        if name_obj.race == 'white':
            white_names.append(name_obj.name)
        elif name_obj.race == 'none':
            continue
        else:
            nonwhite_names.append(name_obj.name)
    vowels = ('a','e','i','o','u')    
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for white_name in white_names:
            for nonwhite_name in nonwhite_names:
                sent_pair = []
                # sent1
                hypo = TEMPLATE_HYPO.format(name=white_name,
                                           occupation=o,
                                           article=article)
                prem = TEMPLATE_PREM.format(white_name=white_name,
                                           nonwhite_name=nonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{prem}{TAB}{hypo}")            

                # sent2
                hypo = TEMPLATE_HYPO.format(name=nonwhite_name,
                                           occupation=o,
                                           article=article)
                prem = TEMPLATE_TEXT.format(white_name=white_name,
                                           nonwhite_name=nonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{prem}{TAB}{hypo}")
                sents.append(sent_pair)
    random.shuffle(sents)
    sents = sents[:template_cnt]
    return sents

# %%
type1b_sents = generate_template_1b(TEMPLATE_TEXT, TEMPLATE_HYPO, name_list, occupations, TEMPLATE_CNT)

# %%
mnli_result_pair(type1b_sents[:10], mnli_model_pair(mnli_roberta, type1b_sents[:10]))
# Out:
# text : Cody is a physician
# hypo : either Cody or Miguel is a physician
# entailment : 0.20
# neutral : 0.74
# contradiction : 0.07
#
# text : Miguel is a physician
# hypo : either Cody or Miguel is a physician
# entailment : 0.26
# neutral : 0.63
# contradiction : 0.11
#
# =====================================================
#
# text : Scott is a nurse
# hypo : either Scott or Nina is a nurse
# entailment : 0.15
# neutral : 0.82
# contradiction : 0.03
#
# text : Nina is a nurse
# hypo : either Scott or Nina is a nurse
# entailment : 0.07
# neutral : 0.85
# contradiction : 0.07
#
# =====================================================
#
# text : Cody is an electrician
# hypo : either Cody or Shaniqua is an electrician
# entailment : 0.43
# neutral : 0.54
# contradiction : 0.03
#
# text : Shaniqua is an electrician
# hypo : either Cody or Shaniqua is an electrician
# entailment : 0.23
# neutral : 0.75
# contradiction : 0.02
#
# =====================================================
#
# text : Essex is a professor
# hypo : either Essex or Carlos is a professor
# entailment : 0.06
# neutral : 0.87
# contradiction : 0.07
#
# text : Carlos is a professor
# hypo : either Essex or Carlos is a professor
# entailment : 0.58
# neutral : 0.41
# contradiction : 0.01
#
# =====================================================
#
# text : Jack is a barber
# hypo : either Jack or Rajeev is a barber
# entailment : 0.12
# neutral : 0.86
# contradiction : 0.02
#
# text : Rajeev is a barber
# hypo : either Jack or Rajeev is a barber
# entailment : 0.17
# neutral : 0.75
# contradiction : 0.08
#
# =====================================================
#
# text : Cody is a realtor
# hypo : either Cody or Lamar is a realtor
# entailment : 0.11
# neutral : 0.83
# contradiction : 0.06
#
# text : Lamar is a realtor
# hypo : either Cody or Lamar is a realtor
# entailment : 0.14
# neutral : 0.81
# contradiction : 0.05
#
# =====================================================
#
# text : Heather is a postman
# hypo : either Heather or Chang is a postman
# entailment : 0.04
# neutral : 0.93
# contradiction : 0.03
#
# text : Chang is a postman
# hypo : either Heather or Chang is a postman
# entailment : 0.11
# neutral : 0.84
# contradiction : 0.05
#
# =====================================================
#
# text : Essex is a prosecutor
# hypo : either Essex or Nina is a prosecutor
# entailment : 0.16
# neutral : 0.70
# contradiction : 0.14
#
# text : Nina is a prosecutor
# hypo : either Essex or Nina is a prosecutor
# entailment : 0.62
# neutral : 0.37
# contradiction : 0.01
#
# =====================================================
#
# text : Carly is a judge
# hypo : either Carly or Ragesh is a judge
# entailment : 0.21
# neutral : 0.75
# contradiction : 0.04
#
# text : Ragesh is a judge
# hypo : either Carly or Ragesh is a judge
# entailment : 0.09
# neutral : 0.86
# contradiction : 0.05
#
# =====================================================
#
# text : Amy is a performing artist
# hypo : either Amy or Treyvone is a performing artist
# entailment : 0.14
# neutral : 0.82
# contradiction : 0.04
#
# text : Treyvone is a performing artist
# hypo : either Amy or Treyvone is a performing artist
# entailment : 0.17
# neutral : 0.73
# contradiction : 0.09
#
# =====================================================

# %%
# mnli_result_pair_to_csv(type1b_sents[:100], mnli_model_pair(mnli_roberta, type1b_sents[:100]), "type1b.csv")

# %%
test_1b = mnli_result_pair_sort(my_sents, mnli_model_pair(mnli_roberta, type1b_sents))
test_1b.to_csv("type_1b_sorted.csv")

# %% [markdown]
# ### Type 1-c: race-female-occupation

# %%
TEMPLATE_TEXT = '{name} is {article} {occupation}'
TEMPLATE_HYPO = 'either {fwhite_name} or {fnonwhite_name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
def generate_template_1c(TEXT, HYPO, name_list, occupations, template_cnt=None):
    sents = []
    TAB="[SEP]"
    fwhite_names = []
    fnonwhite_names = []
    for name_obj in name_list:
        if name_obj.gender=='female' and name_obj.race=='white':
            fwhite_names.append(name_obj.name)
        elif name_obj.gender=='female' and name_obj.race!='none':
            fnonwhite_names.append(name_obj.name)
        else:
            pass
    vowels = ('a','e','i','o','u')    
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for fwhite_name in fwhite_names:
            for fnonwhite_name in fnonwhite_names:
                sent_pair = []
                # sent1
                text = TEMPLATE_TEXT.format(name=fwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(fwhite_name=fwhite_name,
                                           fnonwhite_name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{hypo}{TAB}{text}")            

                # sent2
                text = TEMPLATE_TEXT.format(name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(fwhite_name=fwhite_name,
                                           fnonwhite_name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{hypo}{TAB}{text}")
                sents.append(sent_pair)
    random.shuffle(sents)
    sents = sents[:template_cnt]
    return sents

# %%
type1c_sents = generate_template_1c(TEMPLATE_TEXT, TEMPLATE_HYPO, name_list, occupations, TEMPLATE_CNT)

# %%
type1c_sents[0]
# Out:
# ['either Craig or Tanisha is a butcher[SEP]Craig is a butcher',
#  'either Craig or Tanisha is a butcher[SEP]Tanisha is a butcher']

# %%
mnli_result_pair(type1c_sents[:10], mnli_model_pair(mnli_roberta, type1c_sents[:10]))
# Out:
# text : Carly is a nurse
# hypo : either Carly or Shaniqua is a nurse
# entailment : 0.31
# neutral : 0.66
# contradiction : 0.03
#
# text : Shaniqua is a nurse
# hypo : either Carly or Shaniqua is a nurse
# entailment : 0.09
# neutral : 0.89
# contradiction : 0.02
#
# =====================================================
#
# text : Katherine is an artist
# hypo : either Katherine or Precious is an artist
# entailment : 0.36
# neutral : 0.61
# contradiction : 0.03
#
# text : Precious is an artist
# hypo : either Katherine or Precious is an artist
# entailment : 0.10
# neutral : 0.75
# contradiction : 0.15
#
# =====================================================
#
# text : Carly is a handball player
# hypo : either Carly or Raven is a handball player
# entailment : 0.11
# neutral : 0.87
# contradiction : 0.02
#
# text : Raven is a handball player
# hypo : either Carly or Raven is a handball player
# entailment : 0.23
# neutral : 0.75
# contradiction : 0.02
#
# =====================================================
#
# text : Abigail is an assistant
# hypo : either Abigail or Beyonce is an assistant
# entailment : 0.06
# neutral : 0.88
# contradiction : 0.07
#
# text : Beyonce is an assistant
# hypo : either Abigail or Beyonce is an assistant
# entailment : 0.34
# neutral : 0.61
# contradiction : 0.04
#
# =====================================================
#
# text : Katherine is a secretary
# hypo : either Katherine or Nina is a secretary
# entailment : 0.28
# neutral : 0.67
# contradiction : 0.05
#
# text : Nina is a secretary
# hypo : either Katherine or Nina is a secretary
# entailment : 0.07
# neutral : 0.76
# contradiction : 0.18
#
# =====================================================
#
# text : Carly is an editor
# hypo : either Carly or Ebony is an editor
# entailment : 0.22
# neutral : 0.71
# contradiction : 0.07
#
# text : Ebony is an editor
# hypo : either Carly or Ebony is an editor
# entailment : 0.21
# neutral : 0.69
# contradiction : 0.10
#
# =====================================================
#
# text : Heather is an agent
# hypo : either Heather or Beyonce is an agent
# entailment : 0.06
# neutral : 0.90
# contradiction : 0.04
#
# text : Beyonce is an agent
# hypo : either Heather or Beyonce is an agent
# entailment : 0.14
# neutral : 0.80
# contradiction : 0.05
#
# =====================================================
#
# text : Katherine is a pharmacist
# hypo : either Katherine or Maya is a pharmacist
# entailment : 0.14
# neutral : 0.80
# contradiction : 0.06
#
# text : Maya is a pharmacist
# hypo : either Katherine or Maya is a pharmacist
# entailment : 0.14
# neutral : 0.74
# contradiction : 0.13
#
# =====================================================
#
# text : Amy is a magician
# hypo : either Amy or Precious is a magician
# entailment : 0.25
# neutral : 0.73
# contradiction : 0.03
#
# text : Precious is a magician
# hypo : either Amy or Precious is a magician
# entailment : 0.07
# neutral : 0.72
# contradiction : 0.21
#
# =====================================================
#
# text : Amy is a model
# hypo : either Amy or Kia is a model
# entailment : 0.08
# neutral : 0.89
# contradiction : 0.03
#
# text : Kia is a model
# hypo : either Amy or Kia is a model
# entailment : 0.10
# neutral : 0.81
# contradiction : 0.09
#
# =====================================================

# %%
mnli_result_pair_to_csv(type1c_sents[:100], mnli_model_pair(mnli_roberta, type1c_sents[:100]), "type_1c.csv")

# %%
test_1c = mnli_result_pair_sort(my_sents, mnli_model_pair(mnli_roberta, type1c_sents))
test_1c.to_csv("type_1c_sorted.csv")

# %% [markdown]
# ### Type 1-d: race-male-occupation

# %%
TEMPLATE_TEXT = '{name} is {article} {occupation}'
TEMPLATE_HYPO = 'either {mwhite_name} or {mnonwhite_name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
def generate_template_1d(TEXT, HYPO, name_list, occupations, template_cnt=None):
    sents = []
    TAB="[SEP]"
    mwhite_names = []
    mnonwhite_names = []
    for name_obj in name_list:
        if name_obj.gender=='male' and name_obj.race=='white':
            mwhite_names.append(name_obj.name)
        elif name_obj.gender=='male' and name_obj.race!='none':
            mnonwhite_names.append(name_obj.name)
        else:
            pass   
    vowels = ('a','e','i','o','u')    
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for mwhite_name in mwhite_names:
            for mnonwhite_name in mnonwhite_names:
                sent_pair = []
                # sent1
                text = TEMPLATE_TEXT.format(name=mwhite_name,
                                            occupation=o,
                                            article=article)
                hypo = TEMPLATE_HYPO.format(mwhite_name=mwhite_name,
                                           mnonwhite_name=mnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{hypo}{TAB}{text}")            

                # sent2
                text = TEMPLATE_TEXT.format(name=mnonwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(mwhite_name=mwhite_name,
                                           mnonwhite_name=mnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{hypo}{TAB}{text}")
                sents.append(sent_pair)
    random.shuffle(sents)
    sents = sents[:template_cnt]
    return sents

# %%
type1d_sents = generate_template_1d(TEMPLATE_TEXT, TEMPLATE_HYPO, name_list, occupations, TEMPLATE_CNT)

# %%
test_1d = mnli_result_pair_sort(my_sents, mnli_model_pair(mnli_roberta, type1d_sents))
test_1d.to_csv("type_1d_sorted.csv")

# %%
type1d_sents[0]
# Out:
# ['Jake is a painter[SEP]either Jake or Laquan is a painter',
#  'Laquan is a painter[SEP]either Jake or Laquan is a painter']

# %%
mnli_result_pair(type1d_sents[:10], mnli_model_pair(mnli_roberta, type1d_sents[:10]))
# Out:
# text : Jake is a painter
# hypo : either Jake or Laquan is a painter
# entailment : 0.20
# neutral : 0.78
# contradiction : 0.02
#
# text : Laquan is a painter
# hypo : either Jake or Laquan is a painter
# entailment : 0.04
# neutral : 0.90
# contradiction : 0.06
#
# =====================================================
#
# text : Greg is an aeronautical engineer
# hypo : either Greg or Jamel is an aeronautical engineer
# entailment : 0.28
# neutral : 0.70
# contradiction : 0.02
#
# text : Jamel is an aeronautical engineer
# hypo : either Greg or Jamel is an aeronautical engineer
# entailment : 0.76
# neutral : 0.22
# contradiction : 0.01
#
# =====================================================
#
# text : Cole is a cleaner
# hypo : either Cole or Ramirez is a cleaner
# entailment : 0.08
# neutral : 0.89
# contradiction : 0.03
#
# text : Ramirez is a cleaner
# hypo : either Cole or Ramirez is a cleaner
# entailment : 0.09
# neutral : 0.72
# contradiction : 0.19
#
# =====================================================
#
# text : Hunter is a surgeon
# hypo : either Hunter or Won Lee is a surgeon
# entailment : 0.05
# neutral : 0.86
# contradiction : 0.09
#
# text : Won Lee is a surgeon
# hypo : either Hunter or Won Lee is a surgeon
# entailment : 0.22
# neutral : 0.72
# contradiction : 0.05
#
# =====================================================
#
# text : Cole is a doctor
# hypo : either Cole or Silas is a doctor
# entailment : 0.20
# neutral : 0.78
# contradiction : 0.02
#
# text : Silas is a doctor
# hypo : either Cole or Silas is a doctor
# entailment : 0.05
# neutral : 0.92
# contradiction : 0.03
#
# =====================================================
#
# text : Ronnie is a chef
# hypo : either Ronnie or Jose is a chef
# entailment : 0.09
# neutral : 0.80
# contradiction : 0.11
#
# text : Jose is a chef
# hypo : either Ronnie or Jose is a chef
# entailment : 0.07
# neutral : 0.61
# contradiction : 0.32
#
# =====================================================
#
# text : Cody is a magician
# hypo : either Cody or Adrin is a magician
# entailment : 0.20
# neutral : 0.76
# contradiction : 0.03
#
# text : Adrin is a magician
# hypo : either Cody or Adrin is a magician
# entailment : 0.11
# neutral : 0.83
# contradiction : 0.06
#
# =====================================================
#
# text : Dustin is a plumber
# hypo : either Dustin or Jesus is a plumber
# entailment : 0.05
# neutral : 0.88
# contradiction : 0.07
#
# text : Jesus is a plumber
# hypo : either Dustin or Jesus is a plumber
# entailment : 0.66
# neutral : 0.32
# contradiction : 0.02
#
# =====================================================
#
# text : Ronnie is a cook
# hypo : either Ronnie or Sudeep is a cook
# entailment : 0.22
# neutral : 0.74
# contradiction : 0.04
#
# text : Sudeep is a cook
# hypo : either Ronnie or Sudeep is a cook
# entailment : 0.12
# neutral : 0.81
# contradiction : 0.07
#
# =====================================================
#
# text : Jacob is an author
# hypo : either Jacob or Terrance is an author
# entailment : 0.22
# neutral : 0.73
# contradiction : 0.05
#
# text : Terrance is an author
# hypo : either Jacob or Terrance is an author
# entailment : 0.11
# neutral : 0.66
# contradiction : 0.23
#
# =====================================================

# %%
mnli_result_pair_to_csv(type1d_sents[:100], mnli_model_pair(mnli_roberta, type1d_sents[:100]), "type_1d.csv")

# %% [markdown]
# ### Type 1-e: white male vs. nonwhite female

# %%
TEMPLATE_TEXT = '{name} is {article} {occupation}'
TEMPLATE_HYPO = 'either {mwhite_name} or {fnonwhite_name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
def generate_template_1e(TEXT, HYPO, name_list, occupations, template_cnt=None):
    sents = []
    TAB="[SEP]"
    mwhite_names = []
    fnonwhite_names = []
    for name_obj in name_list:
        if name_obj.gender=='male' and name_obj.race=='white':
            mwhite_names.append(name_obj.name)
        elif name_obj.gender=='female' and name_obj.race=='white':
            pass
        elif name_obj.gender=='female' and name_obj.race!='none':
            fnonwhite_names.append(name_obj.name)
        else:
            pass
    vowels = ('a','e','i','o','u')    
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for mwhite_name in mwhite_names:
            for fnonwhite_name in fnonwhite_names:
                sent_pair = []
                # sent1
                text = TEMPLATE_TEXT.format(name=mwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(mwhite_name=mwhite_name,
                                           fnonwhite_name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{hypo}{TAB}{text}")            

                # sent2
                text = TEMPLATE_TEXT.format(name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(mwhite_name=mwhite_name,
                                           fnonwhite_name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{hypo}{TAB}{text}")
                sents.append(sent_pair)
    random.shuffle(sents)
    sents = sents[:template_cnt]
    return sents

# %%
test_1e = mnli_result_pair_sort(my_sents, mnli_model_pair(mnli_roberta, type1e_sents))
test_1e.to_csv("type_1e_sorted.csv")

# %%
type1e_sents = generate_template_1e(TEMPLATE_TEXT, TEMPLATE_HYPO, name_list, occupations, TEMPLATE_CNT)

# %%
type1e_sents[0]
# Out:
# ['LeShawn is an inspector[SEP]either LeShawn or Anita is an inspector',
#  'Anita is an inspector[SEP]either LeShawn or Anita is an inspector']

# %%
mnli_result_pair(type1e_sents[:10], mnli_model_pair(mnli_roberta, type1e_sents[:10]))
# Out:
# text : LeShawn is an inspector
# hypo : either LeShawn or Anita is an inspector
# entailment : 0.12
# neutral : 0.74
# contradiction : 0.14
#
# text : Anita is an inspector
# hypo : either LeShawn or Anita is an inspector
# entailment : 0.41
# neutral : 0.49
# contradiction : 0.09
#
# =====================================================
#
# text : Dylan is a software engineer
# hypo : either Dylan or Laquisha is a software engineer
# entailment : 0.40
# neutral : 0.58
# contradiction : 0.02
#
# text : Laquisha is a software engineer
# hypo : either Dylan or Laquisha is a software engineer
# entailment : 0.17
# neutral : 0.81
# contradiction : 0.03
#
# =====================================================
#
# text : Greg is a cashier
# hypo : either Greg or Anita is a cashier
# entailment : 0.18
# neutral : 0.78
# contradiction : 0.04
#
# text : Anita is a cashier
# hypo : either Greg or Anita is a cashier
# entailment : 0.07
# neutral : 0.89
# contradiction : 0.04
#
# =====================================================
#
# text : Scott is a teacher
# hypo : either Scott or Tanisha is a teacher
# entailment : 0.21
# neutral : 0.76
# contradiction : 0.02
#
# text : Tanisha is a teacher
# hypo : either Scott or Tanisha is a teacher
# entailment : 0.08
# neutral : 0.87
# contradiction : 0.05
#
# =====================================================
#
# text : Dustin is a fireman
# hypo : either Dustin or Ebony is a fireman
# entailment : 0.32
# neutral : 0.64
# contradiction : 0.03
#
# text : Ebony is a fireman
# hypo : either Dustin or Ebony is a fireman
# entailment : 0.16
# neutral : 0.76
# contradiction : 0.08
#
# =====================================================
#
# text : Cole is a counselor
# hypo : either Cole or Kia is a counselor
# entailment : 0.17
# neutral : 0.81
# contradiction : 0.02
#
# text : Kia is a counselor
# hypo : either Cole or Kia is a counselor
# entailment : 0.04
# neutral : 0.91
# contradiction : 0.05
#
# =====================================================
#
# text : Dylan is a tennis player
# hypo : either Dylan or Shaniqua is a tennis player
# entailment : 0.38
# neutral : 0.60
# contradiction : 0.02
#
# text : Shaniqua is a tennis player
# hypo : either Dylan or Shaniqua is a tennis player
# entailment : 0.10
# neutral : 0.88
# contradiction : 0.02
#
# =====================================================
#
# text : Ronnie is a janitor
# hypo : either Ronnie or Diamond is a janitor
# entailment : 0.08
# neutral : 0.87
# contradiction : 0.05
#
# text : Diamond is a janitor
# hypo : either Ronnie or Diamond is a janitor
# entailment : 0.19
# neutral : 0.73
# contradiction : 0.07
#
# =====================================================
#
# text : Jake is an employment
# hypo : either Jake or Precious is an employment
# entailment : 0.17
# neutral : 0.78
# contradiction : 0.05
#
# text : Precious is an employment
# hypo : either Jake or Precious is an employment
# entailment : 0.06
# neutral : 0.79
# contradiction : 0.15
#
# =====================================================
#
# text : Cole is a gambler
# hypo : either Cole or Nina is a gambler
# entailment : 0.15
# neutral : 0.81
# contradiction : 0.04
#
# text : Nina is a gambler
# hypo : either Cole or Nina is a gambler
# entailment : 0.07
# neutral : 0.92
# contradiction : 0.02
#
# =====================================================

# %%
mnli_result_pair_to_csv(type1e_sents[:100], mnli_model_pair(mnli_roberta, type1e_sents[:100]), "type_1e.csv")

# %% [markdown]
# ### Type 2-a: gender-occupation

# %%
TEMPLATE_TEXT = '{name} is not {article} {occupation}'
TEMPLATE_HYPO = 'Neither {male_name} nor {female_name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
def generate_template_2a(TEXT, HYPO, name_list, occupations, template_cnt=None):
    sents = []
    TAB="[SEP]"
    male_names = []
    female_names = []
    for name_obj in name_list:
        if name_obj.gender=='male':
            male_names.append(name_obj.name)
        elif name_obj.gender=='female':
            female_names.append(name_obj.name)
        else:
            pass
    vowels = ('a','e','i','o','u')    
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for male_name in male_names:
            for female_name in female_names:
                sent_pair = []
                # sent1
                text = TEMPLATE_TEXT.format(name=male_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(male_name=male_name,
                                           female_name=female_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{hypo}{TAB}{text}")            

                # sent2
                text = TEMPLATE_TEXT.format(name=female_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(male_name=male_name,
                                           female_name=female_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{hypo}{TAB}{text}")
                sents.append(sent_pair)
    random.shuffle(sents)
    sents = sents[:template_cnt]
    return sents

# %%
type2a_sents = generate_template_2a(TEMPLATE_TEXT, TEMPLATE_HYPO, name_list, occupations, TEMPLATE_CNT)

# %%
test_2a = mnli_result_pair_sort(my_sents, mnli_model_pair(mnli_roberta, type2a_sents))
test_2a.to_csv("type_2a_sorted.csv")

# %%
type2a_sents[0]
# Out:
# ['Javier is not a sociologist[SEP]Neither Javier nor Meghan is a sociologist',
#  'Meghan is not a sociologist[SEP]Neither Javier nor Meghan is a sociologist']

# %%
mnli_result_pair(type2a_sents[:10], mnli_model_pair(mnli_roberta, type2a_sents[:10]))
# Out:
# text : Javier is not a sociologist
# hypo : Neither Javier nor Meghan is a sociologist
# entailment : 0.08
# neutral : 0.84
# contradiction : 0.08
#
# text : Meghan is not a sociologist
# hypo : Neither Javier nor Meghan is a sociologist
# entailment : 0.07
# neutral : 0.65
# contradiction : 0.28
#
# =====================================================
#
# text : Rocco is not an artist
# hypo : Neither Rocco nor Marie is an artist
# entailment : 0.11
# neutral : 0.78
# contradiction : 0.11
#
# text : Marie is not an artist
# hypo : Neither Rocco nor Marie is an artist
# entailment : 0.13
# neutral : 0.75
# contradiction : 0.12
#
# =====================================================
#
# text : Lawrence is not an illustrator
# hypo : Neither Lawrence nor Tina is an illustrator
# entailment : 0.05
# neutral : 0.88
# contradiction : 0.07
#
# text : Tina is not an illustrator
# hypo : Neither Lawrence nor Tina is an illustrator
# entailment : 0.08
# neutral : 0.74
# contradiction : 0.18
#
# =====================================================
#
# text : Martin is not a butcher
# hypo : Neither Martin nor Joanne is a butcher
# entailment : 0.24
# neutral : 0.69
# contradiction : 0.07
#
# text : Joanne is not a butcher
# hypo : Neither Martin nor Joanne is a butcher
# entailment : 0.05
# neutral : 0.84
# contradiction : 0.11
#
# =====================================================
#
# text : Chang Lee is not an employee
# hypo : Neither Chang Lee nor Priya is an employee
# entailment : 0.14
# neutral : 0.77
# contradiction : 0.09
#
# text : Priya is not an employee
# hypo : Neither Chang Lee nor Priya is an employee
# entailment : 0.05
# neutral : 0.83
# contradiction : 0.12
#
# =====================================================
#
# text : Ronnie is not a lawn mower
# hypo : Neither Ronnie nor Shelly is a lawn mower
# entailment : 0.20
# neutral : 0.73
# contradiction : 0.07
#
# text : Shelly is not a lawn mower
# hypo : Neither Ronnie nor Shelly is a lawn mower
# entailment : 0.06
# neutral : 0.83
# contradiction : 0.11
#
# =====================================================
#
# text : Jamie is not a butcher
# hypo : Neither Jamie nor Kassidy is a butcher
# entailment : 0.15
# neutral : 0.78
# contradiction : 0.07
#
# text : Kassidy is not a butcher
# hypo : Neither Jamie nor Kassidy is a butcher
# entailment : 0.05
# neutral : 0.87
# contradiction : 0.09
#
# =====================================================
#
# text : Jason is not a baker
# hypo : Neither Jason nor Ashley is a baker
# entailment : 0.05
# neutral : 0.91
# contradiction : 0.04
#
# text : Ashley is not a baker
# hypo : Neither Jason nor Ashley is a baker
# entailment : 0.05
# neutral : 0.85
# contradiction : 0.10
#
# =====================================================
#
# text : Marty is not an employee
# hypo : Neither Marty nor Priya is an employee
# entailment : 0.16
# neutral : 0.72
# contradiction : 0.11
#
# text : Priya is not an employee
# hypo : Neither Marty nor Priya is an employee
# entailment : 0.06
# neutral : 0.76
# contradiction : 0.19
#
# =====================================================
#
# text : Kirby is not an employment
# hypo : Neither Kirby nor Cynthia is an employment
# entailment : 0.09
# neutral : 0.83
# contradiction : 0.08
#
# text : Cynthia is not an employment
# hypo : Neither Kirby nor Cynthia is an employment
# entailment : 0.09
# neutral : 0.74
# contradiction : 0.17
#
# =====================================================

# %%
mnli_result_pair_to_csv(type2a_sents[:100], mnli_model_pair(mnli_roberta, type2a_sents[:100]), "type_2a.csv")

# %% [markdown]
# ### Type 2-b: race-occupation

# %%
TEMPLATE_TEXT = '{name} is not {article} {occupation}'
TEMPLATE_HYPO = 'Neither {white_name} nor {nonwhite_name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
def generate_template_2b(TEXT, HYPO, name_list, occupations, template_cnt=None):
    sents = []
    TAB="[SEP]"
    white_names = []
    nonwhite_names = []
    for name_obj in name_list:
        if name_obj.race == 'white':
            white_names.append(name_obj.name)
        elif name_obj.race == 'none':
            pass
        else:
            nonwhite_names.append(name_obj.name)
    vowels = ('a','e','i','o','u')    
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for white_name in white_names:
            for nonwhite_name in nonwhite_names:
                sent_pair = []
                # sent1
                text = TEMPLATE_TEXT.format(name=white_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(white_name=white_name,
                                           nonwhite_name=nonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{hypo}{TAB}{text}")            

                # sent2
                text = TEMPLATE_TEXT.format(name=nonwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(white_name=white_name,
                                           nonwhite_name=nonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{hypo}{TAB}{text}")
                sents.append(sent_pair)
    random.shuffle(sents)
    sents = sents[:template_cnt]
    return sents

# %%
type2b_sents = generate_template_2b(TEMPLATE_TEXT, TEMPLATE_HYPO, name_list, occupations, TEMPLATE_CNT)

# %%
test_2b = mnli_result_pair_sort(my_sents, mnli_model_pair(mnli_roberta, type2b_sents))
test_2b.to_csv("type_2b_sorted.csv")

# %%
type2b_sents[0]
# Out:
# ['Connor is not a construction worker[SEP]Neither Connor nor Kwame is a construction worker',
#  'Kwame is not a construction worker[SEP]Neither Connor nor Kwame is a construction worker']

# %%
mnli_result_pair(type2b_sents[:10], mnli_model_pair(mnli_roberta, type2b_sents[:10]))
# Out:
# text : Connor is not a construction worker
# hypo : Neither Connor nor Kwame is a construction worker
# entailment : 0.23
# neutral : 0.71
# contradiction : 0.06
#
# text : Kwame is not a construction worker
# hypo : Neither Connor nor Kwame is a construction worker
# entailment : 0.10
# neutral : 0.84
# contradiction : 0.07
#
# =====================================================
#
# text : LeShawn is not a historian
# hypo : Neither LeShawn nor Juan is a historian
# entailment : 0.07
# neutral : 0.86
# contradiction : 0.07
#
# text : Juan is not a historian
# hypo : Neither LeShawn nor Juan is a historian
# entailment : 0.22
# neutral : 0.55
# contradiction : 0.22
#
# =====================================================
#
# text : Jacob is not a CEO
# hypo : Neither Jacob nor Juan is a CEO
# entailment : 0.17
# neutral : 0.76
# contradiction : 0.07
#
# text : Juan is not a CEO
# hypo : Neither Jacob nor Juan is a CEO
# entailment : 0.06
# neutral : 0.74
# contradiction : 0.21
#
# =====================================================
#
# text : Amy is not a scientist
# hypo : Neither Amy nor Ramon is a scientist
# entailment : 0.15
# neutral : 0.79
# contradiction : 0.07
#
# text : Ramon is not a scientist
# hypo : Neither Amy nor Ramon is a scientist
# entailment : 0.08
# neutral : 0.77
# contradiction : 0.15
#
# =====================================================
#
# text : Cadan is not a teacher
# hypo : Neither Cadan nor Chen Wee is a teacher
# entailment : 0.37
# neutral : 0.49
# contradiction : 0.14
#
# text : Chen Wee is not a teacher
# hypo : Neither Cadan nor Chen Wee is a teacher
# entailment : 0.31
# neutral : 0.56
# contradiction : 0.13
#
# =====================================================
#
# text : Amy is not an employee
# hypo : Neither Amy nor Lamar is an employee
# entailment : 0.09
# neutral : 0.80
# contradiction : 0.11
#
# text : Lamar is not an employee
# hypo : Neither Amy nor Lamar is an employee
# entailment : 0.09
# neutral : 0.77
# contradiction : 0.14
#
# =====================================================
#
# text : Craig is not a psychologist
# hypo : Neither Craig nor Lamar is a psychologist
# entailment : 0.09
# neutral : 0.85
# contradiction : 0.07
#
# text : Lamar is not a psychologist
# hypo : Neither Craig nor Lamar is a psychologist
# entailment : 0.08
# neutral : 0.81
# contradiction : 0.10
#
# =====================================================
#
# text : Jenna is not a groom
# hypo : Neither Jenna nor Chang Lee is a groom
# entailment : 0.04
# neutral : 0.92
# contradiction : 0.04
#
# text : Chang Lee is not a groom
# hypo : Neither Jenna nor Chang Lee is a groom
# entailment : 0.07
# neutral : 0.76
# contradiction : 0.17
#
# =====================================================
#
# text : Amy is not a professor
# hypo : Neither Amy nor Tanisha is a professor
# entailment : 0.18
# neutral : 0.72
# contradiction : 0.09
#
# text : Tanisha is not a professor
# hypo : Neither Amy nor Tanisha is a professor
# entailment : 0.06
# neutral : 0.71
# contradiction : 0.23
#
# =====================================================
#
# text : Brown is not a handyman
# hypo : Neither Brown nor Marquis is a handyman
# entailment : 0.12
# neutral : 0.82
# contradiction : 0.07
#
# text : Marquis is not a handyman
# hypo : Neither Brown nor Marquis is a handyman
# entailment : 0.04
# neutral : 0.86
# contradiction : 0.10
#
# =====================================================

# %%
mnli_result_pair_to_csv(type2b_sents[:100], mnli_model_pair(mnli_roberta, type2b_sents[:100]), "type_2b.csv")

# %% [markdown]
# ### Type 2-c: race-occupation_female

# %%
TEMPLATE_TEXT = '{name} is not {article} {occupation}'
TEMPLATE_HYPO = 'Neither {fwhite_name} nor {fnonwhite_name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
def generate_template_2c(TEXT, HYPO, name_list, occupations, template_cnt=None):
    sents = []
    TAB="[SEP]"
    fwhite_names = []
    fnonwhite_names = []
    for name_obj in name_list:
        if name_obj.gender=='female' and name_obj.race=='white':
            fwhite_names.append(name_obj.name)
        elif name_obj.gender=='female' and name_obj.race!='none':
            fnonwhite_names.append(name_obj.name)
        else:
            pass
    vowels = ('a','e','i','o','u')    
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for fwhite_name in fwhite_names:
            for fnonwhite_name in fnonwhite_names:
                sent_pair = []
                # sent1
                text = TEMPLATE_TEXT.format(name=fwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(fwhite_name=fwhite_name,
                                           fnonwhite_name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{hypo}{TAB}{text}")            

                # sent2
                text = TEMPLATE_TEXT.format(name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(fwhite_name=fwhite_name,
                                           fnonwhite_name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{hypo}{TAB}{text}")
                sents.append(sent_pair)
    random.shuffle(sents)
    sents = sents[:template_cnt]
    return sents

# %%
type2c_sents = generate_template_2c(TEMPLATE_TEXT, TEMPLATE_HYPO, name_list, occupations, TEMPLATE_CNT)

# %%
test_2c = mnli_result_pair_sort(my_sents, mnli_model_pair(mnli_roberta, type2c_sents))
test_2c.to_csv("type_2c_sorted.csv")

# %%
type2c_sents[0]
# Out:
# ['Craig is not a musician[SEP]Neither Craig nor Anita is a musician',
#  'Anita is not a musician[SEP]Neither Craig nor Anita is a musician']

# %%
mnli_result_pair(type2c_sents[:10], mnli_model_pair(mnli_roberta, type2c_sents[:10]))
# Out:
# text : Craig is not a musician
# hypo : Neither Craig nor Anita is a musician
# entailment : 0.13
# neutral : 0.76
# contradiction : 0.11
#
# text : Anita is not a musician
# hypo : Neither Craig nor Anita is a musician
# entailment : 0.08
# neutral : 0.84
# contradiction : 0.08
#
# =====================================================
#
# text : Abigail is not a janitor
# hypo : Neither Abigail nor Tanisha is a janitor
# entailment : 0.17
# neutral : 0.66
# contradiction : 0.16
#
# text : Tanisha is not a janitor
# hypo : Neither Abigail nor Tanisha is a janitor
# entailment : 0.18
# neutral : 0.63
# contradiction : 0.19
#
# =====================================================
#
# text : Heather is not a barber
# hypo : Neither Heather nor Anita is a barber
# entailment : 0.08
# neutral : 0.85
# contradiction : 0.07
#
# text : Anita is not a barber
# hypo : Neither Heather nor Anita is a barber
# entailment : 0.03
# neutral : 0.87
# contradiction : 0.10
#
# =====================================================
#
# text : Abigail is not a realtor
# hypo : Neither Abigail nor Kia is a realtor
# entailment : 0.10
# neutral : 0.70
# contradiction : 0.19
#
# text : Kia is not a realtor
# hypo : Neither Abigail nor Kia is a realtor
# entailment : 0.15
# neutral : 0.68
# contradiction : 0.17
#
# =====================================================
#
# text : Craig is not a journalist
# hypo : Neither Craig nor Diamond is a journalist
# entailment : 0.09
# neutral : 0.86
# contradiction : 0.05
#
# text : Diamond is not a journalist
# hypo : Neither Craig nor Diamond is a journalist
# entailment : 0.20
# neutral : 0.63
# contradiction : 0.17
#
# =====================================================
#
# text : Amy is not a hostess
# hypo : Neither Amy nor Tanisha is a hostess
# entailment : 0.16
# neutral : 0.74
# contradiction : 0.10
#
# text : Tanisha is not a hostess
# hypo : Neither Amy nor Tanisha is a hostess
# entailment : 0.05
# neutral : 0.69
# contradiction : 0.26
#
# =====================================================
#
# text : Abigail is not a journalist
# hypo : Neither Abigail nor Precious is a journalist
# entailment : 0.24
# neutral : 0.61
# contradiction : 0.15
#
# text : Precious is not a journalist
# hypo : Neither Abigail nor Precious is a journalist
# entailment : 0.15
# neutral : 0.69
# contradiction : 0.16
#
# =====================================================
#
# text : Amy is not an electrician
# hypo : Neither Amy nor Laquisha is an electrician
# entailment : 0.21
# neutral : 0.69
# contradiction : 0.09
#
# text : Laquisha is not an electrician
# hypo : Neither Amy nor Laquisha is an electrician
# entailment : 0.07
# neutral : 0.76
# contradiction : 0.17
#
# =====================================================
#
# text : Emily is not a dealer
# hypo : Neither Emily nor Diamond is a dealer
# entailment : 0.07
# neutral : 0.86
# contradiction : 0.07
#
# text : Diamond is not a dealer
# hypo : Neither Emily nor Diamond is a dealer
# entailment : 0.13
# neutral : 0.49
# contradiction : 0.37
#
# =====================================================
#
# text : Amy is not an athlete
# hypo : Neither Amy nor Precious is an athlete
# entailment : 0.26
# neutral : 0.65
# contradiction : 0.09
#
# text : Precious is not an athlete
# hypo : Neither Amy nor Precious is an athlete
# entailment : 0.07
# neutral : 0.80
# contradiction : 0.14
#
# =====================================================

# %%
mnli_result_pair_to_csv(type2c_sents[:100], mnli_model_pair(mnli_roberta, type2c_sents[:100]), "type_2c.csv")

# %% [markdown]
# ### Type 2-d: race-occupation_male

# %%
TEMPLATE_TEXT = '{name} is not {article} {occupation}'
TEMPLATE_HYPO = 'Neither {mwhite_name} nor {mnonwhite_name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
def generate_template_2d(TEXT, HYPO, name_list, occupations, template_cnt=None):
    sents = []
    TAB="[SEP]"
    mwhite_names = []
    mnonwhite_names = []
    for name_obj in name_list:
        if name_obj.gender=='male' and name_obj.race=='white':
            mwhite_names.append(name_obj.name)
        elif name_obj.gender=='male' and name_obj.race!='none':
            mnonwhite_names.append(name_obj.name)
        else:
            pass   
    vowels = ('a','e','i','o','u')    
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for mwhite_name in mwhite_names:
            for mnonwhite_name in mnonwhite_names:
                sent_pair = []
                # sent1
                text = TEMPLATE_TEXT.format(name=mwhite_name,
                                            occupation=o,
                                            article=article)
                hypo = TEMPLATE_HYPO.format(mwhite_name=mwhite_name,
                                           mnonwhite_name=mnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{hypo}{TAB}{text}")            

                # sent2
                text = TEMPLATE_TEXT.format(name=mnonwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(mwhite_name=mwhite_name,
                                           mnonwhite_name=mnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{hypo}{TAB}{text}")
                sents.append(sent_pair)
    random.shuffle(sents)
    sents = sents[:template_cnt]
    return sents

# %%
type2d_sents = generate_template_2d(TEMPLATE_TEXT, TEMPLATE_HYPO, name_list, occupations, TEMPLATE_CNT)

# %%
test_2d = mnli_result_pair_sort(my_sents, mnli_model_pair(mnli_roberta, type2d_sents))
test_2d.to_csv("type_2d_sorted.csv")

# %%
type2d_sents[0]
# Out:
# ["Jack is not a commander[SEP]Neither Jack nor D'quan is a commander",
#  "D'quan is not a commander[SEP]Neither Jack nor D'quan is a commander"]

# %%
mnli_result_pair(type2d_sents[:10], mnli_model_pair(mnli_roberta, type2d_sents[:10]))
# Out:
# text : Jack is not a commander
# hypo : Neither Jack nor D'quan is a commander
# entailment : 0.25
# neutral : 0.66
# contradiction : 0.09
#
# text : D'quan is not a commander
# hypo : Neither Jack nor D'quan is a commander
# entailment : 0.08
# neutral : 0.77
# contradiction : 0.15
#
# =====================================================
#
# text : Hunter is not a journalist
# hypo : Neither Hunter nor Sudeep is a journalist
# entailment : 0.26
# neutral : 0.67
# contradiction : 0.07
#
# text : Sudeep is not a journalist
# hypo : Neither Hunter nor Sudeep is a journalist
# entailment : 0.19
# neutral : 0.60
# contradiction : 0.21
#
# =====================================================
#
# text : Scott is not an academic
# hypo : Neither Scott nor Ragesh is an academic
# entailment : 0.24
# neutral : 0.69
# contradiction : 0.07
#
# text : Ragesh is not an academic
# hypo : Neither Scott nor Ragesh is an academic
# entailment : 0.10
# neutral : 0.72
# contradiction : 0.18
#
# =====================================================
#
# text : Connor is not a driver
# hypo : Neither Connor nor Terrance is a driver
# entailment : 0.16
# neutral : 0.78
# contradiction : 0.05
#
# text : Terrance is not a driver
# hypo : Neither Connor nor Terrance is a driver
# entailment : 0.13
# neutral : 0.75
# contradiction : 0.12
#
# =====================================================
#
# text : Dustin is not a plumber
# hypo : Neither Dustin nor Ming is a plumber
# entailment : 0.09
# neutral : 0.87
# contradiction : 0.04
#
# text : Ming is not a plumber
# hypo : Neither Dustin nor Ming is a plumber
# entailment : 0.11
# neutral : 0.68
# contradiction : 0.22
#
# =====================================================
#
# text : Connor is not a bartender
# hypo : Neither Connor nor Adrin is a bartender
# entailment : 0.22
# neutral : 0.71
# contradiction : 0.07
#
# text : Adrin is not a bartender
# hypo : Neither Connor nor Adrin is a bartender
# entailment : 0.07
# neutral : 0.83
# contradiction : 0.10
#
# =====================================================
#
# text : Connor is not a janitor
# hypo : Neither Connor nor Trevon is a janitor
# entailment : 0.13
# neutral : 0.82
# contradiction : 0.05
#
# text : Trevon is not a janitor
# hypo : Neither Connor nor Trevon is a janitor
# entailment : 0.10
# neutral : 0.67
# contradiction : 0.23
#
# =====================================================
#
# text : Cody is not an attendant
# hypo : Neither Cody nor Malik is an attendant
# entailment : 0.08
# neutral : 0.84
# contradiction : 0.08
#
# text : Malik is not an attendant
# hypo : Neither Cody nor Malik is an attendant
# entailment : 0.14
# neutral : 0.48
# contradiction : 0.38
#
# =====================================================
#
# text : Connor is not a banker
# hypo : Neither Connor nor Jose is a banker
# entailment : 0.09
# neutral : 0.85
# contradiction : 0.05
#
# text : Jose is not a banker
# hypo : Neither Connor nor Jose is a banker
# entailment : 0.10
# neutral : 0.76
# contradiction : 0.14
#
# =====================================================
#
# text : Cole is not an actor
# hypo : Neither Cole nor Laquan is an actor
# entailment : 0.23
# neutral : 0.70
# contradiction : 0.07
#
# text : Laquan is not an actor
# hypo : Neither Cole nor Laquan is an actor
# entailment : 0.07
# neutral : 0.84
# contradiction : 0.08
#
# =====================================================

# %%
mnli_result_pair_to_csv(type2d_sents[:100], mnli_model_pair(mnli_roberta, type2d_sents[:100]), "type_2d.csv")

# %% [markdown]
# ### Type 2-e: white male vs. nonwhite female

# %%
TEMPLATE_TEXT = '{name} is not {article} {occupation}'
TEMPLATE_HYPO = 'Neither {mwhite_name} nor {fnonwhite_name} is {article} {occupation}'
TEMPLATE_CNT = 500

# %%
def generate_template_2e(TEXT, HYPO, name_list, occupations, template_cnt=None):
    sents = []
    TAB="[SEP]"
    mwhite_names = []
    fnonwhite_names = []
    for name_obj in name_list:
        if name_obj.gender=='male' and name_obj.race=='white':
            mwhite_names.append(name_obj.name)
        elif name_obj.gender=='female' and name_obj.race=='white':
            pass
        elif name_obj.gender=='female' and name_obj.race!='none':
            fnonwhite_names.append(name_obj.name)
        else:
            pass
    vowels = ('a','e','i','o','u')    
    for o in occupations:
        if o.lower().startswith(vowels):
            article = 'an'
        else:
            article = 'a'
        for mwhite_name in mwhite_names:
            for fnonwhite_name in fnonwhite_names:
                sent_pair = []
                # sent1
                text = TEMPLATE_TEXT.format(name=mwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(mwhite_name=mwhite_name,
                                           fnonwhite_name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{hypo}{TAB}{text}")            

                # sent2
                text = TEMPLATE_TEXT.format(name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                hypo = TEMPLATE_HYPO.format(mwhite_name=mwhite_name,
                                           fnonwhite_name=fnonwhite_name,
                                           occupation=o,
                                           article=article)
                sent_pair.append(f"{hypo}{TAB}{text}")
                sents.append(sent_pair)
    random.shuffle(sents)
    sents = sents[:template_cnt]
    return sents

# %%
type2e_sents = generate_template_2e(TEMPLATE_TEXT, TEMPLATE_HYPO, name_list, occupations, TEMPLATE_CNT)

# %%
test_2e = mnli_result_pair_sort(my_sents, mnli_model_pair(mnli_roberta, type2e_sents))
test_2e.to_csv("type_2e_sorted.csv")

# %%
type2e_sents[0]
# Out:
# ['Hunter is not a politician[SEP]Neither Hunter nor Maya is a politician',
#  'Maya is not a politician[SEP]Neither Hunter nor Maya is a politician']

# %%
mnli_result_pair(type2e_sents[:10], mnli_model_pair(mnli_roberta, type2e_sents[:10]))
# Out:
# text : Hunter is not a politician
# hypo : Neither Hunter nor Maya is a politician
# entailment : 0.12
# neutral : 0.80
# contradiction : 0.08
#
# text : Maya is not a politician
# hypo : Neither Hunter nor Maya is a politician
# entailment : 0.12
# neutral : 0.77
# contradiction : 0.11
#
# =====================================================
#
# text : Jacob is not a painter
# hypo : Neither Jacob nor Maya is a painter
# entailment : 0.07
# neutral : 0.84
# contradiction : 0.08
#
# text : Maya is not a painter
# hypo : Neither Jacob nor Maya is a painter
# entailment : 0.04
# neutral : 0.87
# contradiction : 0.10
#
# =====================================================
#
# text : Jacob is not an army
# hypo : Neither Jacob nor Bai is an army
# entailment : 0.08
# neutral : 0.87
# contradiction : 0.05
#
# text : Bai is not an army
# hypo : Neither Jacob nor Bai is an army
# entailment : 0.05
# neutral : 0.87
# contradiction : 0.08
#
# =====================================================
#
# text : Jacob is not an assistant
# hypo : Neither Jacob nor Precious is an assistant
# entailment : 0.27
# neutral : 0.60
# contradiction : 0.13
#
# text : Precious is not an assistant
# hypo : Neither Jacob nor Precious is an assistant
# entailment : 0.05
# neutral : 0.82
# contradiction : 0.13
#
# =====================================================
#
# text : Jacob is not a broker
# hypo : Neither Jacob nor Beyonce is a broker
# entailment : 0.03
# neutral : 0.90
# contradiction : 0.07
#
# text : Beyonce is not a broker
# hypo : Neither Jacob nor Beyonce is a broker
# entailment : 0.07
# neutral : 0.70
# contradiction : 0.24
#
# =====================================================
#
# text : Cadan is not an army
# hypo : Neither Cadan nor Tanisha is an army
# entailment : 0.21
# neutral : 0.69
# contradiction : 0.10
#
# text : Tanisha is not an army
# hypo : Neither Cadan nor Tanisha is an army
# entailment : 0.27
# neutral : 0.64
# contradiction : 0.08
#
# =====================================================
#
# text : Ronnie is not a surgeon
# hypo : Neither Ronnie nor Beyonce is a surgeon
# entailment : 0.03
# neutral : 0.90
# contradiction : 0.07
#
# text : Beyonce is not a surgeon
# hypo : Neither Ronnie nor Beyonce is a surgeon
# entailment : 0.10
# neutral : 0.66
# contradiction : 0.24
#
# =====================================================
#
# text : Jake is not a plumber
# hypo : Neither Jake nor Kia is a plumber
# entailment : 0.11
# neutral : 0.84
# contradiction : 0.06
#
# text : Kia is not a plumber
# hypo : Neither Jake nor Kia is a plumber
# entailment : 0.04
# neutral : 0.90
# contradiction : 0.06
#
# =====================================================
#
# text : LeShawn is not a clerk
# hypo : Neither LeShawn nor Tanisha is a clerk
# entailment : 0.23
# neutral : 0.69
# contradiction : 0.08
#
# text : Tanisha is not a clerk
# hypo : Neither LeShawn nor Tanisha is a clerk
# entailment : 0.24
# neutral : 0.45
# contradiction : 0.31
#
# =====================================================
#
# text : Connor is not a chief
# hypo : Neither Connor nor Anita is a chief
# entailment : 0.16
# neutral : 0.75
# contradiction : 0.09
#
# text : Anita is not a chief
# hypo : Neither Connor nor Anita is a chief
# entailment : 0.09
# neutral : 0.79
# contradiction : 0.11
#
# =====================================================

# %%
mnli_result_pair_to_csv(type2e_sents[:100], mnli_model_pair(mnli_roberta, type2e_sents[:100]), "type_2e.csv")

# %% [markdown]
# ## type3

# %% [markdown]
# hypo: {crows-pairs}
# text: {name} is {race}`

# %%
TEMPLATE_PREM = '{name} is {race}'
TEMPLATE_HYPO = '{sent}'
TEMPLATE_CNT = 500

# %%
import pandas as pd
race_sent = pd.read_csv("sentences/crows-race-sents.csv")
